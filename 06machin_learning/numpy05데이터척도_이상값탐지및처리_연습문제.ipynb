# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_csv("./data/05_House Prices - Advanced Regression Techniques.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### 문제1 핵심 수치형 변수 살펴보기

# %%
df[['SalePrice','LotArea','GrLivArea','GarageArea']].describe().T
# LotArea가 변수에 극단적인 분포를 가지고 있다.
# Out:
#              count           mean           std      min       25%       50%  \
# SalePrice   1460.0  180921.195890  79442.502883  34900.0  129975.0  163000.0
# LotArea     1460.0   10516.828082   9981.264932   1300.0    7553.5    9478.5
# GrLivArea   1460.0    1515.463699    525.480383    334.0    1129.5    1464.0
# GarageArea  1460.0     472.980137    213.804841      0.0     334.5     480.0
#
#                   75%       max
# SalePrice   214000.00  755000.0
# LotArea      11601.50  215245.0
# GrLivArea     1776.75    5642.0
# GarageArea     576.00    1418.0

# %% [markdown]
# ### 문제2 박스플롯&산점도 시각화

# %%
sum_db = df[['SalePrice','LotArea','GrLivArea','GarageArea']]

# %%
#박스플롯
for i in sum_db:
    print(i)
    sum_db[i].describe()
    sum_db[i].plot(kind="box")
    plt.show()
# Out:
# SalePrice
# LotArea
# GrLivArea
# GarageArea

# %%
#산점도
plt.figure()
sns.lmplot(data=df,x='GrLivArea',y='SalePrice',height = 4.5, aspect=1.2 )
plt.show()

# %% [markdown]
# ### 문제3 IQR 기반 이상값 경계

# %%
SP_IQR = df["SalePrice"].describe()

# %%
Q1 = SP_IQR['25%']
Q3 = SP_IQR['75%']
IQR = Q3-Q1

# %%
lower = Q1 -1.5*IQR
lower
# Out:
# np.float64(3937.5)

# %%
upper = Q3 + 1.5*IQR
upper
# Out:
# np.float64(340037.5)

# %%
# 범위를 벗어난 행의 개수와 비율
print(len(df[df["SalePrice"] > upper]))
len(df[df["SalePrice"] > upper]) / len(df) *100
# Out:
# 61
# 4.178082191780822

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### 문제4 면적 관련 이상값 탐지

# %%
GLA_IQR = df["GrLivArea"].describe()
GLA_IQR
# Out:
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64

# %%
GLA_Q1 = GLA_IQR['25%']
GLA_Q3 = GLA_IQR['75%']
GLA_IQRs = GLA_Q3-GLA_Q1

# %%
print(GLA_Q1,GLA_Q3,GLA_IQRs)
# Out:
# 1129.5 1776.75 647.25

# %%
LA_IQR = df["LotArea"].describe()

# %%
LA_Q1 = LA_IQR['25%']
LA_Q3 = LA_IQR['75%']
LA_IQRs = LA_Q3-LA_Q1

# %%
print(LA_Q1,LA_Q3,LA_IQRs)
# Out:
# 7553.5 11601.5 4048.0

# %%
lower_bround = GLA_Q1 - 1.5*GLA_IQRs

# %%
upper_bround = GLA_Q3 + 1.5*GLA_IQRs
upper_bround
# Out:
# np.float64(2747.625)

# %%
df[df['GrLivArea'] < lower_bround]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 81 columns]

# %%
#이상치 확인
df_outlier_area = df[df['GrLivArea'] > upper_bround]

# %%
df_outlier_area[['GrLivArea','SalePrice','OverallQual','Neighborhood']]
# Out:
#       GrLivArea  SalePrice  OverallQual Neighborhood
# 58         2945     438780           10      StoneBr
# 118        3222     320000            7      SawyerW
# 185        3608     475000           10      OldTown
# 197        3112     235000            8        NAmes
# 231        2794     403000            8      NoRidge
# 304        3493     295000            7      OldTown
# 324        2978     242000            7        NAmes
# 496        3228     430000            8      NoRidge
# 523        4676     184750           10      Edwards
# 583        2775     325000           10      OldTown
# 608        3194     359100            8      Crawfor
# 635        3395     200000            6        SWISU
# 691        4316     755000           10      NoRidge
# 769        3279     538000            8      StoneBr
# 798        3140     485000            9      NridgHt
# 803        2822     582933            9      NridgHt
# 961        2872     272000            6       NWAmes
# 1024       2898     287000            8       Timber
# 1031       3082     197000            7        SWISU
# 1046       2868     556581            9      StoneBr
# 1142       2828     424870            8      CollgCr
# 1169       3627     625000           10      NoRidge
# 1173       3086     200500            5      ClearCr
# 1175       2872     285000            8      NoRidge
# 1182       4476     745000           10      NoRidge
# 1268       3447     381000            8      Crawfor
# 1298       5642     160000           10      Edwards
# 1312       2810     302000            8      NoRidge
# 1328       2792     256000            6      OldTown
# 1353       3238     410000            8      NoRidge
# 1386       2784     250000            7       NWAmes

# %% [markdown]
# ### 문제5 이상치 살펴보기

# %%
df2 = df.copy()

# %%
df_outlier_area
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 58      59          60       RL         66.0    13682   Pave   NaN      IR2
# 118    119          60       RL         90.0    12376   Pave   NaN      Reg
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 231    232          60       RL        174.0    15138   Pave   NaN      IR1
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 324    325          80       RL         96.0    11275   Pave   NaN      Reg
# 496    497          20       RL          NaN    12692   Pave   NaN      IR1
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 608    609          70       RL         78.0    12168   Pave   NaN      Reg
# 635    636         190       RH         60.0    10896   Pave  Pave      Reg
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 798    799          60       RL        104.0    13518   Pave   NaN      Reg
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 961    962          60       RL          NaN    12227   Pave   NaN      IR1
# 1024  1025          20       RL          NaN    15498   Pave   NaN      IR1
# 1031  1032          75       RL        102.0    15863   Pave   NaN      Reg
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1142  1143          60       RL         77.0     9965   Pave   NaN      Reg
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1173  1174          50       RL        138.0    18030   Pave   NaN      IR1
# 1175  1176          50       RL         85.0    10678   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1268  1269          50       RL          NaN    14100   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1312  1313          60       RL          NaN     9572   Pave   NaN      IR1
# 1328  1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 1353  1354          50       RL         56.0    14720   Pave   NaN      IR1
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 58           HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 118          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 185          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 231          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 304          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 324          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 496          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 523          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 583          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 608          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 635          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 798          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 961          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1024         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1031         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1142         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1173         Bnk    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1175         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# 1268         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd    NaN         NaN       0
# 1312         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1328         Lvl    AllPub  ...        0    NaN  MnPrv        Shed    1150
# 1353         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1386         Lvl    AllPub  ...      519     Fa  MnPrv        TenC    2000
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 58       10   2006       New        Partial     438780
# 118       5   2010        WD         Normal     320000
# 185       6   2006        WD         Normal     475000
# 197       3   2006        WD        Abnorml     235000
# 231       7   2009        WD         Normal     403000
# 304       5   2008        WD         Normal     295000
# 324       6   2010        WD         Normal     242000
# 496       5   2007        WD         Normal     430000
# 523      10   2007       New        Partial     184750
# 583       7   2008        WD         Normal     325000
# 608       9   2007        WD         Alloca     359100
# 635       3   2007        WD        Abnorml     200000
# 691       1   2007        WD         Normal     755000
# 769       6   2010        WD         Normal     538000
# 798       7   2009       New        Partial     485000
# 803       1   2009       New        Partial     582933
# 961       7   2008        WD         Normal     272000
# 1024      5   2008       COD        Abnorml     287000
# 1031      8   2009        WD         Normal     197000
# 1046      7   2006       New        Partial     556581
# 1142      4   2007       New        Partial     424870
# 1169      7   2006        WD         Normal     625000
# 1173      3   2007        WD         Normal     200500
# 1175      4   2007        WD         Normal     285000
# 1182      7   2007        WD        Abnorml     745000
# 1268      5   2008        WD         Normal     381000
# 1298      1   2008       New        Partial     160000
# 1312      6   2007        WD         Normal     302000
# 1328      6   2008        WD         Normal     256000
# 1353      3   2010        WD         Normal     410000
# 1386      7   2006        WD         Normal     250000
#
# [31 rows x 81 columns]

# %%
df_outlier_area[['GrLivArea','SalePrice','OverallQual','Neighborhood']]
# Out:
#       GrLivArea  SalePrice  OverallQual Neighborhood
# 58         2945     438780           10      StoneBr
# 118        3222     320000            7      SawyerW
# 185        3608     475000           10      OldTown
# 197        3112     235000            8        NAmes
# 231        2794     403000            8      NoRidge
# 304        3493     295000            7      OldTown
# 324        2978     242000            7        NAmes
# 496        3228     430000            8      NoRidge
# 523        4676     184750           10      Edwards
# 583        2775     325000           10      OldTown
# 608        3194     359100            8      Crawfor
# 635        3395     200000            6        SWISU
# 691        4316     755000           10      NoRidge
# 769        3279     538000            8      StoneBr
# 798        3140     485000            9      NridgHt
# 803        2822     582933            9      NridgHt
# 961        2872     272000            6       NWAmes
# 1024       2898     287000            8       Timber
# 1031       3082     197000            7        SWISU
# 1046       2868     556581            9      StoneBr
# 1142       2828     424870            8      CollgCr
# 1169       3627     625000           10      NoRidge
# 1173       3086     200500            5      ClearCr
# 1175       2872     285000            8      NoRidge
# 1182       4476     745000           10      NoRidge
# 1268       3447     381000            8      Crawfor
# 1298       5642     160000           10      Edwards
# 1312       2810     302000            8      NoRidge
# 1328       2792     256000            6      OldTown
# 1353       3238     410000            8      NoRidge
# 1386       2784     250000            7       NWAmes

# %%
g = df_outlier_area['OverallQual'] < df_outlier_area['OverallQual'].mean()
r  = df_outlier_area['GrLivArea'] > df_outlier_area['GrLivArea'].mean()

# %%
# 평균보다 품질 점수도 낮고 평균보다 크기간 큰 집
df_outlier_area[g & r]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 635    636         190       RH         60.0    10896   Pave  Pave      Reg
# 1268  1269          50       RL          NaN    14100   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 304          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 635          Bnk    AllPub  ...        0    NaN   NaN         NaN       0
# 1268         Lvl    AllPub  ...        0    NaN  GdWo         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 304       5   2008        WD         Normal     295000
# 635       3   2007        WD        Abnorml     200000
# 1268      5   2008        WD         Normal     381000
#
# [3 rows x 81 columns]

# %% [markdown]
# ### 문제6 이상치 처리 전략1 제거(drop)

# %%
df_clean_drop = df.copy()

# %%
df_clean_drop['GarageArea']
# Out:
# 0       548
# 1       460
# 2       608
# 3       642
# 4       836
#        ...
# 1455    460
# 1456    500
# 1457    252
# 1458    240
# 1459    276
# Name: GarageArea, Length: 1460, dtype: int64

# %%
GLA_IQR = df_clean_drop["GrLivArea"].describe()
GLA_IQR
# Out:
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64

# %%
GLA_Q1 = GLA_IQR['25%']
GLA_Q3 = GLA_IQR['75%']
GLA_IQRs = GLA_Q3-GLA_Q1

# %%
df_clean_drop= df_clean_drop.drop(df_outlier_area.index)

# %%
# 행 개수 비교
print(len(df2))
print(len(df_clean_drop))
# Out:
# 1460
# 1429

# %%
# 평균비교
print(df2['GrLivArea'].mean())
print(df_clean_drop['GrLivArea'].mean())
# Out:
# 1515.463698630137
# 1476.7515745276417

# %%
# 표준편차 비교
print(df2['GrLivArea'].std())
print(df_clean_drop['GrLivArea'].std())
# Out:
# 525.4803834232025
# 449.9280558805569

# %% [markdown]
# ### 문제7 이상치 처리 전략2 - 클리핑(원저라이징)

# %%
df_clip = df.copy()

# %%
maxmun = upper_bround

# %%
df_clip.loc[df_clip['GrLivArea'] > maxmun, 'GrLivArea'] =maxmun
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8324\2476764958.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2747.625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_clip.loc[df_clip['GrLivArea'] > maxmun, 'GrLivArea'] =maxmun

# %%
df_clip['GrLivArea'].max()
# Out:
# np.float64(2747.625)

# %%
# 클리핑 전
plt.figure()
df['GrLivArea'].plot(kind='box')
plt.show()

# %%
# 클리핑 후
plt.figure()
df_clip['GrLivArea'].plot(kind='box')
plt.show()

# %% [markdown]
# ### 이상치 제거
# * 장점
#     * 간단하다,통계가 명확해진다
# * 단점
#     * 데이터가 손실, 분포 왜곡 가능성이 있다.
# ### 클리핑
# * 장점
#     * 데이터 손실이 방지, 분포 안정화
# * 단점
#     * 데이터 인위성,편향 발생 가능성이 있다.

# %% [markdown]
# ### 문제8 이상치 처리 후 SalePrice 영향

# %%
#원본
print(df['SalePrice'].mean())
print(df['SalePrice'].std())

plt.figure()
sns.lmplot(data=df,x='GrLivArea',y='SalePrice',height = 4.5, aspect=1.2 )
plt.show()
# Out:
# 180921.19589041095
# 79442.50288288662

# %%
# drop data
print(df_clean_drop['SalePrice'].mean())
print(df_clean_drop['SalePrice'].std())

plt.figure()
sns.lmplot(data=df_clean_drop,x='GrLivArea',y='SalePrice',height = 4.5, aspect=1.2 )
plt.show()
# Out:
# 176714.08817354793
# 71254.16981785695

# %%
# 클리핑 데이터
print(df_clip['SalePrice'].mean())
print(df_clip['SalePrice'].std())

plt.figure()
sns.lmplot(data=df_clip,x='GrLivArea',y='SalePrice',height = 4.5, aspect=1.2 )
plt.show()
# Out:
# 180921.19589041095
# 79442.50288288662

# %% [markdown]
# 만약 '일반적인 중간 가격대 주택의 시세 예측'을 목표로 하는 모델이라면 어떤 버전(df/df_clean_drop/df_clip)을 쓰는 게 적절하다고 생각하시나요?
# * df_drop을 쓰는것이 적절하다고 생각한다.

# %% [markdown]
# ### 문제9 다변량 관점의 이상치

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
a = df[(df['GrLivArea'] > maxmun) & (df['SalePrice'] < df['SalePrice'].mean())]

# %%
plt.figure()
sns.lmplot(data=df,x='GrLivArea',y='SalePrice',height = 4.5, aspect=1.2 )
plt.show()

# %% [markdown]
# 이런 집은 어떤 의미일 수 있는지 해석을 적으세요
# * 이런 집은 집의 크기는 크지만 선호가 낮아서 가격이 평균 이하로 형성되어있는 것을 알 수 있다.

# %% [markdown]
# 문제10 최종 의사결정 제안서
# * 1,일반적인 중간 가격대 주택의 시세예측 모델이라면 이상치를 제거하는게 맞다고 생각합니다. 왜냐면 평균적인 집 가격을 구할라고 하는데 이상치가 포함되면 평균 가격이 급격히 상승하거나 하락 할 수 있기 떄문입니다.
# * 2, 초고가 주택까지 정확히 예측하는 모델이라면 이상치를 포함하면서 iqr의 최대값 이상만 모아서 평균을 구하는 모델을 만드는 것도 방법이라고 생각합니다.
# * 3, 저는 초고가 주택 시세를 예측하는 모델을 만들어서 접근하는 것이 좋은 방법이라고 생각합니다.

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]
