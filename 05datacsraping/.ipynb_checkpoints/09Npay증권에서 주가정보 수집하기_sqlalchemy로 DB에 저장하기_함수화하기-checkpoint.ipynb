# %% [markdown]
# # 09Npay증권에서 주가정보 수집하기_sqlalchemy로 DB에 저장하기_함수화하기

# %%
import re
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine, text
import pymysql
import os
from datetime import datetime
from dbio import load_data, to_db
# Out:
# root

# %% [markdown]
# # dbio를 이용해서 DB에서 데이터 불러오기

# %%
data = load_data("stock_info_20251021","stock_company_list20251021")

# %%
data
# Out:
#       증권종류       회사명    종목코드                   업종                 주요제품  \
# 0     유가증권      명인제약  317450              의약품 제조업              의약품 제조업
# 1      코스닥  KB제33호스팩  0072Z0           금융 지원 서비스업           금융 지원 서비스업
# 2      코스닥   삼성스팩11호  0071M0           금융 지원 서비스업           금융 지원 서비스업
# 3      코스닥    에스투더블유  488280       소프트웨어 개발 및 공급업       소프트웨어 개발 및 공급업
# 4      코스닥        오아  342870    가전제품 및 정보통신장비 소매업    가전제품 및 정보통신장비 소매업
# ...    ...       ...     ...                  ...                  ...
# 2758  유가증권      유한양행  000100              의약품 제조업              의약품 제조업
# 2759  유가증권    CJ대한통운  000120            도로 화물 운송업            도로 화물 운송업
# 2760  유가증권        경방  000050               종합 소매업               종합 소매업
# 2761  유가증권     유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업  회사 본부 및 경영 컨설팅 서비스업
# 2762  유가증권  한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업    연료용 가스 제조 및 배관공급업
#
#              상장일  결산일   대표자명                          홈페이지     지역
# 0     2025-10-01  12월    이행명    http://www.myunginph.co.kr    경기도
# 1     2025-09-30  12월    박성원                            없음  서울특별시
# 2     2025-09-30  12월    문소연                            없음  서울특별시
# 3     2025-09-19  12월    서상덕               http://s2w.inc/    경기도
# 4     2025-09-09  12월    김상무       http://www.oa-world.com  서울특별시
# ...          ...  ...    ...                           ...    ...
# 2758  1962-11-01  12월  대표이..        http://www.yuhan.co.kr  서울특별시
# 2759  1956-07-02  12월  신영수..    http://www.cjlogistics.com  서울특별시
# 2760  1956-03-03  12월  김준,..    http://www.kyungbang.co.kr  서울특별시
# 2761  1956-03-03  12월    송영규  http://www.eusu-holdings.com  서울특별시
# 2762  1956-03-03  12월    조원국  http://www.hhic-holdings.com    경기도
#
# [2763 rows x 10 columns]

# %% [markdown]
# # sqlalchemy와  pymysql로 MySQL에 데이터프레임 저장하기

# %%
# sqlalchemy and pymysql 설치하는 법

# %%
# !pip install SQLAlchemy PyMySQL
# Out:
# Requirement already satisfied: SQLAlchemy in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (2.0.44)
# Requirement already satisfied: PyMySQL in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (1.1.2)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from SQLAlchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from SQLAlchemy) (4.14.1)

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# # sqlalchemy 로 DB 접속하기

# %%
df =pd.read_sql("member", con=conn)
df
# Out:
#   mem_id mem_name  mem_number addr phone(1)  phone(2)  height debut_date
# 0    APN     에이핑크           6   경기      031  77777777     164 2011-02-10
# 1    BLK     블랙핑크           4   경남      055  22222222     163 2016-08-08
# 2    GRL     소녀시대           8   서울       02  44444444     168 2007-08-02
# 3    ITZ       잇지           5   경남     None      None     167 2019-02-12
# 4    MMU      마마무           4   전남      061  99999999     165 2014-06-19
# 5    OMY     오마이걸           7   서울     None      None     160 2015-04-21
# 6    RED     레드벨벳           4   경북      054  55555555     161 2014-08-01
# 7    SPC     우주소녀          13   서울       02  88888888     162 2016-02-25
# 8    TWC     트와이스           9   서울       02  11111111     167 2015-10-19
# 9    WMN     여자친구           6   경기      031  33333333     166 2015-01-15

# %%
data
# Out:
#       증권종류       회사명    종목코드                   업종                 주요제품  \
# 0     유가증권      명인제약  317450              의약품 제조업              의약품 제조업
# 1      코스닥  KB제33호스팩  0072Z0           금융 지원 서비스업           금융 지원 서비스업
# 2      코스닥   삼성스팩11호  0071M0           금융 지원 서비스업           금융 지원 서비스업
# 3      코스닥    에스투더블유  488280       소프트웨어 개발 및 공급업       소프트웨어 개발 및 공급업
# 4      코스닥        오아  342870    가전제품 및 정보통신장비 소매업    가전제품 및 정보통신장비 소매업
# ...    ...       ...     ...                  ...                  ...
# 2758  유가증권      유한양행  000100              의약품 제조업              의약품 제조업
# 2759  유가증권    CJ대한통운  000120            도로 화물 운송업            도로 화물 운송업
# 2760  유가증권        경방  000050               종합 소매업               종합 소매업
# 2761  유가증권     유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업  회사 본부 및 경영 컨설팅 서비스업
# 2762  유가증권  한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업    연료용 가스 제조 및 배관공급업
#
#              상장일  결산일   대표자명                          홈페이지     지역
# 0     2025-10-01  12월    이행명    http://www.myunginph.co.kr    경기도
# 1     2025-09-30  12월    박성원                            없음  서울특별시
# 2     2025-09-30  12월    문소연                            없음  서울특별시
# 3     2025-09-19  12월    서상덕               http://s2w.inc/    경기도
# 4     2025-09-09  12월    김상무       http://www.oa-world.com  서울특별시
# ...          ...  ...    ...                           ...    ...
# 2758  1962-11-01  12월  대표이..        http://www.yuhan.co.kr  서울특별시
# 2759  1956-07-02  12월  신영수..    http://www.cjlogistics.com  서울특별시
# 2760  1956-03-03  12월  김준,..    http://www.kyungbang.co.kr  서울특별시
# 2761  1956-03-03  12월    송영규  http://www.eusu-holdings.com  서울특별시
# 2762  1956-03-03  12월    조원국  http://www.hhic-holdings.com    경기도
#
# [2763 rows x 10 columns]

# %%
# 새로운 데이터 데이터베이스에 저장하는 법

# %%
db_id = os.getenv("id")
db_pw = os.getenv("pw")
addr = os.getenv("addr")
port = os.getenv("port")
engine = create_engine(f"mysql+pymysql://{db_id}:{db_pw}@{addr}:{port}/stock_info_20251021")
conn = engine.connect()

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/stock_info_20251021")
conn = engine.connect()

# %%
data.to_sql("stock_company_list20251021",con=conn, if_exists="replace", index = False)
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.to_sql("stock_company_list20251021",con=conn, if_exists="replace", index = False)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:3106, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2908 """
#    2909 Write records stored in a DataFrame to a SQL database.
#    2910
#    (...)
#    3102 [(1,), (None,), (2,)]
#    3103 """  # noqa: E501
#    3104 from pandas.io import sql
# -> 3106 return sql.to_sql(
#    3107     self,
#    3108     name,
#    3109     con,
#    3110     schema=schema,
#    3111     if_exists=if_exists,
#    3112     index=index,
#    3113     index_label=index_label,
#    3114     chunksize=chunksize,
#    3115     dtype=dtype,
#    3116     method=method,
#    3117 )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\sql.py:1657, in SQLDatabase.__exit__(self, *args)
#    1655 def __exit__(self, *args) -> None:
#    1656     if not self.returns_generator:
# -> 1657         self.exit_stack.close()
#
# File ~\miniforge3\envs\fintech\lib\contextlib.py:540, in ExitStack.close(self)
#     538 def close(self):
#     539     """Immediately unwind the context stack."""
# --> 540     self.__exit__(None, None, None)
#
# File ~\miniforge3\envs\fintech\lib\contextlib.py:532, in ExitStack.__exit__(self, *exc_details)
#     528 try:
#     529     # bare "raise exc_details[1]" replaces our carefully
#     530     # set-up context
#     531     fixed_ctx = exc_details[1].__context__
# --> 532     raise exc_details[1]
#     533 except BaseException:
#     534     exc_details[1].__context__ = fixed_ctx
#
# File ~\miniforge3\envs\fintech\lib\contextlib.py:517, in ExitStack.__exit__(self, *exc_details)
#     515 assert is_sync
#     516 try:
# --> 517     if cb(*exc_details):
#     518         suppressed_exc = True
#     519         pending_raise = False
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\util.py:149, in TransactionalContext.__exit__(self, type_, value, traceback)
#     147     with util.safe_reraise():
#     148         if self._rollback_can_be_called():
# --> 149             self.rollback()
#     150 finally:
#     151     if not out_of_band_exit:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\util.py:145, in TransactionalContext.__exit__(self, type_, value, traceback)
#     143 if type_ is None and self._transaction_is_active():
#     144     try:
# --> 145         self.commit()
#     146     except:
#     147         with util.safe_reraise():
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:2632, in Transaction.commit(self)
#    2616 """Commit this :class:`.Transaction`.
#    2617
#    2618 The implementation of this may vary based on the type of transaction in
#    (...)
#    2629
#    2630 """
#    2631 try:
# -> 2632     self._do_commit()
#    2633 finally:
#    2634     assert not self.is_active
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:2737, in RootTransaction._do_commit(self)
#    2734 assert self.connection._transaction is self
#    2736 try:
# -> 2737     self._connection_commit_impl()
#    2738 finally:
#    2739     # whether or not commit succeeds, cancel any
#    2740     # nested transactions, make this transaction "inactive"
#    2741     # and remove it as a reset agent
#    2742     if self.connection._nested_transaction:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:2708, in RootTransaction._connection_commit_impl(self)
#    2707 def _connection_commit_impl(self) -> None:
# -> 2708     self.connection._commit_impl()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:1147, in Connection._commit_impl(self)
#    1145     self.engine.dialect.do_commit(self.connection)
#    1146 except BaseException as e:
# -> 1147     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:2358, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2356     else:
#    2357         assert exc_info[1] is not None
# -> 2358         raise exc_info[1].with_traceback(exc_info[2])
#    2359 finally:
#    2360     del self._reentrant_error
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:1145, in Connection._commit_impl(self)
#    1143         self._log_info("COMMIT")
#    1144 try:
# -> 1145     self.engine.dialect.do_commit(self.connection)
#    1146 except BaseException as e:
#    1147     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:581, in Connection.connection(self)
#     579 if self._dbapi_connection is None:
#     580     try:
# --> 581         return self._revalidate_connection()
#     582     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     583         raise
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:673, in Connection._revalidate_connection(self)
#     671 if self.__can_reconnect and self.invalidated:
#     672     if self._transaction is not None:
# --> 673         self._invalid_transaction()
#     674     self._dbapi_connection = self.engine.raw_connection()
#     675     return self._dbapi_connection
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:663, in Connection._invalid_transaction(self)
#     662 def _invalid_transaction(self) -> NoReturn:
# --> 663     raise exc.PendingRollbackError(
#     664         "Can't reconnect until invalid %stransaction is rolled "
#     665         "back.  Please rollback() fully before proceeding"
#     666         % ("savepoint " if self._nested_transaction is not None else ""),
#     667         code="8s2b",
#     668     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %% [markdown]
# # DB에서 상장회사 정보 불러와서 Npay 증권 주가 정보 수집하기

# %%
data = pd.read_sql("stock_company_list20251021", con=conn)
data
# Out:
#       증권종류       회사명    종목코드                   업종                 주요제품  \
# 0     유가증권      명인제약  317450              의약품 제조업              의약품 제조업
# 1      코스닥  KB제33호스팩  0072Z0           금융 지원 서비스업           금융 지원 서비스업
# 2      코스닥   삼성스팩11호  0071M0           금융 지원 서비스업           금융 지원 서비스업
# 3      코스닥    에스투더블유  488280       소프트웨어 개발 및 공급업       소프트웨어 개발 및 공급업
# 4      코스닥        오아  342870    가전제품 및 정보통신장비 소매업    가전제품 및 정보통신장비 소매업
# ...    ...       ...     ...                  ...                  ...
# 2758  유가증권      유한양행  000100              의약품 제조업              의약품 제조업
# 2759  유가증권    CJ대한통운  000120            도로 화물 운송업            도로 화물 운송업
# 2760  유가증권        경방  000050               종합 소매업               종합 소매업
# 2761  유가증권     유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업  회사 본부 및 경영 컨설팅 서비스업
# 2762  유가증권  한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업    연료용 가스 제조 및 배관공급업
#
#              상장일  결산일   대표자명                          홈페이지     지역
# 0     2025-10-01  12월    이행명    http://www.myunginph.co.kr    경기도
# 1     2025-09-30  12월    박성원                            없음  서울특별시
# 2     2025-09-30  12월    문소연                            없음  서울특별시
# 3     2025-09-19  12월    서상덕               http://s2w.inc/    경기도
# 4     2025-09-09  12월    김상무       http://www.oa-world.com  서울특별시
# ...          ...  ...    ...                           ...    ...
# 2758  1962-11-01  12월  대표이..        http://www.yuhan.co.kr  서울특별시
# 2759  1956-07-02  12월  신영수..    http://www.cjlogistics.com  서울특별시
# 2760  1956-03-03  12월  김준,..    http://www.kyungbang.co.kr  서울특별시
# 2761  1956-03-03  12월    송영규  http://www.eusu-holdings.com  서울특별시
# 2762  1956-03-03  12월    조원국  http://www.hhic-holdings.com    경기도
#
# [2763 rows x 10 columns]

# %% [markdown]
# # 주가 정보 수집코드를 함수화, 1개데이터를 바로 DB 저장

# %%
for idx,code in enumerate(data['종목코드']):
    print(f"{idx+1}/{len(data['종목코드'])}데이터 수집중",end="\r")
    try:
        int(code[:3])
        naver_stock(code)
    except Exception as e:
        continue
# Out:
# 2763/2763데이터 수집중

# %%
today = datetime.today()
today =f"{today.year}{today.month}{today.day}"
today
# Out:
# '20251022'

# %%
def naber_stock(code):
    result = {}
    cols = ["수집일","종목명","종목코드","현재가","변동금액","변동률","전일가","시가","고가","상한가","저가","하한가","거래량"]
    
    today = datetime.today()
    today =f"{today.year}{today.month}{today.day}"
    
    int(code[:3])
    url = f"https://finance.naver.com/item/main.naver?code={code}"
    r = requests.get(url)
    soup = bs(r.content,'lxml')


    # 종목명
    stock_name = soup.select_one('dl.blind>dd:nth-child(3)').text.split()[1]
    # 현재가
    today_price = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[1]
    #전일

    change = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[3:5]
    change = -int(change[1].replace(',','')) if change[0] == '하락'else int(change[1].replace(',',''))
    change
    #변동률
    percent = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[5:]
    percent ="".join(percent)
    percent = percent.replace("플러스","").replace("마이너스","-").replace("퍼센트","%")
    #전일가
    yester_price = int(soup.select_one('#middle > dl > dd:nth-child(6)').text.split()[1].replace(",",""))
    #시가
    opening_price =int(soup.select_one('#middle > dl > dd:nth-child(7)').text.split()[1].replace(",",""))
    #고가
    hi = int(soup.select_one('#middle > dl > dd:nth-child(8)').text.split()[1].replace(",",""))
    #상한가
    top = int(soup.select_one('#middle > dl > dd:nth-child(9)').text.split()[1].replace(",",""))
    #저가
    low = int(soup.select_one('#middle > dl > dd:nth-child(10)').text.split()[1].replace(",",""))
    #하한가
    bottom = int(soup.select_one('#middle > dl > dd:nth-child(11)').text.split()[1].replace(",",""))
    #거래량
    volum = int(soup.select_one('#middle > dl > dd:nth-child(12)').text.split()[1].replace(",",""))

    values = (today,stock_name,code,today_price,change,percent,yester_price,opening_price,hi,
     top,low,bottom,volum)

    for key,value in zip(cols,values):
        result.setdefault(key,[]).append(value)
            
    df=pd.DataFrame(result)
    
    to_db("stock_info_20251021",f"stock_price_{today[:4]}",df)
    
    return print(f"{stock_name} 주가정보 수집 완료",end="\r")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 54
#      51     to_db("stock_info_20251021","stock_price_{today.year}",df)
#      52     return print(f"{stock_name} 주가정보 수집 완료",end="\r")
# ---> 54 df
#
# NameError: name 'df' is not defined

# %%
result = {}
cols = ["종목명","종목코드","현재가","변동금액","변동률","전일가","시가","고가","상한가","저가","하한가","거래량"]

for idx,code in enumerate(data['종목코드']):
    try:
        int(code[:3])
        print(f"{idx}/{len(data['종목코드'])} 주가정보 수집 중",end="\r")
        url = f"https://finance.naver.com/item/main.naver?code={code}"
        r = requests.get(url)
        soup = bs(r.content,'lxml')


        # 종목명
        stock_name = soup.select_one('dl.blind>dd:nth-child(3)').text.split()[1]
        # 현재가
        today_price = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[1]
        #전일

        change = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[3:5]
        change = -int(change[1].replace(',','')) if change[0] == '하락'else int(change[1].replace(',',''))
        change
        #변동률
        percent = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[5:]
        percent ="".join(percent)
        percent = percent.replace("플러스","").replace("마이너스","-").replace("퍼센트","%")
        #전일가
        yester_price = int(soup.select_one('#middle > dl > dd:nth-child(6)').text.split()[1].replace(",",""))
        #시가
        opening_price =int(soup.select_one('#middle > dl > dd:nth-child(7)').text.split()[1].replace(",",""))
        #고가
        hi = int(soup.select_one('#middle > dl > dd:nth-child(8)').text.split()[1].replace(",",""))
        #상한가
        top = int(soup.select_one('#middle > dl > dd:nth-child(9)').text.split()[1].replace(",",""))
        #저가
        low = int(soup.select_one('#middle > dl > dd:nth-child(10)').text.split()[1].replace(",",""))
        #하한가
        bottom = int(soup.select_one('#middle > dl > dd:nth-child(11)').text.split()[1].replace(",",""))
        #거래량
        volum = int(soup.select_one('#middle > dl > dd:nth-child(12)').text.split()[1].replace(",",""))

        values = (stock_name,code,today_price,change,percent,yester_price,opening_price,hi,
         top,low,bottom,volum)

        for key,value in zip(cols,values):
            result.setdefault(key,[]).append(value)

        time.sleep(3)
    except:
        continue
df=pd.DataFrame(result)
df
# Out:
# 23/2763 주가정보 수집 중

# %% [markdown]
# 종목명,현재가,변동금액,변동률,전일가,고가,상한가,저가,하한가,거래량

# %%
# 종목명
stock_name = soup.select_one('dl.blind>dd:nth-child(3)').text.split()[1]

# %%
# 현재가
today_price = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[1]

# %%
#전일
change = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[3:5]
change = -int(change[1].replace(',','')) if change[0] == '하락'else int(change[1].replace(',',''))
change
# Out:
# 1250

# %%
#변동률
percent = soup.select_one('#middle > dl > dd:nth-child(5)').text.split()[5:]
percent ="".join(percent)
percent = percent.replace("플러스","").replace("마이너스","-").replace("퍼센트","%")
# Out:
# '0.49%'

# %%
#시가
soup.select_one('#middle > dl > dd:nth-child(7)')
# Out:
# <dd>시가 265,000</dd>

# %%
#전일가
yester_price = int(soup.select_one('#middle > dl > dd:nth-child(6)').text.split()[1].replace(",",""))

# %%
#시가
opening_price = soup.select_one('#middle > dl > dd:nth-child(7)').text.split()[1].replace(",","")

# %%
#고가
hi = soup.select_one('#middle > dl > dd:nth-child(8)').text.split()[1].replace(",","")
# Out:
# '265000'

# %%
#상한가
top = soup.select_one('#middle > dl > dd:nth-child(9)').text.split()[1].replace(",","")
# Out:
# '333000'

# %%
#저가
low = soup.select_one('#middle > dl > dd:nth-child(10)').text.split()[1].replace(",","")
# Out:
# '254500'

# %%
#하한가
bottom = soup.select_one('#middle > dl > dd:nth-child(11)').text.split()[1].replace(",","")

# %%
#거래량
volum = int(soup.select_one('#middle > dl > dd:nth-child(12)').text.split()[1].replace(",",""))
# Out:
# '624806'

# %%
table > tbody > tr:nth-child(1) > td:nth-child(3) > span

# %%
#rate_info_nxt > table > tbody > tr:nth-child(1) > td:nth-child(2) > em.no_cha > span.blind

# %%
soup.select_one('tbody')
# Out:
# <tbody>
# <tr><td class="space"></td></tr>
# <tr>
# <td class="left">신한투자증권</td>
# <td><em>86,119</em></td>
# <td class="left">미래에셋증권</td>
# <td><em>59,947</em></td>
# </tr>
# <tr>
# <td class="left"><span class="f_down">제이피모간</span></td>
# <td><em class="f_down">35,617</em></td>
# <td class="left">키움증권</td>
# <td><em>44,112</em></td>
# </tr>
# <tr>
# <td class="left">한화투자증권</td>
# <td><em>33,083</em></td>
# <td class="left">한화투자증권</td>
# <td><em>37,049</em></td>
# </tr>
# <tr>
# <td class="left"><span class="f_down">모간스탠리</span></td>
# <td><em class="f_down">30,030</em></td>
# <td class="left">KB증권</td>
# <td><em>34,180</em></td>
# </tr>
# <tr>
# <td class="left">한국투자증권</td>
# <td><em>29,233</em></td>
# <td class="left">한국투자증권</td>
# <td><em>30,272</em></td>
# </tr>
# </tbody>

# %%
for code in data['종목코드']:
    print(code)
# Out:
# 317450
# 0072Z0
# 0071M0
# 488280
# 342870
# 496320
# 318060
# 397810
# 0044K0
# 0010V0
# 125490
# 0008Z0
# 484590
# 0041B0
# 456160
# 309710
# 0041L0
# 439260
# 468530
# 475230
# 380550
# 484120
# 0004Y0
# 0041J0
# 331740
# 0030R0
# 462310
# 234030
# 0037T0
# 463020
# 388610
# 455180
# 340450
# 474650
# 475430
# 496070
# 287840
# 483650
# 489460
# 424870
# 188040
# 125020
# 376900
# 476040
# 136150
# 459510
# 364950
# 081180
# 448900
# 481070
# 101970
# 462860
# 444530
# 484810
# 098070
# 498390
# 480370
# 031210
# 460870
# 226590
# 393970
# 435570
# 489500
# 479960
# 463480
# 303810
# 475830
# 240550
# 212710
# 064400
# 462980
# 452450
# 482630
# 373160
# 450950
# 096250
# 475460
# 493790
# 478560
# 332190
# 432980
# 387570
# 177900
# 499790
# 487360
# 495810
# 368030
# 176750
# 487720
# 398120
# 476060
# 382150
# 457600
# 484870
# 471820
# 495900
# 492220
# 489480
# 415640
# 489730
# 489210
# 482690
# 459100
# 389680
# 474610
# 466410
# 484130
# 475660
# 413390
# 487830
# 394800
# 464580
# 473980
# 163280
# 475960
# 475560
# 376270
# 475580
# 336680
# 458650
# 488060
# 476710
# 466100
# 044990
# 289930
# 475400
# 457370
# 474170
# 209640
# 465480
# 308430
# 381620
# 351870
# 489790
# 486630
# 464500
# 482680
# 469750
# 461300
# 456070
# 476080
# 478780
# 464280
# 389650
# 431190
# 079900
# 088340
# 482520
# 199480
# 460470
# 460940
# 487570
# 062040
# 481890
# 473950
# 373110
# 478110
# 462870
# 450330
# 462350
# 481850
# 295310
# 266350
