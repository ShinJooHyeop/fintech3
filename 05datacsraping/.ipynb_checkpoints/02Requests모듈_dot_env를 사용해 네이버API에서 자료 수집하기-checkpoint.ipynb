# %% [markdown]
# # 1.requests 모듈
# * HTTP프로토콜을 사용할 수 있게 해주는 모듈
# * 파이썬 기본 모듈인 urlib보다 사용이 편리
# * 따로 설치 필요 pip install requests/ conda install requests

# %% [markdown]
# # 2. Requests 모듈 사용법
# * 1) 모듈 불러오기: import requests
# * 2) url을 변수에 저장
# * 3) url파라미터를 payload라는 변수에 딕셔너리 형태로 저장
#     * payload = {파라미터1 : value, 파라미터2 : value2}
# * 4) headers 도 headers 라는 변수에 딕셔너리 형태로 저장
#     * headers = {파라미터1 : value, 파라미터2 : value2}
# * 5) HTTP요청 보내기 get, osit
#     * get:  r= requests.get(url,params=payload, headers=headers)
#     * psot: r= requests
# * 6) 만들어진 url 확인: print(r.url)
# * 7) 응답코드확인: print(r.status_code)
# * 8) 응답 요서 출력: r.text, r.content, r.json()

# %%
import requests
url = " "
payload = dict()
r = requests.get(url,params=payload)
print(r.url)
print(r.status_code)
response = r.text, r.content, r.json()
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[71], line 4
#       2 url = " "
#       3 payload = dict()
# ----> 4 r = requests.get(url,params=payload)
#       5 print(r.url)
#       6 print(r.status_code)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\sessions.py:484, in Session.prepare_request(self, request)
#     481     auth = get_netrc_auth(request.url)
#     483 p = PreparedRequest()
# --> 484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#     487     files=request.files,
#     488     data=request.data,
#     489     json=request.json,
#     490     headers=merge_setting(
#     491         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     492     ),
#     493     params=merge_setting(request.params, self.params),
#     494     auth=merge_setting(auth, self.auth),
#     495     cookies=merged_cookies,
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#     498 return p
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\models.py:367, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     364 """Prepares the entire request with the given parameters."""
#     366 self.prepare_method(method)
# --> 367 self.prepare_url(url, params)
#     368 self.prepare_headers(headers)
#     369 self.prepare_cookies(cookies)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\models.py:438, in PreparedRequest.prepare_url(self, url, params)
#     435     raise InvalidURL(*e.args)
#     437 if not scheme:
# --> 438     raise MissingSchema(
#     439         f"Invalid URL {url!r}: No scheme supplied. "
#     440         f"Perhaps you meant https://{url}?"
#     441     )
#     443 if not host:
#     444     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '': No scheme supplied. Perhaps you meant https://?

# %%
! conda install requests
# Out:
# Channels:
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
import requests
user_id = os.getenv("user_Id")
user_secret = os.getenv("user_Secret")
url = "https://openapi.naver.com/v1/search/blog"
keyword= '핀테크'
payload = dict(query=  keyword ,display=100,start=1,sort="date")
headers = {'X-Naver-Client-Id' : "","X-Naver-Client-Secret" : ""}
r = requests.get(url,params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
response
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 401
# {'errorMessage': 'Not Exist Client ID : Authentication failed. (인증에 실패했습니다.)',
#  'errorCode': '024'}

# %%
print(type(response))
# Out:
# <class 'dict'>

# %%
response['items']
# Out:
# [{'title': '루민트, 글로벌 협력으로 확장하다',
#   'link': 'https://blog.naver.com/sxnoig/224040826219',
#   'description': '국제 파트너십 강화 루민트는 해외 <b>핀테크</b> 기업들과 협력을 진행 중입니다. 특히 결제 시스템과 데이터 보안 분야에서 협약이 체결되었습니다. 이건 단순한 제휴가 아니라 기술 기반의 실질적 연결입니다.... ',
#   'bloggername': '-',
#   'bloggerlink': 'blog.naver.com/sxnoig',
#   'postdate': '20251014'},
#  {'title': '[케이뱅크 채용] 2026년 케이뱅크 채용연계형 인턴 자소서... ',
#   'link': 'https://blog.naver.com/biographers/224040819512',
#   'description': '따라서 단순히 ‘<b>핀테크</b>가 성장하고 있어서’와 같은 외부적 이유보다는, 케이뱅크만의 서비스·가치·고객 경험 철학에 공감하고, 그것이 본인의 비전과 어떤 방향으로 맞물리는지를 논리적으로 서술해야... ',
#   'bloggername': '자소서 첨삭공방',
#   'bloggerlink': 'blog.naver.com/biographers',
#   'postdate': '20251014'},
#  {'title': '더나은투자 사기 사칭 리딩방 가짜의 온기',
#   'link': 'https://blog.naver.com/slted81266/224039801939',
#   'description': '온기 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/slted81266',
#   'postdate': '20251014'},
#  {'title': '금융 심사의 미래 : 신용점수 vs 소셜 신용 점수',
#   'link': 'https://blog.naver.com/ouoigno361/224040533855',
#   'description': '이런 방식은 아직 국내에서는 본격적으로 도입되지 않았지만, 해외에서는 이미 일부 <b>핀테크</b> 기업들이... <b>핀테크</b> 기술의 발전으로 인해 국내외 다양한 기업들도 유사한 시도를 하고 있으며, 앞으로는 이런 방식이... ',
#   'bloggername': '소비의미학',
#   'bloggerlink': 'blog.naver.com/ouoigno361',
#   'postdate': '20251014'},
#  {'title': '달라진 신용대출 금리 체계와 금융 소비자에게 다가올 주요... ',
#   'link': 'https://blog.naver.com/ggudaofficial/224040799628',
#   'description': '최근에는 FICO 점수 외에도 은행 자체 모델이나 <b>핀테크</b> 기업의 대안 신용평가가 활용되며, 통신료 납부 이력, 공공요금 납부 기록 등 비금융 데이터가 금리 산정에 반영되기도 합니다. 영국은 신용조회기관(CRA)... ',
#   'bloggername': 'GGUDA',
#   'bloggerlink': 'blog.naver.com/ggudaofficial',
#   'postdate': '20251014'},
#  {'title': '넥스볼트 사기 NexVault 로맨스스캠 리딩방 수법 정밀 분석... ',
#   'link': 'https://blog.naver.com/lucifer49329/224040661212',
#   'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': '데이 강민성 변호사',
#   'bloggerlink': 'blog.naver.com/lucifer49329',
#   'postdate': '20251014'},
#  {'title': '리사블룸 사기 lsabbact 사칭 팀미션 가면 뒤의 진짜 얼굴',
#   'link': 'https://blog.naver.com/mongoli62869/224039790424',
#   'description': '얼굴 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/mongoli62869',
#   'postdate': '20251014'},
#  {'title': '2025.10.14 한국 경제 신문 &lt;최근에 쇼핑했던 주식들과 최근... ',
#   'link': 'https://blog.naver.com/haileytax/224040789155',
#   'description': '비자 비자는 페이팔과 같은 이유 푸투 홀딩스 상대적으로 규모가 작은 <b>핀테크</b> 및 투자지주회사 유동성이 낮음 데번 에너지 미국의 대표적인 세일 오일, 천연가스 개발 회사. 고배당주 판둬둬 시가 총액 높은... ',
#   'bloggername': 'Hailey Tax Blog',
#   'bloggerlink': 'blog.naver.com/haileytax',
#   'postdate': '20251014'},
#  {'title': '10월 14일 블록체인 소식',
#   'link': 'https://blog.naver.com/phill_ssing/224040783777',
#   'description': '및 <b>핀테크</b> 전문 기업 두나무의 협력이 AI(인공지능)와 웹3(Web3)를 결합한 새로운 벤처 생태계 구축으로 이어질 것이라는 전망이 나온다. 양사의 파트너십은 단순한 페이 서비스나 자산 관리 연동을 넘어, AI... ',
#   'bloggername': "Phill's 삶 속 이야기",
#   'bloggerlink': 'blog.naver.com/phill_ssing',
#   'postdate': '20251014'},
#  {'title': '변화하는 규제 환경, 2025년 사업자 생존 전략',
#   'link': 'https://blog.naver.com/miracle1024_/224040775902',
#   'description': '특히 새로운 기술을 활용하는 <b>핀테크</b>, 빅데이터 분야의 규제와 감독 체계가 강화되고 있습니다. 높은... 금융 및 혁신 분야 규제 대응 <b>핀테크</b>나 디지털 자산 분야의 사업자는 ‘규제 샌드박스’ 제도를... ',
#   'bloggername': '기업운영자금상담',
#   'bloggerlink': 'blog.naver.com/miracle1024_',
#   'postdate': '20251014'},
#  {'title': '더나은투자 사기 및 리딩방 미끼 경계 가이드 (사칭)',
#   'link': 'https://blog.naver.com/dtive84494/224040773011',
#   'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': '데이 강민성 변호사',
#   'bloggerlink': 'blog.naver.com/dtive84494',
#   'postdate': '20251014'},
#  {'title': '2025년, ‘비은행의 시대’ — 보이지 않는 금융권력이... ',
#   'link': 'https://blog.naver.com/nandahaha_/224040771863',
#   'description': '금리상승 #유동성리스크 #레버리지위험 #DSR강화 #저축은행 #캐피탈사 #보험사 #증권사 #<b>핀테크</b>금융 #대체금융 #현금흐름투자 #금융리스크 #2025경제 #글로벌자금흐름 #리스크관리 #금융분석 #경제인사이트',
#   'bloggername': '발길이 이끄는 대로',
#   'bloggerlink': 'blog.naver.com/nandahaha_',
#   'postdate': '20251014'},
#  {'title': '씨오비 사기 사칭 코인투자 겉만 번지르르한 말들',
#   'link': 'https://blog.naver.com/mongoli62869/224039786745',
#   'description': '말들 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/mongoli62869',
#   'postdate': '20251014'},
#  {'title': '넥스볼트 사기 NexVault 사칭 로맨스스캠 거짓의 포장지',
#   'link': 'https://blog.naver.com/mongoli62869/224039783984',
#   'description': '포장지 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/mongoli62869',
#   'postdate': '20251014'},
#  {'title': '[칼럼] 비밀과 투명성 사이 — 빌더버그 회의, 그리고 글로벌... ',
#   'link': 'https://blog.naver.com/84jojo/224040749131',
#   'description': '새로운 엘리트 구조 ― 기술기업과 중앙은행의 결합 오늘날 빌더버그의 새로운 축은 테크·<b>핀테크</b>·디지털 화폐다. 2019년 회의 명단에는 Google, Microsoft, Santander, Ripple의 파트너 기관 관계자들이... ',
#   'bloggername': '인문학과 블록체인(화폐) 혁명',
#   'bloggerlink': 'blog.naver.com/84jojo',
#   'postdate': '20251014'},
#  {'title': 'Assessing Bank Performance with Operational Researchand... ',
#   'link': 'https://blog.naver.com/blackzelkova/224040745659',
#   'description': '#은행성과평가 #운영연구 #인공지능금융 #데이터포락분석 #효율성측정 #SFA #신경망 #퍼지로직 #유전알고리즘 #하이브리드모델 #AI은행 #<b>핀테크</b>분석 #금융데이터사이언스 #설명가능AI... ',
#   'bloggername': '왕십리 살쾡이',
#   'bloggerlink': 'blog.naver.com/blackzelkova',
#   'postdate': '20251014'},
#  {'title': '신용카드한도 백화점 상품권현금화 할부 결제 이용 현황',
#   'link': 'https://blog.naver.com/hdhddhddd/224040746142',
#   'description': '<b>핀테크</b>는 가상통화부터 부동산까지 다양한 영역에 적용되고 있다. 어려운 상황에서도 경제적 안정을 찾는 건 위험한 샛길에서 벗어나 안전한 대로로 가는 것과 같다. 그러니 앞으로도 신중하게 차근차근... ',
#   'bloggername': '딩딩이의 먹방 만년 다이어리',
#   'bloggerlink': 'blog.naver.com/hdhddhddd',
#   'postdate': '20251014'},
#  {'title': 'Global Vicke 사기 투자 리딩방 주의해야 할 이유 (사칭)',
#   'link': 'https://blog.naver.com/crnivorous20772/224040742194',
#   'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': '데이 강민성 변호사',
#   'bloggerlink': 'blog.naver.com/crnivorous20772',
#   'postdate': '20251014'},
#  {'title': 'AZ financial 사기 사칭 투자플랫폼 완벽은 가장 안전한 가면',
#   'link': 'https://blog.naver.com/mongoli62869/224039777421',
#   'description': '가면 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/mongoli62869',
#   'postdate': '20251014'},
#  {'title': '네이버 주가 전망, 지금 사야 할까? 꼭 알아야 할 3가지',
#   'link': 'https://blog.naver.com/kangho1119/224040540873',
#   'description': '최근에 네이버가 <b>핀테크</b> 회사 두나무와 결합한다는 뉴스 봤죠? 표면적으로는 &quot;웹3 시대를 대비한다&quot;는... #NAVER #네이버 #035420 #주식투자 #포털사이트 #커머스 #목표주가 #투자분석 #<b>핀테크</b> #BUY',
#   'bloggername': '머니플러스',
#   'bloggerlink': 'blog.naver.com/kangho1119',
#   'postdate': '20251014'},
#  {'title': '한국의 인기 직업 트렌드 — MZ세대가 선택한 미래형 커리어',
#   'link': 'https://blog.naver.com/chleogh40/224040743150',
#   'description': '소프트웨어 엔지니어, AI 개발자, 데이터 분석가 등의 수요가 폭발적으로 증가하고 있으며, <b>핀테크</b>(Fintech), 블록체인, 사이버 보안, 스타트업 기술 개발 분야에서도 인재 경쟁이 치열합니다. 삼성, 네이버... ',
#   'bloggername': '도날드트럼프',
#   'bloggerlink': 'blog.naver.com/chleogh40',
#   'postdate': '20251014'},
#  {'title': '“파라과이를 남미의 실리콘밸리로” - 가브리엘라 시빌리스... ',
#   'link': 'https://blog.naver.com/ny-keith/224040434315',
#   'description': '<b>핀테크</b>, 에듀테크, 그린테크 분야에서 신생 기업들이 속속 등장하며, ‘라틴테크 신흥 허브’ 로 주목받고 있다. 가브리엘라는 “파라과이가 작다고 해서 가능성이 작은 건 아니다. 실리콘밸리도 처음엔... ',
#   'bloggername': '행복 메신저',
#   'bloggerlink': 'blog.naver.com/ny-keith',
#   'postdate': '20251014'},
#  {'title': 'Global Vicke 사기 사칭 리딩방 완벽해 보여야만 하는 이유',
#   'link': 'https://blog.naver.com/mongoli62869/224039772596',
#   'description': '이유 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/mongoli62869',
#   'postdate': '20251014'},
#  {'title': '로빈후드 (HOOD) 경제적 해자',
#   'link': 'https://blog.naver.com/hadu_zlz/224040731265',
#   'description': '로빈후드(Robinhood)는 미국 최대 <b>핀테크</b> 기반 투자·거래 플랫폼으로서, 젊은 고객층의 충성도를 바탕으로 금융 슈퍼앱 전략을 통해 혁신적 성장세를 보이고 있음. 2025년 2분기에는 3분기 연속 흑자를... ',
#   'bloggername': '헤이지듀드',
#   'bloggerlink': 'blog.naver.com/hadu_zlz',
#   'postdate': '20251014'},
#  {'title': '[UPPITY 머니레터] 베트남, 글로벌 최저한세(15%) 도입 — 한국... ',
#   'link': 'https://blog.naver.com/myungsu0912/224040731088',
#   'description': '<b>핀테크</b>/결제: 스테이블코인 송금 확대 → 글로벌 간편결제, 거래소와 제휴 가속(예: 일본 페이페이, 바이낸스 재팬 지분 40% 인수).  기업 LG에너지솔루션: 3Q 영업이익 6,013억 원(+34.1% YoY) — ESS 수요 호조.... ',
#   'bloggername': '책 속의 명수씨',
#   'bloggerlink': 'blog.naver.com/myungsu0912',
#   'postdate': '20251014'},
#  {'title': '가전제품 담보대출, 언제까지 가능할까?',
#   'link': 'https://blog.naver.com/miharu8282/224040725372',
#   'description': '최근에는 <b>핀테크</b> 기업에서도 빠르고 손쉽게 대출이 가능합니다. 3.모바일 앱 대출: 다양한 금융 앱을 통해 신용 분석을 거쳐 소액 대출을 받아볼 수 있습니다. 이는 빠른 승인과 간단한 절차가 특징입니다.... ',
#   'bloggername': '엄마의 돈공부 책공부',
#   'bloggerlink': 'blog.naver.com/miharu8282',
#   'postdate': '20251014'},
#  {'title': '신용카드한도 백화점 상품권현금화 할부 결제 이용 원리',
#   'link': 'https://blog.naver.com/hdhddhddd/224040720641',
#   'description': '<b>핀테크</b> 분야는 그야말로 넓은 바다와도 같습니다. 암호화폐에서부터 부동산까지 다양한 영역을... 폭풍우 속에서도 항해를 이어가는 배처럼, 기준금리 인상과 불확실한 전망 속에서도 <b>핀테크</b> 분야는 성장세를... ',
#   'bloggername': '딩딩이의 먹방 만년 다이어리',
#   'bloggerlink': 'blog.naver.com/hdhddhddd',
#   'postdate': '20251014'},
#  {'title': '페이코신용카드상품권현금화 서비스 이용 시 주의사항... ',
#   'link': 'https://blog.naver.com/hdhddhddd/224040718219',
#   'description': '늘었더라구요~ <b>핀테크</b> 산업에 대한 관심도 점점 커지고 있고요! 비트코인, 주식, 부동산 같은 자산에도... <b>핀테크</b> 산업이 그래서 더 주목받는 것 같아요! 0.56포인트로 상품권을 사는 건 흔치 않은 투자법이에요... ',
#   'bloggername': '딩딩이의 먹방 만년 다이어리',
#   'bloggerlink': 'blog.naver.com/hdhddhddd',
#   'postdate': '20251014'},
#  {'title': '10월 14일 국내 글로벌 코인 이슈, 정보!!',
#   'link': 'https://blog.naver.com/lbank-/224040715843',
#   'description': '동시에 한국 <b>핀테크</b> 기업 Toss가 원화 기반 스테이블코인 발행을 검토 중이라는 보도도 있고, 정부 쪽에서도 관련 법제 정비 가능성이 논의되고 있습니다. 만약 성사되면, 원화 스테이블코인이 국내외... ',
#   'bloggername': '코인의 모든것을 도와드립니다. "코모도"',
#   'bloggerlink': 'blog.naver.com/lbank-',
#   'postdate': '20251014'},
#  {'title': 'Global Vicke 사기 투자 리딩방의 교묘한 수법과 대응방법... ',
#   'link': 'https://blog.naver.com/dissocition12385/224040713051',
#   'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': 'daylaw 강민성 대표 변호사',
#   'bloggerlink': 'blog.naver.com/dissocition12385',
#   'postdate': '20251014'},
#  {'title': '최근 암호화폐 시장의 급락은 기관 투자자들의 의도적인 시장... ',
#   'link': 'https://blog.naver.com/ucrypto/224040712383',
#   'description': '* 시사하는 바: 이번 협력은 암호화폐가 단순 투자 자산을 넘어 실제 기관 금융 인프라에 통합되기 시작했음을 보여주며, 향후 국내 블록체인, <b>핀테크</b>, IT 기업들에게도 새로운 산업 기회가 열릴... ',
#   'bloggername': 'U+Crypto Academy',
#   'bloggerlink': 'blog.naver.com/ucrypto',
#   'postdate': '20251014'},
#  {'title': '인도네시아 주식 시장, 소액 투자자들의 공감과 분노',
#   'link': 'https://blog.naver.com/begin_of_empathy/224040705276',
#   'description': '특히 금융 서비스의 접근성을 높여주었던 <b>핀테크</b> 기업들이 성장 후 수익성을 위해 정책을 변경할 때, 초기 사용자들의 공감을 얻지 못하면 큰 반발에 직면할 수 있다는 것을 보여주는 사례네요. 2.... ',
#   'bloggername': '공감의 시작',
#   'bloggerlink': 'blog.naver.com/begin_of_empathy',
#   'postdate': '20251014'},
#  {'title': '[10월 부산설명회 초청] 호주 머독대학교 in 싱가포르... ',
#   'link': 'https://blog.naver.com/freewayinternational/224040704311',
#   'description': '분석, <b>핀테크</b>, 호스피탈리티 및 관광경영, 인사관리, 정보기술, 법학, 물류 및 공급망 관리, 마케팅 및 경영, 대중매체 커뮤니케이션, 미디어 커뮤니케이션 및 디지털 마케팅, 심리학, 심리학 및 상담... ',
#   'bloggername': '프리웨이 에듀케이션',
#   'bloggerlink': 'blog.naver.com/freewayinternational',
#   'postdate': '20251014'},
#  {'title': '케이뱅크 역 이름이 생긴 이유 3가지, 서울이 들썩인 진짜 사연',
#   'link': 'https://blog.naver.com/bhivv/224040584698',
#   'description': '경험하는 <b>핀테크</b> 문화”를 완성하고 있는 셈이라고 봐야 한다 ※ 함께 보면 좋은 글 https://blog.naver.com/bhivv/224038476383 이유 3. 지하철 45개 역사에 깔린 생활형 금융 네트워크 생활 속에서도 케이뱅크는 이미... ',
#   'bloggername': '목마른 경제적 자유',
#   'bloggerlink': 'blog.naver.com/bhivv',
#   'postdate': '20251014'},
#  {'title': '미래에셋 박현주회장의 큰딸 박하민이 꿈꾸는 원대한 미래',
#   'link': 'https://blog.naver.com/the-economy/224040700478',
#   'description': '넥서스베이캐피탈의 창업자인 구승하 대표는 과거 중국 <b>핀테크</b> 기업 크레딧이즈(CreditEase)의 글로벌 VC·PE 부문을 총괄해 운용자산 규모를 10억 달러 수준까지 성장시킨 경력이 있다. 또한 맥쿼리, GCM... ',
#   'bloggername': '더 이코노미(The Economy)',
#   'bloggerlink': 'blog.naver.com/the-economy',
#   'postdate': '20251014'},
#  {'title': 'CMA금리비교: 현명한 투자자를 위한 숨겨진 꿀팁 대방출!',
#   'link': 'https://blog.naver.com/gghyui/224040375383',
#   'description': '같은 <b>핀테크</b> 앱을 통해 CMA 금리를 비교하는 사람들도 많습니다. 이러한 앱들은 사용자 친화적인 인터페이스를 제공하여 CMA 상품을 직관적으로 비교할 수 있도록 도와줍니다. 하지만, <b>핀테크</b> 앱에서... ',
#   'bloggername': '⭐경제-킴잡스 이야기⭐',
#   'bloggerlink': 'blog.naver.com/gghyui',
#   'postdate': '20251014'},
#  {'title': '무직자 대출: 신용점수, 담보 활용, 한도 증액까지 현실적인... ',
#   'link': 'https://blog.naver.com/worldcon88/224040692141',
#   'description': '무직자는 토스 등 <b>핀테크</b> 플랫폼으로 대출 신청하면 승인이 더 잘 되나요? • 플랫폼별 자체 스크리닝 기준은 별도로 존재하나, 최종 승인 기준은 각 제휴 금융사의 심사 정책에 따릅니다. 기대출 과다... ',
#   'bloggername': '라이프케어가드',
#   'bloggerlink': 'blog.naver.com/worldcon88',
#   'postdate': '20251014'},
#  {'title': '독일 송금 수수료 부담없이 저렴하게!',
#   'link': 'https://blog.naver.com/wirebarley_official/224040681890',
#   'description': '와이어바알리는 독자적인 <b>핀테크</b> 기술을 통해 중개은행을 거치지 않고 독일 해외송금이 가능한데요.... 빠른 송금 처리 독자적인 <b>핀테크</b> 기술을 통해 중개은행 없이 빠른 송금 처리가 가능하여 간편하게... ',
#   'bloggername': 'WireBarley, 글로벌 해외송금',
#   'bloggerlink': 'blog.naver.com/wirebarley_official',
#   'postdate': '20251014'},
#  {'title': 'NAVER 최신 리포트 정리, 목표주가와 전망 정리',
#   'link': 'https://blog.naver.com/ytl26/224040674392',
#   'description': '서론: NAVER, 지금 주목해야 할 타이밍 네이버는 검색, 광고, 커머스, 콘텐츠, <b>핀테크</b>, 웹툰 등 다방면 서비스를 운영하며 플랫폼 기업으로 자리매김해 왔습니다. 최근에는 AI 투자, 두나무 관련 사업 연계... ',
#   'bloggername': '책배남',
#   'bloggerlink': 'blog.naver.com/ytl26',
#   'postdate': '20251014'},
#  {'title': '테마동향_251013',
#   'link': 'https://blog.naver.com/become_buja84/224040001052',
#   'description': '(Yanolja), <b>핀테크</b>(FinTech), 여행, 줄기세포, 가상화폐(비트코인 등), 블록체인, 무선충전기술, 비만치료제, SNS(소셜네트워크서비스) 등... 로봇(산업용/협동로봇 등)/ 지능형로봇/인공지능(AI) 피규어AI, 3세대... ',
#   'bloggername': '성공, 매일 반복되는 작은 노력의 합',
#   'bloggerlink': 'blog.naver.com/become_buja84',
#   'postdate': '20251014'},
#  {'title': '주말 비대면대출 가능한곳 확고하게 안내',
#   'link': 'https://blog.naver.com/zooer/224040079926',
#   'description': '스마트폰 기술의 빠른 발전과 함께 <b>핀테크</b> 산업도 급성장하면서 토스 뱅크나 카카오뱅크 같은 디지털 은행들이 생겨났고 다양한 금융사에 서도 온라인 전용 상품을 꾸준히 출시하고 있습늬다. 그렇다면... ',
#   'bloggername': '주노CAKE',
#   'bloggerlink': 'blog.naver.com/zooer',
#   'postdate': '20251014'},
#  {'title': '한국 유니콘 기업 현황',
#   'link': 'https://blog.naver.com/s-cover/224040671190',
#   'description': '업종 분포는 전자상거래 4개, 소매업 2개, 기타 7개로 다양하나 <b>핀테크</b>·AI 등 기술 분야가... 전체적으로 <b>핀테크</b>(Toss, $7.4B), 모빌리티(Kakao Mobility, $6.5B), 게임(Bluehole Studio, $4.6B), e-commerce... ',
#   'bloggername': '에스커버 모바일 액세서리 전문 쇼핑몰',
#   'bloggerlink': 'blog.naver.com/s-cover',
#   'postdate': '20251014'},
#  {'title': '와이즈 Wise USD, AUD달러 계좌 개설 모인 MOIN 송금서비스... ',
#   'link': 'https://blog.naver.com/juho524/224040666691',
#   'description': '해외 송금이나 외화 결제가 필요할 때, 비싼 은행수수료 대신 빠르고 저렴한 <b>핀테크</b> 앱 하나로... Wise(와이즈) 앱으로 USD, AUD 계좌 개설하는 방법 와이즈는 영국 <b>핀테크</b> 기반의 글로벌 금융 서비스로... ',
#   'bloggername': '퇴직금으로 여행하는 심플수트',
#   'bloggerlink': 'blog.naver.com/juho524',
#   'postdate': '20251014'},
#  {'title': 'AZ Financial 사기 투자 플랫폼 수법 완전 분석 (사칭)',
#   'link': 'https://blog.naver.com/lucifer49329/224040522753',
#   'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': '데이 강민성 변호사',
#   'bloggerlink': 'blog.naver.com/lucifer49329',
#   'postdate': '20251014'},
#  {'title': '프랙탈에프엔 리틀버핏 오전 뉴스 [10/14 (화)]',
#   'link': 'https://blog.naver.com/mmd1292/224040659480',
#   'description': '안녕하세요, 오늘의 주요 <b>핀테크</b> 뉴스를 공유 드립니다. 한국<b>핀테크</b>지원센터 Daily News Monitoring [10/14 (화)] [한국<b>핀테크</b>지원센터] 1. 2025 <b>핀테크</b> 전문가 과정 ‘FinBoost... ',
#   'bloggername': '리틀버핏',
#   'bloggerlink': 'blog.naver.com/mmd1292',
#   'postdate': '20251014'},
#  {'title': '네이버 업비트 두나무 관련주, 뱅크웨어글로벌 종목 분석',
#   'link': 'https://blog.naver.com/luckyinnae/224040653772',
#   'description': '네이버 두나무 인수 관련주 총정리 | 뱅크웨어글로벌 주가 전망과 투자전략 최근 <b>핀테크</b> 시장이... 결제·<b>핀테크</b> 인프라 공급사 NHN KCP, 쿠콘, 헥토파이낸셜, 다날 스테이블코인·결제 API 핵심 수혜주 금융 IT... ',
#   'bloggername': '심소장의 아파트분양 리뷰',
#   'bloggerlink': 'blog.naver.com/luckyinnae',
#   'postdate': '20251014'},
#  {'title': '쇼피파이 2분기 어닝콜 프리젠테이션 자료 분석',
#   'link': 'https://blog.naver.com/hhr4376/224040649401',
#   'description': 'https://s27.q4cdn.com/572064924/files/doc_presentations/2025/May/08/Investor-Overview-Deck-Q1-2025-2.pdf AI 활용 설정 사진 설명을 입력하세요. AI 활용 설정 사진 설명을 입력하세요. 해당 이미지는 쇼피파이(Shopify)의 주요... ',
#   'bloggername': '생각이 돈이다',
#   'bloggerlink': 'blog.naver.com/hhr4376',
#   'postdate': '20251014'},
#  {'title': '변화와 미래 전망:금융권 동향부터 디지털 혁신,<b>핀테크</b>까지',
#   'link': 'https://blog.naver.com/dth73819/224040643226',
#   'description': '금융산업 변화와 미래전망 : 금융권 동향부터 디지털 혁신, <b>핀테크</b> 까지 안녕하세요,금융에 관심있는 여러분! 최근 금융 산업은 빠르게 변화하고 있습니다. 전통 금융권은 물론, 디지털 금융과 <b>핀테크</b>까지... ',
#   'bloggername': '삽살개',
#   'bloggerlink': 'blog.naver.com/dth73819',
#   'postdate': '20251014'},
#  {'title': '[도약 프로그램] 2025 중소기업 지원, 도약(Jump-Up)... ',
#   'link': 'https://blog.naver.com/fki_lsc/224040446624',
#   'description': '서비스 <b>핀테크</b>, 인슈어테크, 로보어드바이저, 디지털 뱅킹 등 전문 및 교육 서비스 에듀테크, 온라인 교육 플랫폼, 디자인 컨설팅 등 친환경 및 스마트인프라 신재생에너지 태양광, 풍력, 수소에너지, 지열... ',
#   'bloggername': '한경협중소기업협력센터',
#   'bloggerlink': 'blog.naver.com/fki_lsc',
#   'postdate': '20251014'},
#  {'title': '2025년 10월 14일 - 15일 미국주식정보(25.10.14... ',
#   'link': 'https://blog.naver.com/wnguddhkd/224040630301',
#   'description': '기대 • <b>핀테크</b>: GS, PYPL(PayPal), MQ(Marqeta) ‘매도’ 하향 – 마진 압박 및 집중 리스크 지적 5️⃣ 자산시장 동향 • 채권시장 휴장(Columbus Day)으로 변동 제한. WTI $59.95, Gold $4,114로 상승... ',
#   'bloggername': '호기심',
#   'bloggerlink': 'blog.naver.com/wnguddhkd',
#   'postdate': '20251014'},
#  {'title': '실리콘밸리 <b>핀테크</b> 하프모어, 딥코어 리드 투자로 누적 35억 원... ',
#   'link': 'https://blog.naver.com/ksvalley/224040630287',
#   'description': '딥코어 관계자는 &quot;하프모어는 강력한 초기 성과와 넓은 금융 웰니스로의 확장 잠재력을 갖췄다&quot;며 투자 배경을 밝혔다.',
#   'bloggername': 'k스타트업 밸리',
#   'bloggerlink': 'blog.naver.com/ksvalley',
#   'postdate': '20251014'},
#  {'title': '[CTN정보]꼭 읽어야 할 서울시소식',
#   'link': 'https://blog.naver.com/ggh7000/224040630580',
#   'description': '(금) ‘(재)서울투자진흥재단 창립총회’ 개최…설립 전 주요사항 심의 및 의결 - 창립총회 이후, 법인설립 허가 및 등기 등 제반 절차 거쳐 10월말 출범 목표 - GFCI 3년 연속 Top10, <b>핀테크</b> 8위 최초... ',
#   'bloggername': 'CTN신문사',
#   'bloggerlink': 'blog.naver.com/ggh7000',
#   'postdate': '20251014'},
#  {'title': '가족간 차용증 이자율 부모자식 형제 작성법(양식 무료다운)',
#   'link': 'https://blog.naver.com/kapbue/224040628117',
#   'description': '<b>핀테크</b> 기반의 앱을 통해 변호사 검토가 포함된 계약서를 작성할 수 있으며, 본인 인증까지 완료되어 법적 효력을 갖출 수 있습니다. 전자 차용증은 종이보다 보관이 쉽고 분실 위험도 적어 요즘 많은 분들이... ',
#   'bloggername': '호치스의 50억 만드는 부동산',
#   'bloggerlink': 'blog.naver.com/kapbue',
#   'postdate': '20251014'},
#  {'title': '무직자도 OK! 지금 바로 대출 가능?',
#   'link': 'https://blog.naver.com/himse/224040621180',
#   'description': '<b>핀테크</b> 기술의 발전과 더불어 청년, 취업준비생, 사회초년생 등 다양한 계층을 위한 맞춤형 대출 상품이 쏟아져 나오고 있어요.은행 문턱이 높다고 좌절하지 마세요. 2금융권, <b>핀테크</b> 기업 등 다양한 곳에서... ',
#   'bloggername': '아파트 담보대출 전문! OK자산관리대부',
#   'bloggerlink': 'blog.naver.com/himse',
#   'postdate': '20251014'},
#  {'title': '2025년 노벨 경제학상 - “창조적 파괴”',
#   'link': 'https://blog.naver.com/jeenu123/224040620030',
#   'description': '✅ <b>핀테크</b>·디지털 금융: Toss 등 — 은행·결제 시스템의 경쟁 재구성 무엇이 바뀌었나: Toss 등 <b>핀테크</b>는 간편송금·금융서비스를 통해 전통 은행의 소매금융 일부를 잠식하고, 사용자 경험을 재정의.... ',
#   'bloggername': 'Humus',
#   'bloggerlink': 'blog.naver.com/jeenu123',
#   'postdate': '20251014'},
#  {'title': '패스트파이브, 올 상반기 재계약률 94%...‘믿고 찾는 사무실... ',
#   'link': 'https://blog.naver.com/phenomdark/224040619773',
#   'description': '실제 장기 입주 기업 중 한 곳인 글로벌 <b>핀테크</b> 기업 와이어바알리는 2019년 첫 입주 이후 6년 이상 패스트파이브를 거점 오피스로 사용해 왔다. 와이어바알리는 성장 단계마다 필요한 규모와 입지를 유연하게... ',
#   'bloggername': 'SHOW MUST GO ON..',
#   'bloggerlink': 'blog.naver.com/phenomdark',
#   'postdate': '20251014'},
#  {'title': '7편 – PG(Payment Gateway)란 무엇인가',
#   'link': 'https://blog.naver.com/dydwo7151-/224040619374',
#   'description': 'PG의 진화 – <b>핀테크</b>와 함께 가는 길 최근 PG 산업은 단순한 결제 중개를 넘어 데이터 기반 정산, 마케팅, 소비 분석을 제공하는 방향으로 발전하고 있습니다. 또한 블록체인 기술과 결합해, 국경 없는... ',
#   'bloggername': 'dydwo7151-님의 블로그',
#   'bloggerlink': 'blog.naver.com/dydwo7151-',
#   'postdate': '20251014'},
#  {'title': '전자금융공동망은 어떻게 진화했을까, 미래 금융의 뿌리',
#   'link': 'https://blog.naver.com/rlocate/224040618979',
#   'description': "넘어 '금융기관과 <b>핀테크</b> 기업의 연결 허브'로 확장되었습니다 <b>핀테크</b> 기업들은 중앙은행이 관리하는 공동망을 통해 은행의 핵심 결제 기능에 접근할 수 있게 되었고 이는 간편 송금, 간편 결제 등 다양한... ",
#   'bloggername': '미소 지는 순간',
#   'bloggerlink': 'blog.naver.com/rlocate',
#   'postdate': '20251014'},
#  {'title': '급여통장 신규 개설 및 인터넷뱅킹 신청 방법',
#   'link': 'https://blog.naver.com/elow1957/224040614815',
#   'description': '다른 <b>핀테크</b> 서비스의 대안 서론 요즘 대부분의 금융거래가 온라인으로 이루어지고 있습니다. 이에... 다른 <b>핀테크</b> 서비스의 대안 최근에는 카카오뱅크, 케이뱅크 등 인터넷 전문은행을 통한 다양한 통장... ',
#   'bloggername': '내가 좋아하는것들',
#   'bloggerlink': 'blog.naver.com/elow1957',
#   'postdate': '20251014'},
#  {'title': '전망좋은주식 미국 주식 종목 중심 분석',
#   'link': 'https://blog.naver.com/wwlcc28/224040612860',
#   'description': '에너지 저장, 5G 통신, <b>핀테크</b> 분야 또한 안정적인 성장세를 보이고 있습니다. 이런 흐름 속에서 주목받는 기업들은 기술력, 수익 구조, 시장 점유율 세 가지 기준에서 공통된 특징을 가집니다. “지속... ',
#   'bloggername': 'wwlcc28님의 블로그',
#   'bloggerlink': 'blog.naver.com/wwlcc28',
#   'postdate': '20251014'},
#  {'title': '인도 ETF｜RISE 인도디지털성장·KODEX 인도Nifty50·TIGER... ',
#   'link': 'https://blog.naver.com/notinghel/224040610822',
#   'description': 'MarketVector 지수를 추종하며, 인도의 인터넷·<b>핀테크</b>·통신·클라우드 기업들이 중심입니다.... IT, <b>핀테크</b>, 통신 대형주, 금융, 에너지 소비재, 서비스, 자동차 최근 NAV 수준 약 10,300원 약 13... ',
#   'bloggername': 'notinghel님의 블로그',
#   'bloggerlink': 'blog.naver.com/notinghel',
#   'postdate': '20251014'},
#  {'title': '감성지능: <b>핀테크</b> 고객 경험의 미래',
#   'link': 'https://blog.naver.com/pxjlpss565/224040607064',
#   'description': '감성지능: <b>핀테크</b> 고객 경험의 미래 <b>핀테크</b> 산업은 빠르게 발전하고 있으며, 이에 따라 고객 경험에 대한 요구도 더욱 증가하고 있다. 최근 감성지능 기술의 발전으로 <b>핀테크</b> 기업들은 더욱 개인화된 서비스를... ',
#   'bloggername': '운동과 공부가 취미',
#   'bloggerlink': 'blog.naver.com/pxjlpss565',
#   'postdate': '20251014'},
#  {'title': '[신한투자증권 미국주식 주요이슈] 챗GPT 내 즉시 결제... ',
#   'link': 'https://blog.naver.com/shinhansec_official/224040598934',
#   'description': '구글과 쇼핑 전쟁 : 이번 기능은 오픈AI의 자체 기술인 ‘에이전틱 커머스 프로토콜’과 <b>핀테크</b> 기업 스트라이프(Stripe)와의 협력을 통해 구현됐고, 앞으로 장바구니 기능 및 글로벌 확장도 계획 중이에요.... ',
#   'bloggername': '신한투자증권 공식 블로그',
#   'bloggerlink': 'blog.naver.com/shinhansec_official',
#   'postdate': '20251014'},
#  {'title': '영문계약서, 어디서부터 봐야 할까? 기본 구조와 핵심 조항... ',
#   'link': 'https://blog.naver.com/legal_lemonade/224040593334',
#   'description': 'About the Authour 국내 대형은행 법무팀에서 10년 이상 국제금융, 신용장, 영문계약서 및 외국환규제 자문 등을 담당하고, <b>핀테크</b> 기업에서 해외 지급결제와 해외 진출 등 다양한 프로젝트를 수행한... ',
#   'bloggername': '리걸 레몬에이드',
#   'bloggerlink': 'blog.naver.com/legal_lemonade',
#   'postdate': '20251014'},
#  {'title': '비트코인관련주 코인베이스 다날 우리기술투자 주가 분석',
#   'link': 'https://blog.naver.com/fashiongreen/224040588409',
#   'description': "기반 <b>핀테크</b> / 결제 플랫폼 기업으로 암호화폐 결제 플랫폼인 다날<b>핀테크</b>를 개발해 '페이코인'을 실생활 결제에 적용하는 등의 경험을 가지고 있는데요 이러한 기술력을 기반으로 스테이블코인 사업 진출... ",
#   'bloggername': '돈 되는 경제만 쉽고 빠르게',
#   'bloggerlink': 'blog.naver.com/fashiongreen',
#   'postdate': '20251014'},
#  {'title': '신용점수 올리는 방법 2025 최신 기준 정리',
#   'link': 'https://blog.naver.com/sssolution1858/224039350975',
#   'description': '정확한 진단 정직한 처방 고객과 상생을 도모하는 에스에스솔루션 2025년 들어 신용점수 제도가 한층 더 정교해졌다. 단순히 연체 없이 대출을 갚는 것만으로는 점수를 높이기 어렵고, 금융사마다 평가 기준이... ',
#   'bloggername': 'Sssolution',
#   'bloggerlink': 'blog.naver.com/sssolution1858',
#   'postdate': '20251014'},
#  {'title': 'RISE 인도디지털성장 ETF 완전정리｜인도 디지털 인프라... ',
#   'link': 'https://blog.naver.com/notinghel/224040584997',
#   'description': '이 ETF는 인도의 IT·통신·<b>핀테크</b>·디지털 인프라 산업을 대표하는 상장기업들로 구성되어... 디지털 인프라, 온라인 서비스, 통신, <b>핀테크</b>, 클라우드 등 인도의 정보기술 기반 산업 성장을... ',
#   'bloggername': 'notinghel님의 블로그',
#   'bloggerlink': 'blog.naver.com/notinghel',
#   'postdate': '20251014'},
#  {'title': '시니어 마케팅, 60대·70대·80대, 같은 ‘시니어’로 묶어선... ',
#   'link': 'https://blog.naver.com/trotnewsofficial/224040583199',
#   'description': '평생교육, 디지털 고급 교육(<b>핀테크</b>, AI 활용)을 제공하세요. 여가·문화·관광 바우처를 적극 활용하세요. 70대 정책: 안전 관리 만성질환 예방 바우처, 보안·사기 예방 교육을 확대하세요. 디지털 서비스에 1:1... ',
#   'bloggername': '시니어마케팅 연구소',
#   'bloggerlink': 'blog.naver.com/trotnewsofficial',
#   'postdate': '20251014'},
#  {'title': '신한은행 2026년 동계 청년인턴 채용 완벽 가이드 - 금융권... ',
#   'link': 'https://blog.naver.com/cymmcymm/224040566983',
#   'description': '결합된 <b>핀테크</b> 시대에 꼭 필요한 경험을 쌓을 수 있는 기회랍니다. 신한은행 청년인턴 지원 자격 조건... 금융권 취업을 준비하고 계신 분들, IT와 금융을 결합한 <b>핀테크</b> 분야에 관심 있는 분들 모두에게 정말... ',
#   'bloggername': 'Creater Y',
#   'bloggerlink': 'blog.naver.com/cymmcymm',
#   'postdate': '20251014'},
#  {'title': '“솔라나 × 한국 스테이블코인 — 주식시장에서 주목할... ',
#   'link': 'https://blog.naver.com/hmn1204/224040565408',
#   'description': '증가 <b>핀테크</b> / 결제 플랫폼 스테이블코인 → 결제/송금/정산 활용 가능성, 자체 플랫폼 내 사용... <b>핀테크</b> / 결제 플랫폼 회사 (예: 토스 등) 실제 보도가 있듯 토스(Toss)가 “원화 기반 스테이블코인 발행”을... ',
#   'bloggername': '억만덕후의 이시대 살아남는법',
#   'bloggerlink': 'blog.naver.com/hmn1204',
#   'postdate': '20251014'},
#  {'title': '미국의 파이어족이 불러올 경제의 나비효과',
#   'link': 'https://blog.naver.com/garts44/224040562087',
#   'description': '오늘날의 <b>핀테크</b>, 국채, 디지털 자산이 같은 역할을 하고 있습니다. 5️⃣ 소비재·유통 도시화와 중산층의 등장으로 전국 유통망이 생겼고, 시어스의 카탈로그와 코카콜라는 그 시대의 아이콘이었습니다.... ',
#   'bloggername': '오늘 질문은...',
#   'bloggerlink': 'blog.naver.com/garts44',
#   'postdate': '20251014'},
#  {'title': '[<b>핀테크</b> 기자단] 2025 K-DATA·신용보즘기금·한국<b>핀테크</b>지... ',
#   'link': 'https://blog.naver.com/koreafintech/224040557226',
#   'description': '지난 9월 18일 디캠프 프론트원에서 진행된 2025 K-DATA·신용보즘기금· 한국<b>핀테크</b>지원센터 IR DAY 데모데이에 <b>핀테크</b> 대학생 기자단이 현장취재를 다녀왔습니다! 각 기관이 지원하는 유망 스타트업들을... ',
#   'bloggername': '한국핀테크지원센터',
#   'bloggerlink': 'blog.naver.com/koreafintech',
#   'postdate': '20251014'},
#  {'title': '8월 서울 오피스 시장 분석 — 거래 급감에도 공실률은 하락',
#   'link': 'https://blog.naver.com/jsh5015/224040557309',
#   'description': 'AI, <b>핀테크</b>, 콘텐츠 업종 중심으로 오피스 입주 문의는 오히려 증가세.”  임대비용 — NOC 상승세... AI·<b>핀테크</b>·콘텐츠 산업 중심의 신규 오피스 수요 지속 하반기에는 강남·성수·여의도권 중심 재계약... ',
#   'bloggername': '부동산과 경제 뉴스 정리, 분양 소식과 다양한 정보',
#   'bloggerlink': 'blog.naver.com/jsh5015',
#   'postdate': '20251014'},
#  {'title': '증권사리포트 요약본 2025.10.14',
#   'link': 'https://blog.naver.com/kwangpoong/224040556592',
#   'description': '[035420] ˝AI, <b>핀테크</b>, 커머스˝ 모두 바쁨 ▶ 3Q25 Preview: 영업이익 5,579억원(+13.9% YoY)으로 컨센서스 하회 추정 ▶ 중장기 <b>핀테크</b> 사업 가치 부각 하나증권 이준호 카카오 [035720] 3분기 영업이익 1... ',
#   'bloggername': '學習忍',
#   'bloggerlink': 'blog.naver.com/kwangpoong',
#   'postdate': '20251014'},
#  {'title': '스테이블코인 결제시스템 3가지 핵심 변화 총정리',
#   'link': 'https://blog.naver.com/law_sugarsquare/224035670742',
#   'description': "* [상담문의]  02-563-5877  010-****-**** 카톡 '법무법인슈가스퀘어' 검색! 또는 카카오톡 상담링크  ****@sugar.legal #스테이블코인 #결제시스템 #<b>핀테크</b> #블록체인 #금융혁신",
#   'bloggername': '법무법인 슈가스퀘어 블로그',
#   'bloggerlink': 'blog.naver.com/law_sugarsquare',
#   'postdate': '20251014'},
#  {'title': '2025년 10월 14일 관심종목(주식)',
#   'link': 'https://blog.naver.com/kk9550ch/224040546776',
#   'description': 'idxno=3162806 아이티센피엔에스 - 통합 보안시스템+양자암호 솔루션 - <b>핀테크</b>, 스테이블코인 관련주 [특징주] 아이티센피엔에스, &quot;美 스테이블코인 규제법 통과&quot; 가상화폐 ... ',
#   'bloggername': '재테크 in my life (feat.맛난음식)',
#   'bloggerlink': 'blog.naver.com/kk9550ch',
#   'postdate': '20251014'},
#  {'title': '오늘자 이커머스 전망에 대해 알아보자',
#   'link': 'https://blog.naver.com/pdion/224040542746',
#   'description': '결제·<b>핀테크</b> 통합 BNPL(Buy Now Pay Later), 간편 결제, 디지털 월렛 등이 사용자 경험을 매끄럽게 할 것 마켓플레이스 재편 / 플랫폼 경쟁 플랫폼 간 제휴, 인수합병, 수수료 및 데이터 경쟁이 심화될 것 3. 기회... ',
#   'bloggername': '피디온',
#   'bloggerlink': 'blog.naver.com/pdion',
#   'postdate': '20251014'},
#  {'title': '코스피 시가총액 순위, 대한민국 TOP10 기업 성적표',
#   'link': 'https://blog.naver.com/hanvit_lol/224040543213',
#   'description': 'TOP10에 턱걸이로 안착했으며 <b>핀테크</b>, 콘텐츠, AI 삼박자를 앞세워서 제2의 도약을 노리고 있는 중이다. 이상으로 대한민국 경제의 심장인 코스피 TOP10 기업들의 역동적인 성적표 보았다. 25년의 성적표는 AI... ',
#   'bloggername': '잘먹고 잘사는 오리좌',
#   'bloggerlink': 'blog.naver.com/hanvit_lol',
#   'postdate': '20251014'},
#  {'title': '[비트코인 스탠다드]가 말하지 못한 것: GENIUS Act와 STABLE... ',
#   'link': 'https://blog.naver.com/10000reading/224040540164',
#   'description': '이 경우 카드 네트워크·은행 코어·<b>핀테크</b> 월렛이 스테이블코인 결제 레일을 품으며 **‘매끄러운... 은행-<b>핀테크</b>-카드사가 맺는 삼각 파트너십이 관건이다. 4) 체인 간 상호운용성과 계정 추상화 모바일... ',
#   'bloggername': '일만리딩',
#   'bloggerlink': 'blog.naver.com/10000reading',
#   'postdate': '20251014'},
#  {'title': '네이버·카카오, AI 전환으로 실적 폭발!',
#   'link': 'https://blog.naver.com/smart-moneylog/224039305600',
#   'description': '디지털 자산, <b>핀테크</b>, 블록체인 등 새로운 성장축이 확실히 잡히는 셈이죠. AI에다 가상자산까지... 앞으로의 관전 포인트 네이버는 AI로 쇼핑과 <b>핀테크</b>를, 카카오는 AI로 커뮤니케이션과 광고를 진화시키는... ',
#   'bloggername': '스마트머니로그',
#   'bloggerlink': 'blog.naver.com/smart-moneylog',
#   'postdate': '20251014'},
#  {'title': '비바리퍼블리카 주가 급등하는 이유, 2025년 상장 앞둔 토스의... ',
#   'link': 'https://blog.naver.com/kwonmj1216/224022265678',
#   'description': '최근 <b>핀테크</b> 업계에서 가장 뜨거운 관심을 받는 비바리퍼블리카에 대한 궁금증이었습니다. 실제로... 나 역시 <b>핀테크</b> 업계를 10년 넘게 지켜보면서 이만큼 탄탄한 실적 기반을 갖춘 회사를 본 적이 드물다고... ',
#   'bloggername': '올인포',
#   'bloggerlink': 'blog.naver.com/kwonmj1216',
#   'postdate': '20251014'},
#  {'title': 'AI가 리드하는 <b>핀테크</b> 혁신의 미래! : 서울 <b>핀테크</b> 위크 2025... ',
#   'link': 'https://blog.naver.com/elmanproduction/224040539614',
#   'description': '오늘은 서울 <b>핀테크</b> 위크 2025 홍보 영상 제작 후기를 들고 왔습니다. 로딩중,,, 글로번 <b>핀테크</b> 축제인 서울 <b>핀테크</b> 위크 2025가 곧 개최됩니다. 금융과 AI, <b>핀테크</b> 산업의 주요 이슈를 다루고 혁신적인... ',
#   'bloggername': 'ELMAN 영상제작사',
#   'bloggerlink': 'blog.naver.com/elmanproduction',
#   'postdate': '20251014'},
#  {'title': '벤처기업도 이제 ‘가상자산 거래업’을 할 수 있다!',
#   'link': 'https://blog.naver.com/veteran01/224040538500',
#   'description': '◆ 기대 효과 혁신 스타트업의 진입 확대: 블록체인 기술 기반의 <b>핀테크</b>, 거래 플랫폼, 토큰증권(STO) 등 다양한 영역에서 벤처기업들이 자유롭게 사업을 추진할 수 있습니다. 투자 활성화: 벤처기업 인증이... ',
#   'bloggername': 'Not success but Service',
#   'bloggerlink': 'blog.naver.com/veteran01',
#   'postdate': '20251014'},
#  {'title': '<b>핀테크</b>와 혁신의 만남 : 제4회 피노베이션 챌린지 행사 오프닝... ',
#   'link': 'https://blog.naver.com/elmanproduction/224040533011',
#   'description': '<b>핀테크</b>(Fintech)와 이노베이션(Innovation)을 합친 용어로, 서울시가 추진해온 프로그램입니다. <b>핀테크</b>, 인슈어테크, AI, 빅데이터 등 다양한 기술 역량을 가진 스타트업을 발굴하고, 금융사와의 공동 사업화를... ',
#   'bloggername': 'ELMAN 영상제작사',
#   'bloggerlink': 'blog.naver.com/elmanproduction',
#   'postdate': '20251014'},
#  {'title': '10월 14일. 투자자를 위한 뉴스 속 실마리 [자본시장 이슈... ',
#   'link': 'https://blog.naver.com/numbersmembers/224040531979',
#   'description': "https://www.insightkorea.co.kr/news/articleView.html?idxno=233417 Published on: 2025-10-13 15:34:00 가상자산 M&amp;A 3배 급증…금융·<b>핀테크</b> '합종연횡' 본격화 /전자신문 가상자산 업계 인수합병(M&amp;A) 발표가... ",
#   'bloggername': 'M&A·지배구조·Deal·기업분석 뉴스 서비스 <넘버스>',
#   'bloggerlink': 'blog.naver.com/numbersmembers',
#   'postdate': '20251014'},
#  {'title': '디지털 브레튼우즈의 서막: 달러·금의 시대를 넘어 블록체인... ',
#   'link': 'https://blog.naver.com/10000reading/224040531447',
#   'description': 'IMF·BIS와 함께 민간 PSP, <b>핀테크</b>, 은행 컨소시엄이 공동으로 의결권을 행사하여 권력 집중을 방지한다. 5~7년의 로드맵: 테스트넷에서 글로벌 표준으로 1단계에서는 CBDC 상호운용 최소규격과 디지털 SDR... ',
#   'bloggername': '일만리딩',
#   'bloggerlink': 'blog.naver.com/10000reading',
#   'postdate': '20251014'},
#  {'title': '[GPU Live] GPUaaS 서비스 GPU Live!',
#   'link': 'https://blog.naver.com/nhn_injeinc/224039765197',
#   'description': '✅ 금융·<b>핀테크</b> 산업 GPU Live는 금융기관에서 중요한 딥러닝 기반 이상거래 탐지(FDS), 신용평가 모델링, 고객 행동 분석 등대규모 연산이 필요한 금융 서비스 환경에 최적화되어 있습니다! GPU 자원을... ',
#   'bloggername': 'NHN 인재아이엔씨',
#   'bloggerlink': 'blog.naver.com/nhn_injeinc',
#   'postdate': '20251014'},
#  {'title': '채무통합대환대출조건 채무통합으로 시작하는 현명한 재무 관리',
#   'link': 'https://blog.naver.com/my-loan-clinic/223949594538',
#   'description': '금융사의 상품을 비교할 때 대출 비교 앱이나 <b>핀테크</b> 플랫폼을 적극 활용해 봐야 합니다. 통합 대출 시 발생할 수 있는 수수료나 추가 비용도 반드시 확인하셔야 합니다. 직접 금융 기관 상담이 어렵다면 전문가... ',
#   'bloggername': '마이금융클리닉 공식블로그',
#   'bloggerlink': 'blog.naver.com/my-loan-clinic',
#   'postdate': '20251014'},
#  {'title': '카드매출로 보증받는 법, 실전 가이드',
#   'link': 'https://blog.naver.com/yj920621/224040121932',
#   'description': '은행·<b>핀테크</b> 특례형) Tip: 현금 매출 비중이 높아도 카드·PG 매출 증빙 비율을 최대화하면 한도에 유리합니다. 준비물 체크리스트 - 필수 - 사업자등록증 사본 - 대표자 신분증 - 최근 6~12개월 카드매출 내역... ',
#   'bloggername': '한국중소기업 지원센터',
#   'bloggerlink': 'blog.naver.com/yj920621',
#   'postdate': '20251014'},
#  {'title': '가상자산: ‘벤처인증 허용’+‘대출 규제’ 병행… 산업은... ',
#   'link': 'https://blog.naver.com/k3228452/224040522149',
#   'description': '#가상자산 #크립토 #디지털자산 #벤처인증 #디지털자산기본법 #스테이블코인 #렌딩규제 #금리상한 #레버리지금지 #소비자보호 #공시의무 #내부통제 #준법감시 #리스크관리 #거래소 #커스터디 #<b>핀테크</b> #웹3',
#   'bloggername': '한눈정책 – 핵심만 콕, 하루 한 장',
#   'bloggerlink': 'blog.naver.com/k3228452',
#   'postdate': '20251014'},
#  {'title': 'Eat-Lancet이 제시한 이상적인 식단',
#   'link': 'https://blog.naver.com/yelms/224040517993',
#   'description': '이는 저렴한 식물성 단백질 기반의 간편식(HMR), 개인 맞춤형 구독 서비스, 혹은 건강한 식습관을 유도하는 챌린지 앱과 같은 <b>핀테크</b> 결합 서비스 등 무궁무진한 사업 기회를 의미한다. 2. 전통 식단의 보호와... ',
#   'bloggername': '국경없는금융포럼',
#   'bloggerlink': 'blog.naver.com/yelms',
#   'postdate': '20251014'},
#  {'title': '2025.10.14(화) 기업 리포트 요약 정리',
#   'link': 'https://blog.naver.com/timulys/224040516473',
#   'description': 'A035420 -˝AI, <b>핀테크</b>, 커머스˝ 모두 바쁨 3Q25 Preview: 영업이익 5,579억원(+13.9% YoY)으로 컨센서스 하회 추정 중장기 <b>핀테크</b> 사업 가치 부각 매수 320,000 262,500 SK증권 남효지 2025/10/14... ',
#   'bloggername': '투자하는 행복',
#   'bloggerlink': 'blog.naver.com/timulys',
#   'postdate': '20251014'},
#  {'title': '[TUO]10월14일 세계뉴스: 가자 휴전, 우크라 토마호크, EU... ',
#   'link': 'https://blog.naver.com/world-response/224040514540',
#   'description': '넷째, 유엔 사이버협약의 서명·비준 과정을 거치며 데이터 이전, 전자증거 교환, 플랫폼 책임 범위가 분명해지면 클라우드·보안·<b>핀테크</b> 기업의 규제 대응 비용과 수익 모델에도 변화가 생길 가능성이 큽니다.... ',
#   'bloggername': '장대표의 인사이드 베트남',
#   'bloggerlink': 'blog.naver.com/world-response',
#   'postdate': '20251014'},
#  {'title': 'Global Vicke 사기 투자 리딩방 미끼 완전 해부 (사칭)',
#   'link': 'https://blog.naver.com/lucifer49329/224040508093',
#   'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#   'bloggername': '데이 강민성 변호사',
#   'bloggerlink': 'blog.naver.com/lucifer49329',
#   'postdate': '20251014'},
#  {'title': 'Angel❤️월세·전세금 부담 줄이는 혁신 서비스  보증금... ',
#   'link': 'https://blog.naver.com/nyk34644/224040504261',
#   'description': '이런 고민을 해결해주는 다양한 <b>핀테크</b> 서비스들이 등장하고 있어 관심이 집중되고 있습니다.... <b>핀테크</b> 스타트업 데브디에서 출시한 집업페이는 또 다른 혁신을 가져왔습니다. 바로 집주인의 동의 없이도... ',
#   'bloggername': '작으면서 큰 부동산이야기',
#   'bloggerlink': 'blog.naver.com/nyk34644',
#   'postdate': '20251014'},
#  {'title': '이직사유 예시 BEST 3, 면접 답변 꿀팁 총정리 &amp; 합격 전략!',
#   'link': 'https://blog.naver.com/staffs00/224040498054',
#   'description': '최근 <b>핀테크</b> 분야에 큰 관심을 갖게 되면서 귀사의 AI 기반 개인화 금융 서비스를 주목하게... 제가 보유한 대용량 데이터 처리 경험과 금융 도메인 지식을 바탕으로 귀사 AI <b>핀테크</b> 서비스의 안정성과 확장성... ',
#   'bloggername': 'STAFFS STORY',
#   'bloggerlink': 'blog.naver.com/staffs00',
#   'postdate': '20251014'},
#  {'title': '2030대가 선호하는 대기업 TOP10과 선택 이유',
#   'link': 'https://blog.naver.com/rct190/224040494783',
#   'description': '카카오 플랫폼, 콘텐츠, <b>핀테크</b> 등 영역을 넘나들며 혁신을 시도하는 모습이 2030대의 관심을 끌고 있습니다. “미래 가치가 기대된다”라는 평가와 함께 브랜드 이미지도 세련되고 젊은 감각이 강하다는... ',
#   'bloggername': '파이어족의 경제, 금융 이야기',
#   'bloggerlink': 'blog.naver.com/rct190',
#   'postdate': '20251014'},
#  {'title': '카카오페이 10월 14일 퀴즈 맞히고 복권 받기',
#   'link': 'https://blog.naver.com/tkadla1422/224040494383',
#   'description': '이처럼 통합 <b>핀테크</b> 플랫폼으로 진화하며 투자, 환전, 보험, 청구서 관리 등 다양한 금융 서비스를 통합 제공하는 점도 큰 강점입니다. 요약하면, 카카오페이는 카카오톡과의 완벽한 연동으로 쉽고 빠른 결제와... ',
#   'bloggername': '김맹구의 탐구생활',
#   'bloggerlink': 'blog.naver.com/tkadla1422',
#   'postdate': '20251014'},
#  {'title': '카카오뱅크 목표가 하향 대출 규제 속 성장 전망 분석 투자 전략!',
#   'link': 'https://blog.naver.com/lottotem_economy/224040487251',
#   'description': '가계대출 규제가 성장 전망치에 미친 구체적 영향 <b>핀테크</b> 리더로서 카카오뱅크는 저렴한 수신 확대를... 시장 컨센서스 비교 및 <b>핀테크</b> 주의 향후 주가 전망 KB증권이 제시한 28,000원의 목표주가는 최근 6개월... ',
#   'bloggername': '경제톡',
#   'bloggerlink': 'blog.naver.com/lottotem_economy',
#   'postdate': '20251014'},
#  {'title': '10/14 섹터별 현황',
#   'link': 'https://blog.naver.com/mark-s/224040487497',
#   'description': '93 <b>핀테크</b>(FinTech) 0.92 mRNA(메신저 리보핵산) 0.92 PCB(FPCB 등) 0.90 코로나19(치료제/백신 개발 등) 0.90 2025 상반기 신규상장 0.89 딥페이크(deepfake) 0.88 제습기 0.87 두나무(Dunamu) 0.86... ',
#   'bloggername': 'Observer',
#   'bloggerlink': 'blog.naver.com/mark-s',
#   'postdate': '20251014'}]

# %%
import pandas as pd
df = pd.DataFrame(response['items'])
df
# Out:
#                                         title  \
# 0                          루민트, 글로벌 협력으로 확장하다
# 1       [케이뱅크 채용] 2026년 케이뱅크 채용연계형 인턴 자소서...
# 2                      더나은투자 사기 사칭 리딩방 가짜의 온기
# 3                금융 심사의 미래 : 신용점수 vs 소셜 신용 점수
# 4         달라진 신용대출 금리 체계와 금융 소비자에게 다가올 주요...
# ..                                        ...
# 95  이직사유 예시 BEST 3, 면접 답변 꿀팁 총정리 &amp; 합격 전략!
# 96               2030대가 선호하는 대기업 TOP10과 선택 이유
# 97                 카카오페이 10월 14일 퀴즈 맞히고 복권 받기
# 98       카카오뱅크 목표가 하향 대출 규제 속 성장 전망 분석 투자 전략!
# 99                               10/14 섹터별 현황
#
#                                                  link  \
# 0          https://blog.naver.com/sxnoig/224040826219
# 1     https://blog.naver.com/biographers/224040819512
# 2      https://blog.naver.com/slted81266/224039801939
# 3      https://blog.naver.com/ouoigno361/224040533855
# 4   https://blog.naver.com/ggudaofficial/224040799628
# ..                                                ...
# 95       https://blog.naver.com/staffs00/224040498054
# 96         https://blog.naver.com/rct190/224040494783
# 97     https://blog.naver.com/tkadla1422/224040494383
# 98  https://blog.naver.com/lottotem_economy/224040...
# 99         https://blog.naver.com/mark-s/224040487497
#
#                                           description        bloggername  \
# 0   국제 파트너십 강화 루민트는 해외 <b>핀테크</b> 기업들과 협력을 진행 중입니다...                  -
# 1   따라서 단순히 ‘<b>핀테크</b>가 성장하고 있어서’와 같은 외부적 이유보다는, ...           자소서 첨삭공방
# 2   온기 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기...  daylaw 강민성 대표 변호사
# 3   이런 방식은 아직 국내에서는 본격적으로 도입되지 않았지만, 해외에서는 이미 일부 <...              소비의미학
# 4   최근에는 FICO 점수 외에도 은행 자체 모델이나 <b>핀테크</b> 기업의 대안 ...              GGUDA
# ..                                                ...                ...
# 95  최근 <b>핀테크</b> 분야에 큰 관심을 갖게 되면서 귀사의 AI 기반 개인화 금...       STAFFS STORY
# 96  카카오 플랫폼, 콘텐츠, <b>핀테크</b> 등 영역을 넘나들며 혁신을 시도하는 모...   파이어족의 경제, 금융 이야기
# 97  이처럼 통합 <b>핀테크</b> 플랫폼으로 진화하며 투자, 환전, 보험, 청구서 관...          김맹구의 탐구생활
# 98  가계대출 규제가 성장 전망치에 미친 구체적 영향 <b>핀테크</b> 리더로서 카카오...                경제톡
# 99  93 <b>핀테크</b>(FinTech) 0.92 mRNA(메신저 리보핵산) 0.9...           Observer
#
#                         bloggerlink  postdate
# 0             blog.naver.com/sxnoig  20251014
# 1        blog.naver.com/biographers  20251014
# 2         blog.naver.com/slted81266  20251014
# 3         blog.naver.com/ouoigno361  20251014
# 4      blog.naver.com/ggudaofficial  20251014
# ..                              ...       ...
# 95          blog.naver.com/staffs00  20251014
# 96            blog.naver.com/rct190  20251014
# 97        blog.naver.com/tkadla1422  20251014
# 98  blog.naver.com/lottotem_economy  20251014
# 99            blog.naver.com/mark-s  20251014
#
# [100 rows x 6 columns]

# %%
import re
def text_clean(text):
    # html 태그를 없애는 정규표현식
    result = re.sub(r"</?[^>]+>","",text)
    # 한글,영문,슷자 외의 모든 문자 제거 후 공백으로 변환
    result = re.sub(r"[^가-힣a-zA-Z0-9]"," ",result)
    result = result.replace("  "," ").replace("  "," ").replace("  "," ")
    return result

# %%
print(all_data[2])
# Out:
# [{'title': '기업은행, 정부의 금고이자 배당통로…밸류업 숨은 핵심주', 'link': 'https://blog.naver.com/kyending/224041737603', 'description': "최근에는 <b>핀테크</b> 제휴, AI 기반 신용평가 모델, 중소기업 전용 금융 플랫폼 등 디지털 전환에도 속도를 내고 있다. 전통적으로 정부와 산업은행, 수출입은행과 함께 '정책 3은행'으로 분류된다. 경쟁력... ", 'bloggername': '세상 돋보기 +0.75', 'bloggerlink': 'blog.naver.com/kyending', 'postdate': '20251015'}, {'title': '급전 필요할 땐? 2금융권 무서류 당일 대출, 똑똑하게 이용하는... ', 'link': 'https://blog.naver.com/kkimania/224041735668', 'description': '특히 토스와 같은 <b>핀테크</b> 플랫폼에서는 여러 2금융권의 대출 상품을 한눈에 비교하고 신청할 수 있어 편리합니다. 가정주부나 소득 증빙이 어려운 프리랜서도 신용카드 사용 내역 등을 통해 대출을 받을 수 있는... ', 'bloggername': 'kkimania님의블로그', 'bloggerlink': 'blog.naver.com/kkimania', 'postdate': '20251015'}, {'title': '대출 진행 시 필수 확인해야 할 금융정보 모음', 'link': 'https://sibauchi.tistory.com/1155', 'description': '<b>핀테크</b> 기업들은 AI 기반 신용 평가 모델을 개발하여 대출 심사의 정확성을 높이고, 맞춤형 대출 상품을 제공하는 데 주력하고 있습니다. 소비자들은 금리 변동에 대한 위험을 줄이기 위해 고정 금리 대출이나... ', 'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평", 'bloggerlink': 'https://sibauchi.tistory.com/', 'postdate': '20251015'}, {'title': '더존비즈온(Duzon Bizon) 기업분석 및 투자포인트', 'link': 'https://blog.naver.com/techjay/224041691443', 'description': '<b>핀테크</b>/데이터: 자동전표·매입/매출 수집, 기업 신용/데이터 서비스, 비용관리. 보안·인프라... 데이터·<b>핀테크</b> 연계: 금융기관/PG사·법인카드 데이터 연동으로 비용·정산 자동화와 현금흐름 가시성 개선... ', 'bloggername': 'TechTag', 'bloggerlink': 'blog.naver.com/techjay', 'postdate': '20251015'}, {'title': '엔젤로보틱스(55900) +17.74% 급등 - 소프트뱅크 ABB 로봇... ', 'link': 'https://blog.naver.com/ai_invest/224041726290', 'description': "금융위원회, '코리아 <b>핀테크</b> 위크 2025' 개최 ✅ 2025-12: '국제 AI 표준 서밋' 한국 개최 ✅ 2026-01-06: CES 2026(국제전자제품박람회) 개최 ▶ 투자 전략 ✅ 단기: 로봇 테마 모멘텀으로 단기 강세... ", 'bloggername': '미래투자랩', 'bloggerlink': 'blog.naver.com/ai_invest', 'postdate': '20251015'}, {'title': '[돈나무] “ChatGPT에서 바로 쇼핑한다! 월마트가 연 AI... ', 'link': 'https://blog.naver.com/kang760302/224041724293', 'description': '2% AI 커머스와 <b>핀테크</b> 융합 수혜 IBUY (Amplify Online Retail ETF) ETSY, MELI, EBAY, AMZN +6.5% ChatGPT 쇼핑 테마 수혜 가능 FDN (Internet Index ETF) META, GOOG, SHOP, AMZN +5.9% AI 검색과 커머스 융합형 ETF ETF... ', 'bloggername': '돈나무 Money Tree', 'bloggerlink': 'blog.naver.com/kang760302', 'postdate': '20251015'}, {'title': '햇살론15 특례보증 신청자격과 준비서류 완벽정리', 'link': 'https://think-tank.tistory.com/919', 'description': '은행들은 리스크 관리에 더욱 집중하며 대출 심사를 강화하는 추세이며, <b>핀테크</b> 기업들은 자체... 이를 해결하기 위해 정부는 금리 인하 및 신청 절차 간소화를 추진하고 있으며, <b>핀테크</b> 기업들은 온라인... ', 'bloggername': 'think-tank.tistory.com', 'bloggerlink': 'https://think-tank.tistory.com/', 'postdate': '20251015'}, {'title': '월마트, OpenAI와 손잡고 챗GPT에서 쇼핑 기능 제공', 'link': 'https://blog.naver.com/gatewaypla/224041720925', 'description': '외부 근거: 최근 금융권에서는 JP모건이 자체 AI 모델 개발과 동시에 다수의 AI <b>핀테크</b> 스타트업에 투자 및 파트너십을 체결하고 있으며, 미디어 분야에서는 AP통신, 악셀 스프링거 등이 OpenAI와 콘텐츠... ', 'bloggername': '인내와자유', 'bloggerlink': 'blog.naver.com/gatewaypla', 'postdate': '20251015'}, {'title': '토스뱅크 사장님 대출 금리 한도, 사업자 자격 총정리', 'link': 'https://ilovefamily.tistory.com/548', 'description': 'AI 기반 신용 평가 모델 도입, <b>핀테크</b> 기업과의 협력 강화, ESG 경영 확산 등이 주요 전략으로 꼽힙니다. 소비자는 금리 변동에 민감하게 반응하며, 정책 자금 활용과 <b>핀테크</b> 플랫폼 비교 분석을 통해 유리한 대출... ', 'bloggername': '과거,현재,미래, 그리고 나.', 'bloggerlink': 'https://ilovefamily.tistory.com/', 'postdate': '20251015'}, {'title': '케이뱅크 사업자대출 신청자격과 금리 혜택 총정리', 'link': 'https://sibauchi.tistory.com/1141', 'description': '그리고 <b>핀테크</b> 기업의 성장이라는 세 가지 주요 요인에 의해 크게 변화했습니다. 금리 인상은... 반면, 케이뱅크를 포함한 <b>핀테크</b> 기업들은 비대면 대출 서비스를 통해 접근성을 높이며 시장 점유율을... ', 'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평", 'bloggerlink': 'https://sibauchi.tistory.com/', 'postdate': '20251015'}, {'title': '아르헨티나 전력사 CEPU, OpenAI가 지원하는 데이터센터에... ', 'link': 'https://blog.naver.com/gatewaypla/224041718497', 'description': '클라우드 서비스의 품질 향상, 지연 시간(latency) 감소 등은 MercadoLibre의 이커머스 및 <b>핀테크</b> 사업 운영 효율성을 높이고 미래 성장을 위한 견고한 기반이 될 수 있습니다.', 'bloggername': '인내와자유', 'bloggerlink': 'blog.naver.com/gatewaypla', 'postdate': '20251015'}, {'title': '국제금융중심지 서울 도약 위한 전략과 금융 혁신 방안', 'link': 'https://blog.naver.com/new ...

# %%
df = pd.DataFrame(result)
df.to_csv("./data/02Requests모듈_dot_env를 사용해 네이버API에서 자료 수집하기.ipynb",index = False , encoding = 'utf-8-sig')

# %% [markdown]
# # python-dotenv로 api key 안전하게 사용하기
# * .env 파일에 환경변수를 저장하고 python 코드에서 자동으로 불러오는 모듈
# * pip install python-dotenv
# * .env 파일을 만들어서 변수=값 형태로 내용 저장
# ```python
# from dotenv import load_dotenv
# import os
#
# load_dotenv() # 같은 폴더에 .env 파일이 있을 경우 자동으로 불러옴
# # 환경변수 내용 출력
# user_id = os.getenv("Id")
# secret = os.getenv("Secret")
#
# ```
#
# # .env 경로를 다른 곳으로 주거나 이름을 바꾸고 싶을때
# * load_dotenv("경로및 파일명")
# ```python
# from dotenv import load_dotenv
# import os
#
# load_dotenv(dotenv_path="./data/.env_naver) # ./data 폴더에 .env_naver를 불러올 때
# # 환경변수 내용 출력
# user_id = os.getenv("Id")
# secret = os.getenv("Secret")
#
# ```

# %%
from dotenv import load_dotenv
import os
load_dotenv()

user_id = os.getenv("Id")
user_secret = os.getenv("Secret")
url = "https://openapi.naver.com/v1/search/blog"
keword= '핀테크'
payload = dict(query= keyword,display=100,start=1,sort="date")
headers = {'X-Naver-Client-Id' : user_id,"X-Naver-Client-Secret" : user_secret}
r = requests.get(url,params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
response
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 200
# {'lastBuildDate': 'Wed, 15 Oct 2025 09:06:22 +0900',
#  'total': 476972,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': 'NASA 차기 국장 인선 논란: 아이작먼, 혹독한 검증대에 오르다',
#    'link': 'https://blog.naver.com/gatewaypla/224041686083',
#    'description': '핵심 내용 요약 이 기사들은 <b>핀테크</b> 억만장자이자 민간 우주비행사인 **재러드 아이작먼(Jared Isaacman)**이 트럼프 행정부의 NASA(미 항공우주국) 차기 국장으로 재검토되는 과정과 그를 둘러싼 논란을... ',
#    'bloggername': '인내와자유',
#    'bloggerlink': 'blog.naver.com/gatewaypla',
#    'postdate': '20251015'},
#   {'title': '카카오뱅크 주가 – 스테이블코인, 플랫폼금융으로의 확장',
#    'link': 'https://blog.naver.com/2004speedboy/224041680434',
#    'description': '최근에는 단순 은행을 넘어 데이터 기반 플랫폼으로 확장하며, <b>핀테크</b> 산업 내에서도 독보적인... 09 서울 <b>핀테크</b> 위크에서 원화형 코인 중요성 강조 현재 국회에서는 스테이블코인 관련 법제화 논의가... ',
#    'bloggername': '전직 IR담당의 주식시황 분석',
#    'bloggerlink': 'blog.naver.com/2004speedboy',
#    'postdate': '20251015'},
#   {'title': '10/15(수)',
#    'link': 'https://blog.naver.com/oiq/224041677677',
#    'description': '참고로 PG/<b>핀테크</b>(밸류 회복) 쪽은 KG모빌리언스의 **’25E PER 7.9배(동종 평균 11.4배)**로 저평가 논지라 관찰 명단에 올려 둘 만합니다(단, 목표가는 리포트 부재). 3) 간밤 뉴스 &amp; 오늘 영향, 관련... ',
#    'bloggername': 'oiq님의 블로그',
#    'bloggerlink': 'blog.naver.com/oiq',
#    'postdate': '20251015'},
#   {'title': '해시태그 #급등예상 #장전뉴스 #반도체 #방산 #에너지 #ESS... ',
#    'link': 'https://blog.naver.com/romantist7711/224041676185',
#    'description': '---  ⑪ 스테이블코인 / 블록체인 스테이블코인 거래량 최대치 경신… 테더 200조 돌파 관련주: 아이티센글로벌, NAVER, NHN KCP, KG모빌리언스 ✅ 포인트: 가상자산 결제 시스템 고도화, 블록체인 기반 <b>핀테크</b>... ',
#    'bloggername': '경제&뉴스 주식_클리닉',
#    'bloggerlink': 'blog.naver.com/romantist7711',
#    'postdate': '20251015'},
#   {'title': 'IT 개발자를 노리는 해외 취업 사기, 이것만은 꼭 확인하세요',
#    'link': 'https://blog.naver.com/p_rich/224041674451',
#    'description': '업무 내용의 명확성 확인 직무 설명이 모호하거나 “블록체인 개발”, “<b>핀테크</b> 플랫폼 개발” 같은 포괄적인 용어만 사용하는 경우 주의하세요. 구체적으로 어떤 서비스를 개발하는지, 사용하는 기술 스택은... ',
#    'bloggername': 'David IT School',
#    'bloggerlink': 'blog.naver.com/p_rich',
#    'postdate': '20251015'},
#   {'title': '‘화폐 가치 하락(Debasement)’ 논쟁, 세계 금융 시장을... ',
#    'link': 'https://blog.naver.com/gatewaypla/224041673916',
#    'description': "특히, 자사의 <b>핀테크</b> 플랫폼인 '메르카도 파고(Mercado Pago)'를 통해 사용자들이 자국 통화의 가치 하락을 헤지할 수 있는 금융 솔루션(예: 달러 연동 디지털 자산 투자)을 제공하는 등, 이러한 환경을 비즈니스... ",
#    'bloggername': '인내와자유',
#    'bloggerlink': 'blog.naver.com/gatewaypla',
#    'postdate': '20251015'},
#   {'title': 'MOU vs LOI vs Agreement: 법적 구속력은 어디까지 미칠까?',
#    'link': 'https://blog.naver.com/legal_lemonade/224041674153',
#    'description': 'About the Authour 국내 대형은행 법무팀에서 10년 이상 국제금융, 신용장, 영문계약서 및 외국환규제 자문 등을 담당하고, <b>핀테크</b> 기업에서 해외 지급결제와 해외 진출 등 다양한 프로젝트를... ',
#    'bloggername': '리걸 레몬에이드',
#    'bloggerlink': 'blog.naver.com/legal_lemonade',
#    'postdate': '20251015'},
#   {'title': '농협카드 단기대출 급전 필요할 때 활용하는 방법',
#    'link': 'https://think-tank.tistory.com/893',
#    'description': '<b>핀테크</b> 기업들의 공세적인 마케팅과 간편한 대출 절차는 기존 금융권에 긴장감을 불어넣었으며, 플랫폼... 또한, <b>핀테크</b> 기업과의 경쟁 심화에 따른 과도한 마케팅 경쟁을 지양하고, 건전한 금융 생태계를... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '개인회생 면책후 신용카드 발급, 언제쯤 가능할까요?',
#    'link': 'https://blog.naver.com/dewnmp92606_gu/224019546885',
#    'description': '기존에 거래했던 주거래 은행부터 시작하여, 신용카드 발급에 비교적 관대한 조건을 가진 제2금융권, 혹은 일부 <b>핀테크</b> 기업들도 있습니다. 중요한 것은 본인의 현재 신용 상태를 정확히 파악하고, 그에 맞는... ',
#    'bloggername': '부적의 반려동물 일기',
#    'bloggerlink': 'blog.naver.com/dewnmp92606_gu',
#    'postdate': '20251015'},
#   {'title': '2025.10.15 -',
#    'link': 'https://blog.naver.com/gvox/224041667155',
#    'description': '오전 8:28 정호윤 한국투자증권 연구원은 &quot;네이버의 두나무 인수가 성공적으로 마무리될 경우 광고와 커머스에 치중되어 있던 네이버 사업에서 <b>핀테크</b>가 급부상할 것&quot;이라며 &quot;두나무의 거래소... ',
#    'bloggername': '사천도리',
#    'bloggerlink': 'blog.naver.com/gvox',
#    'postdate': '20251015'},
#   {'title': '디지털 금융과 경제범죄의 연결고리',
#    'link': 'https://blog.naver.com/hyeqe/224041664051',
#    'description': '모바일 뱅킹, 블록체인 기술, <b>핀테크</b> 플랫폼 등 다양한 혁신이 사용자에게 편리함을 제공하는 동시에... 경제범죄 #사이버범죄 #자금세탁 #비트코인 #사이버안전 #온라인거래 #피해예방 #보안대책 #<b>핀테크</b>',
#    'bloggername': 'hyeqe님의 블로그',
#    'bloggerlink': 'blog.naver.com/hyeqe',
#    'postdate': '20251015'},
#   {'title': '10월 15일(수) 장 시작 전 핵심 뉴스 브리핑 &amp; 관련주 총정리',
#    'link': 'https://blog.naver.com/engnia/224041663213',
#    'description': '✅ 관련주 다날: 써클 USDC 관련 온보딩 테스트 통과 NHN KCP, 미투온, 갤럭시아머니트리, 카카오페이 (간편결제 및 페이 관련주) 뱅크웨어글로벌, 쿠콘, 더존, 헥토파이낸셜 (<b>핀테크</b> 및 결제 인프라 관련주) 3.... ',
#    'bloggername': 'assetparking',
#    'bloggerlink': 'blog.naver.com/engnia',
#    'postdate': '20251015'},
#   {'title': '메리츠증권 채용, 최근 사회이슈 중 관심주제 자소서 작성법',
#    'link': 'https://blog.naver.com/thejasoseo/224040829075',
#    'description': '동시에 AI 기반 리스크 분석시스템, 디지털 자산 플랫폼 구축 등 <b>핀테크</b> 연계 투자금융 혁신에도 속도를 내고 있습니다. 결과적으로 중개형 증권사를 넘어, 자본시장 전 영역을 아우르는 투자금융... ',
#    'bloggername': '자소서번역기 ㅣ 저스펙취준생 전문 자기소개서 첨삭',
#    'bloggerlink': 'blog.naver.com/thejasoseo',
#    'postdate': '20251015'},
#   {'title': '여신전문금융회사 특성과 역할 및 최신 금융 서비스 동향 분석',
#    'link': 'https://blog.naver.com/avaidalabl3849/224041660698',
#    'description': '발맞춰 <b>핀테크</b> 기업들과 협력하여 혁신적인 금융 상품도 개발하고 있습니다. 이렇게 끊임없이 진화하는... 금융과 <b>핀테크</b> 협업 통한 혁신 여신전문금융회사는 단순한 금융회사를 넘어 우리의 경제 생활을 더욱... ',
#    'bloggername': '패션매거진',
#    'bloggerlink': 'blog.naver.com/avaidalabl3849',
#    'postdate': '20251015'},
#   {'title': '비상장주식★한패스 장외주식, 상장 예심 청구, 국내 외국인... ',
#    'link': 'https://blog.naver.com/xgfk0320/224041658811',
#    'description': '해외 송금 <b>핀테크</b>기업 코스닥 상장 예심 청구 2017년에 설립된 한패스는 외국인 대상 종합금융 플랫폼... 글로벌 금융 <b>핀테크</b> 기업 한패스는 가파른 성장세를 이어가고 있으며 이러한 성과는 중국, 베트남... ',
#    'bloggername': '드림 장외주식',
#    'bloggerlink': 'blog.naver.com/xgfk0320',
#    'postdate': '20251015'},
#   {'title': '3분기 은행들의 역대급 실적...그런데 뭔가 이상하다?',
#    'link': 'https://blog.naver.com/mananym3/224041657986',
#    'description': '✔️ <b>핀테크</b> 대출 플랫폼에서 대출 플랫폼, 그리고 은행에서 기관까지 리스크 전이 경로가 너무 복잡하다... 2008년 서브프라임때와 유사?  결론: 소비자 신용에 균열이 생겼다 은행 실적은 견고한 소비자 대출... ',
#    'bloggername': '포로리얌과 함께 부자되세요!(포부요!)',
#    'bloggerlink': 'blog.naver.com/mananym3',
#    'postdate': '20251015'},
#   {'title': '통장사본 모바일 발급 방법과 제출 시 유의사항 총정리',
#    'link': 'https://ilovefamily.tistory.com/541',
#    'description': '<b>핀테크</b> 기술 발전과 비대면 금융 서비스 확산에 힘입어 사용자 편의성이 극대화된 것이 주요... C <b>핀테크</b> 기업은 AI 기반의 이상 거래 탐지 시스템을 구축하여 금융 사기를 예방하고 있습니다. 문제점으로는 OCR... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': 'NAVER·카카오 리포트 분석 (2025.10.14 하나증권)',
#    'link': 'https://blog.naver.com/investock_/224041655721',
#    'description': 'NAVER: 안정적 성장 지속, AI·<b>핀테크</b> 확장 가속화 NAVER의 3분기 영업수익은 3조 443억 원으로 전년... 5% 유지 NAVER는 안정적인 이익 구조를 유지하면서도 AI·<b>핀테크</b> 인력 확대 및 연구개발 비용 집행을... ',
#    'bloggername': '내가 궁금한 이슈노트',
#    'bloggerlink': 'blog.naver.com/investock_',
#    'postdate': '20251015'},
#   {'title': '조심스레 전하는 마음 건강과 법 이야기',
#    'link': 'https://blog.naver.com/w0vlri9j/224041653678',
#    'description': '우선 ‘<b>핀테크</b>와 법’이라는 키워드가 요즘 많이 화두인데요, 금융과 기술의 융합을 뜻하는 <b>핀테크</b>는 우리의 생활 편리함을 크게 높여주지만 동시에 다양한 법적 문제도 함께 고민해야 하는 분야랍니다. 예를... ',
#    'bloggername': '명언 예술',
#    'bloggerlink': 'blog.naver.com/w0vlri9j',
#    'postdate': '20251015'},
#   {'title': '1억원 대출 이자 계산기 결과와 상환방법 확인',
#    'link': 'https://think-tank.tistory.com/871',
#    'description': '<b>핀테크</b> 기업들은 빅데이터 분석을 통해 개인별 맞춤형 금리 정보를 제공하고, 온라인 대출 플랫폼을... <b>핀테크</b> 기업들의 온라인 대출 플랫폼 확대로 인해 대출 상품 접근성이 높아지고, 개인 맞춤형 금리 정보... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '카카오뱅크, 중·저신용자에 15조원 돌파!',
#    'link': 'https://blog.naver.com/smallbusiness84/224041650079',
#    'description': '은행·<b>핀테크</b>사의 중·저신용 대출 진입 전략 ⸻  정리 요약 카카오뱅크는 출범 이후 약 8년간 중... 카카오뱅크스코어 #신용개선 #금융소외계층 #무수익여신 #<b>핀테크</b>대출 #네이버블로그경제 #금융트렌드',
#    'bloggername': '비즈니스 99개 만들기',
#    'bloggerlink': 'blog.naver.com/smallbusiness84',
#    'postdate': '20251015'},
#   {'title': 'nhn kcp',
#    'link': 'https://blog.naver.com/goodxgoodx/224041647978',
#    'description': '반등가자!! #스테이블코인 #블록체인테마주 #가상화폐관련주 #암호화폐수혜주 #디지털자산테마 #웹3관련주 #<b>핀테크</b>주 #전자결제관련주 #가상화폐보안주 #CBDC관련주',
#    'bloggername': '불기둥 차트',
#    'bloggerlink': 'blog.naver.com/goodxgoodx',
#    'postdate': '20251015'},
#   {'title': '25/10/14 [미국] 뉴스 및 특징주',
#    'link': 'https://blog.naver.com/moneyfreeway/224041646261',
#    'description': '■ 로빈후드 마켓츠(NASDAQ: HOOD) - <b>핀테크</b> 플랫폼 로빈후드는 예측시장 사업 확장 가능성이 제기되며 3% 하락했다. 로이터 통신은 &quot;로빈후드가 새로운 인수합병 기회를 검토 중&quot;이라고 전했다.... ',
#    'bloggername': 'Money의 freeway',
#    'bloggerlink': 'blog.naver.com/moneyfreeway',
#    'postdate': '20251015'},
#   {'title': '트윌리오(TWLO) 전망 | 기업과 고객을 메시지와 음성으로... ',
#    'link': 'https://blog.naver.com/happy_starbee/224041568202',
#    'description': '금융, <b>핀테크</b> JP모건, 잭헨리 등 보안 인증, 고객상담 자동화 금융 거래의 보안과 신뢰성이 생명이라 안전한 통신 채널이 필수 의료, 헬스케어 커뮤어 환자 예약 알림, 진료 상담 환자와의 소통 단절이 생명과... ',
#    'bloggername': '알파는올블루에있다',
#    'bloggerlink': 'blog.naver.com/happy_starbee',
#    'postdate': '20251015'},
#   {'title': '전세대출 DSR 포함 유력? 내 대출 한도 얼마나 줄까｜사례... ',
#    'link': 'https://blog.naver.com/jarita113/224041354594',
#    'description': '만기 6개월 이내 전세·주담대 보유자 1) 사전한도 조회(은행·<b>핀테크</b>) → 금리·만기·상환방식 바꿨을 때 한도 변동 비교 2) 보증 상품(HUG·HF·SGI) 변경 시 한도·요건 차이 확인 2. 다중대출 보유자(신용... ',
#    'bloggername': '사물에답',
#    'bloggerlink': 'blog.naver.com/jarita113',
#    'postdate': '20251015'},
#   {'title': "세계 시총 5위 솔라나 코인, '한국 원화'가 된다?",
#    'link': 'https://blog.naver.com/cider-economy/224041490604',
#    'description': '촉진하고, 우리의 금융 생활을 어떻게 바꾸어 놓을지 그 귀추가 주목됩니다. #솔라나 #원화스테이블코인 #스테이블코인 #웨이브릿지 #블록체인 #가상자산 #암호화폐 #디지털자산 #토큰화 #MMF #수이 #K금융 #<b>핀테크</b>',
#    'bloggername': '사이다경제',
#    'bloggerlink': 'blog.naver.com/cider-economy',
#    'postdate': '20251015'},
#   {'title': '서울대 컴퓨터공학과 – 인공지능 시대를 선도하는 기술의 심장',
#    'link': 'https://blog.naver.com/scnno8740/224040959808',
#    'description': '대기업 / 빅테크 기업 : 네이버, 카카오, 삼성전자, LG전자, SK C&amp;C, 현대오토에버 글로벌 테크 기업 : Google, Apple, Microsoft, Meta, Amazon 등 스타트업 및 창업 : AI 기반 서비스, <b>핀테크</b>, 로보틱스, 헬스케어 스타트업... ',
#    'bloggername': '과외는 여기서',
#    'bloggerlink': 'blog.naver.com/scnno8740',
#    'postdate': '20251015'},
#   {'title': '비바리퍼블리카 토스 대표 이승건 프로필 나이 고향 학력 경력',
#    'link': 'https://blog.naver.com/happyair4/224041624511',
#    'description': '제1대 한국<b>핀테크</b>산업협회 회장 2013.08.~ 비바리퍼블리카 대표 [수상] 2021 제2회 포니정 영리더상 2021 세계경제포럼 WEF 차세대 지도자 2018 제63회 정보통신의 날 대통령 표창 2014 청년기업인상... ',
#    'bloggername': '정치장인',
#    'bloggerlink': 'blog.naver.com/happyair4',
#    'postdate': '20251015'},
#   {'title': '금산분리 완화 수혜주 지금 주목해야 할 종목과 산업은?',
#    'link': 'https://blog.naver.com/necromance/224039291280',
#    'description': "문제는 앞서 말한 <b>핀테크</b> 기업들은 '산업자본'으로 분류되어 있어, 금융회사를 충분히 소유하거나... ▶ 플랫폼·<b>핀테크</b>(카카오, 네이버, 토스 등) 카카오뱅크, 네이버파이낸셜 등 기존 플랫폼 기업의 금융사업... ",
#    'bloggername': '써노',
#    'bloggerlink': 'blog.naver.com/necromance',
#    'postdate': '20251015'},
#   {'title': 'NH농협 디깅퀴즈 올원뱅크 10월 15일 7시 정답',
#    'link': 'https://blog.naver.com/chip8076/224041635578',
#    'description': '이는 사용자가 앱에 지속적으로 접속하고 참여하도록 유도하는 <b>핀테크</b> 기업의 전략적인 리워드 시스템입니다. 게임의 매력: 매일 일정 횟수 참여 가능하며, 성공 단계에 따라 차등적인 포인트가 지급됩니다.... ',
#    'bloggername': '똑답 - 똑똑한 돈버는 퀴즈정답 사이트',
#    'bloggerlink': 'blog.naver.com/chip8076',
#    'postdate': '20251015'},
#   {'title': '놀라운 연대 총동문회 회비',
#    'link': 'https://blog.naver.com/goldenmean161/224041634127',
#    'description': '그러면서 &quot;회비로 받은 가상자산의 현금화와 회계 처리는 <b>핀테크</b> 기업 웨이브릿지의 자문을 받아 해결할 계획&quot;이라고 덧붙였다. 3 총동문회비를 암호화폐로 받겠다는 것은 그동안 의심스러웠던... ',
#    'bloggername': '숫자로 보는 세계',
#    'bloggerlink': 'blog.naver.com/goldenmean161',
#    'postdate': '20251015'},
#   {'title': '햇살론 유스 추가대출 신청자격과 후기 모음',
#    'link': 'https://sibauchi.tistory.com/1090',
#    'description': '<b>핀테크</b> 기업들과의 협력을 통해 온라인 신청 절차가 더욱 간편해지고, 다양한 금융 교육 프로그램과... 향후 햇살론 유스는 <b>핀테크</b> 기술과의 융합을 통해 더욱 편리하고 효율적인 대출 서비스로 발전할 가능성이... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '2금융권 대출 상품 – 직장인·무직자 후기 및 맞춤정리',
#    'link': 'https://blog.naver.com/magok8319/224041300255',
#    'description': '소액 비상금대출 <b>핀테크</b> 기반으로 간단하게 신청 가능. 다만 금리는 다소 높은 편. 보증인 대출 가족, 지인을 보증인으로 설정하면 승인 가능성 상승. 제가 아는 한 지인은 차량을 담보로 무직 상태에서도 1,000만... ',
#    'bloggername': '브라보금융',
#    'bloggerlink': 'blog.naver.com/magok8319',
#    'postdate': '20251015'},
#   {'title': '신한카드 단기대출 신청방법과 한도 확인하기',
#    'link': 'https://sibauchi.tistory.com/1158',
#    'description': '숨 가쁘게 달려온 1년, 앞으로 <b>핀테크</b> 단기 대출 시장은? 📈 지난 1년간 신용카드 단기 대출 시장은 <b>핀테크</b> 기업의 성장과 함께 빠르게 변화해왔습니다. 특히, 빅데이터 기반의 신용평가 모델 도입으로 인해 기존... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '따뜻한 워크숍 AI와 블록체인을 결합한 세계 최초의 실용형... ',
#    'link': 'https://blog.naver.com/dongsn1004/224041630752',
#    'description': '및 <b>핀테크</b> 플랫폼입니다. 주요 특징은 다음과 같습니다: 블록체인 기반 플랫폼: 커머스 기능과... 0 기반의 <b>핀테크</b> 커머스 플랫폼입니다. 표범신동선 #AI-ZIO는 아멕스지그룹(AMAXG) 최정무 회장이 주도하여... ',
#    'bloggername': 'dongsn1004님의블로그',
#    'bloggerlink': 'blog.naver.com/dongsn1004',
#    'postdate': '20251015'},
#   {'title': 'KB국민은행 KB스타뱅킹 스타퀴즈 정답 10월 15일 7시',
#    'link': 'https://blog.naver.com/chip8076/224041628874',
#    'description': '금융 서비스의 확장: KB스타뱅킹은 금융 정보 외에도 경제, 산업 전반의 지식을 제공하며 고객의 지적 만족도를 높이고, <b>핀테크</b>, 모빌리티 등 신기술과 연계된 새로운 금융 서비스의 접점을 넓히고 있습니다.... ',
#    'bloggername': '똑답 - 똑똑한 돈버는 퀴즈정답 사이트',
#    'bloggerlink': 'blog.naver.com/chip8076',
#    'postdate': '20251015'},
#   {'title': '투자레터 | ARKF ETF, 코인 투자는 무섭지만 기회는 잡고 싶다면',
#    'link': 'https://blog.naver.com/6606__/224041098098',
#    'description': "전통 금융시장 뺨아리 뚜까 날릴 수 있는 혁신 <b>핀테크</b> 기업만 골라 담았다, 이말이야. 근데 이제... 은 당연히 아니고 <b>핀테크</b>의 'F'. (Fintech) 돈나무 누나의 상품답게 '혁신기업'만 담긴만큼 분배금 따윈... ",
#    'bloggername': '몽근이',
#    'bloggerlink': 'blog.naver.com/6606__',
#    'postdate': '20251015'},
#   {'title': '2026년 일본 <b>핀테크</b> 혁신, 변화의 서막',
#    'link': 'https://blog.naver.com/suited4853/224041624710',
#    'description': '2026년 일본 <b>핀테크</b> 혁신은 기술 발전과 소비자 변화, 정책 지원이 어우러져 새로운 지평을 열 것으로 기대됩니다. 이 글에서는 일본 <b>핀테크</b>의 현재 상황과 미래 전망을 심도 있게 살펴보겠습니다. 일본의 <b>핀테크</b>... ',
#    'bloggername': '퀸세일NOW',
#    'bloggerlink': 'blog.naver.com/suited4853',
#    'postdate': '20251015'},
#   {'title': '국민은행 사잇돌 대출조건과 한도 확인하기',
#    'link': 'https://sibauchi.tistory.com/1154',
#    'description': '📈 하지만 정부의 서민 금융 지원 정책 강화, <b>핀테크</b> 기업의 시장 진출 등 긍정적인 변화도 감지됩니다. 주요 은행들은 디지털 플랫폼을 활용한 대출 상품 개발, 비대면 심사 강화 등 경쟁력 확보에 주력할... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '2025년 한국인들이 가장 많이 매수한 미국주식 TOP10',
#    'link': 'https://blog.naver.com/gr1328/224041619876',
#    'description': '2025년 한국인 순매수 미국주식 TOP20 순위 코드 종목명 유형 1 UNH 유나이티드헬스 그룹 헬스케어 주식 2 CRCL 서클 인터넷 그룹 <b>핀테크</b> 주식 3 TSLL 테슬라 2배 레버리지 ETF 레버리지 ETF 4 SCHD 슈왑 미국... ',
#    'bloggername': '오늘도 경제 한 줌',
#    'bloggerlink': 'blog.naver.com/gr1328',
#    'postdate': '20251015'},
#   {'title': '국민은행 KB국민ONE대출 자격조건과 금리 총정리',
#    'link': 'https://think-tank.tistory.com/869',
#    'description': '<b>핀테크</b> 기업들의 금융 시장 진출 확대는 경쟁 심화를 가져오겠지만, 동시에 새로운 대출 상품 및 서비스 개발을 촉진할 것입니다. 주요 은행들은 디지털 전환 가속화, 맞춤형 상품 개발, 그리고 리스크 관리... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '브랜드와 일상의 만남: 어떤 제품이 우리의 삶을 개선할까?',
#    'link': 'https://blog.naver.com/tmduynyx606/224041616430',
#    'description': '<b>핀테크</b> 기업들의 등장으로 인해 우리는 금융 거래를 훨씬 더 간편하게 처리할 수 있게 되었습니다. 모바일 뱅킹 앱이나 결제 시스템은 언제 어디서나 빠르고 안전하게 금융 업무를 볼 수 있도록 지원합니다. 이는... ',
#    'bloggername': '행복의 지도',
#    'bloggerlink': 'blog.naver.com/tmduynyx606',
#    'postdate': '20251015'},
#   {'title': '미국·영국, 캄보디아발 ‘온라인 사기 산업’에 동시... ',
#    'link': 'https://blog.naver.com/j3837/224041615006',
#    'description': '② 기업(<b>핀테크</b>·수출입·가상자산업) 리스크 관리 제재 스크리닝 고도화: 상대방·수취인·UBO에 Prince Group/Chen Zhi/Huione 연계성 점검. KYT/트래블룰 업데이트: 캄보디아·미얀마 라우팅, 의심 지갑... ',
#    'bloggername': '최고의 선택.',
#    'bloggerlink': 'blog.naver.com/j3837',
#    'postdate': '20251015'},
#   {'title': '미래에셋증권 “가상자산 기대감·지배구조 개편으로 업종 내... ',
#    'link': 'https://blog.naver.com/sgpjb1/224041609484',
#    'description': '가상자산·<b>핀테크</b> 시장 진출의 기폭제로 기대됩니다.  한 줄 정리 “KOSPI 4,000 시대, 미래에셋은... 해시태그 #미래에셋증권 #증권업종 #가상자산 #<b>핀테크</b> #네이버파이낸셜 #두나무 #자사주소각... ',
#    'bloggername': '그리드_토선생_밝은 황소',
#    'bloggerlink': 'blog.naver.com/sgpjb1',
#    'postdate': '20251015'},
#   {'title': '아이 용돈 통장, 아직도 은행 가서 만드시나요? 스마트폰으로... ',
#    'link': 'https://blog.naver.com/zzondd/224033774374',
#    'description': '대부분의 은행과 <b>핀테크</b> 앱에서 부모가 법정대리인 자격으로 자녀의 계좌를 비대면으로 개설할 수 있게 되었습니다. 제가 비대면 방식을 강력하게 추천하는 이유는 단 하나, ‘압도적인 시간 효율성’... ',
#    'bloggername': '로안의 누리집',
#    'bloggerlink': 'blog.naver.com/zzondd',
#    'postdate': '20251015'},
#   {'title': '미국 증시 : 월마트 폭등, 엔비디아 급락… 실적장이 던진 신호!',
#    'link': 'https://blog.naver.com/gdhksj/224041606096',
#    'description': '가상자산·<b>핀테크</b> 타격  긍정 요인 - 파월의 유동성 시그널 → 외국인 자금 유입 기대 - 러셀·다우 상승 → 경기민감·소형주 반등 가능성  KOSPI 야간선물 (+0.27%)  MSCI 한국 ETF (-1.11%) 전반적으로 장 초반은... ',
#    'bloggername': '오십 년을 더 살자(건강, 돈, 행복)의 비밀',
#    'bloggerlink': 'blog.naver.com/gdhksj',
#    'postdate': '20251015'},
#   {'title': '2024년 핵심 테마주와 투자 전략 분석',
#    'link': 'https://blog.naver.com/pokqygo0u1885fa/224041604668',
#    'description': '온라인 커머스, 디지털 콘텐츠, <b>핀테크</b> 기업들은 아직도 성장의 싹을 틔우는 단계입니다. 특히, ‘디지털 전환’이라는 말을 빼고는 요즘 시장을 이야기하기 어렵겠죠? 투자 전략으로는 플랫폼과 생태계를... ',
#    'bloggername': '촉감 폴록',
#    'bloggerlink': 'blog.naver.com/pokqygo0u1885fa',
#    'postdate': '20251015'},
#   {'title': '[2025.10.15 수] 오늘의 정책 시그널 요약',
#    'link': 'https://blog.naver.com/policyintel/224041604171',
#    'description': '→ 【<b>핀테크</b>/암호화폐】 수혜 ③ 2023년 10월 15일, 한국 정부는 탄소중립 목표 달성을 위해... → 【에너지/친환경】 수혜 〔핵심 섹터〕 해운/물류 · <b>핀테크</b>/암호화폐 · 에너지/친환경 〔주목... ',
#    'bloggername': 'policy Intel',
#    'bloggerlink': 'blog.naver.com/policyintel',
#    'postdate': '20251015'},
#   {'title': '25년 10월 15일 경제 방송 추천종목',
#    'link': 'https://blog.naver.com/andantehonga/224041603183',
#    'description': '실적 금거래호실적기대 20500 27000 19000 아톤 보안 <b>핀테크</b> 보안전문 스테이블코인 9500 6800 엘앤에프 양극재 lfp확대 ess 흑자기대 82500 105000 69000 두산에너빌리티 90000 67000',
#    'bloggername': 'andantehonga님의 블로그',
#    'bloggerlink': 'blog.naver.com/andantehonga',
#    'postdate': '20251015'},
#   {'title': '고령자도 가능한 100만 원 대출 자금 마련 방법',
#    'link': 'https://blog.naver.com/magok8319/224037986244',
#    'description': '모바일 소액 지원 서비스 카카오뱅크, 토스뱅크, 핀크 등 <b>핀테크</b> 기반 비상금 상품은 고령자도 모바일 인증만으로 신청이 가능합니다. 대부분 통신요금 납부 이력 등으로 간편 심사가 이루어지며, 100만 원 이하... ',
#    'bloggername': '브라보금융',
#    'bloggerlink': 'blog.naver.com/magok8319',
#    'postdate': '20251015'},
#   {'title': '근로장려금 수급자를 위한 맞춤형 대출 종류 총정리',
#    'link': 'https://think-tank.tistory.com/907',
#    'description': '강화, <b>핀테크</b> 기업의 등장 등 다양한 요인으로 인해 빠르게 변화하고 있습니다. 특히, 저금리 시대가... 또한, <b>핀테크</b> 기업들은 빅데이터 분석과 AI 기술을 활용하여 개인별 맞춤형 대출 상품을 추천하고, 온라인... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '양자컴퓨터 관련주 및 미래 전망 – 유망 종목 투자 가이드',
#    'link': 'https://blog.naver.com/gaogaiga13/224041062274',
#    'description': '1. 양자컴퓨터란? 양자컴퓨터는 양자역학 원리를 활용해 기존 컴퓨터가 수행하기 어려운 복잡한 계산을 빠르게 처리하는 차세대 첨단 기술입니다. 일반 컴퓨터가 0 또는 1의 비트를 사용하는 반면... ',
#    'bloggername': '3년1억',
#    'bloggerlink': 'blog.naver.com/gaogaiga13',
#    'postdate': '20251015'},
#   {'title': '테크메이트코리아대부 대출상품 자격조건 정리',
#    'link': 'https://think-tank.tistory.com/870',
#    'description': '향후 1-2년 동안은 고금리 기조가 유지될 것으로 예상되며, <b>핀테크</b> 기술의 발달과 함께 온라인 대출... 향후, <b>핀테크</b> 기술을 활용한 맞춤형 대출 상품 개발, AI 기반의 리스크 관리 시스템 구축 등을 통해 대출... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '25년 10월 15일 미증시) 파월 QT중단 시사로 반등 … 트럼프... ',
#    'link': 'https://blog.naver.com/heavenrise/224041594805',
#    'description': '80%): Wecan 협력으로 양자 내성 고객 확인 제도 관련 솔루션 개발 계획 발표에 폭등 암호화폐·<b>핀테크</b> 비트코인: 미-중 갈등 재부상과 미 상원 암호화폐 규제법안(RFIA) 민주당 수정안 제출로 교착상태... ',
#    'bloggername': 'H E A V E N',
#    'bloggerlink': 'blog.naver.com/heavenrise',
#    'postdate': '20251015'},
#   {'title': '흥미진진한 법률 이야기 <b>핀테크</b>, 환경 소송, 분쟁 예방',
#    'link': 'https://blog.naver.com/gyygn/224041591422',
#    'description': '흥미진진한 법률 이야기 <b>핀테크</b>, 환경 소송, 분쟁 예방 흥미진진한 법률 이야기 <b>핀테크</b>, 환경 소송, 분쟁 예방 <b>핀테크</b>와 법, 디지털 금융의 그림자 새로운 시대, <b>핀테크</b>는 혁신과 동시에 법적 도전을 안고... ',
#    'bloggername': '하늘사랑',
#    'bloggerlink': 'blog.naver.com/gyygn',
#    'postdate': '20251015'},
#   {'title': '당일 대출, 손쉽게 가능할까? 급한 자금이 필요할 때 꼭 알아야... ',
#    'link': 'https://blog.naver.com/cityload3/224041591632',
#    'description': '<b>핀테크</b>, P2P 대출 플랫폼 모바일 비대면 심사로 즉시 승인되는 소액대출 상품이 많으나, 대출 한도는... 또는 <b>핀테크</b>가 실제 선택지가 됩니다. 그렇지만 소액 당일 대출은 경우에 따라 금리가 매우 높아요. 특히... ',
#    'bloggername': '야옹이의 경제스토리',
#    'bloggerlink': 'blog.naver.com/cityload3',
#    'postdate': '20251015'},
#   {'title': "&quot;국민 대다수의 목소리가 반영되어야 하기 때문에 '금융도 곧... ",
#    'link': 'https://blog.naver.com/agasesu7/223871597543',
#    'description': '김은혜의 바이든 날리면 시즌 2 [팟빵] 매불쇼 ’관광업 큰 손’ 중국인들, 황금연휴 중동에 ’우르르’ CityTimes - (출처:Pixabay) [시티타임스=중국/일본] 최근 수많은 중국인 여행객들이 중동으로 떠나는 등... ',
#    'bloggername': '사회권 강국',
#    'bloggerlink': 'blog.naver.com/agasesu7',
#    'postdate': '20251015'},
#   {'title': '<b>핀테크</b> 관련주 IT 주식 SK 한국정보인증 네이버 주가',
#    'link': 'https://blog.naver.com/owls3753/224041197178',
#    'description': '<b>핀테크</b> 관련주 종류 및 순위 안녕하세요, 부엉이입니다. 오늘은 국내 상장 금융 IT... <b>핀테크</b> 관련주 종류 및 주가 순위 종목명 주가 네이버 258,000 SK 222,000 카카오 59,600 코나아이 51... ',
#    'bloggername': '부엉이와 함께하는 투자 정보',
#    'bloggerlink': 'blog.naver.com/owls3753',
#    'postdate': '20251015'},
#   {'title': '키위 대출 간편 신청방법과 비상금대출 조건 확인',
#    'link': 'https://think-tank.tistory.com/889',
#    'description': '격동의 금융 지형: 키위 대출, 1년의 발자취와 미래 전망 📈 지난 1년간 키위 대출을 포함한 비상금 대출 시장은 금리 인상, 경기 침체 우려, 그리고 <b>핀테크</b> 기업들의 경쟁 심화 등 다양한 요인에 의해 끊임없이... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '10/14 미국 마감시황',
#    'link': 'https://blog.naver.com/dbgbks123/224041583072',
#    'description': '▶ 크립토·<b>핀테크</b> 비트코인 관련주: 하락장 속에도 일부 AI 전환주 상승 — IREN(+10%), CLSK(+11%), WULF(+14%). IREN: 목표가 49달러 → 100달러로 상향(Cantor). WULF: 32억달러 회사채 발행 통해 뉴욕... ',
#    'bloggername': 'DB증권 글로벌',
#    'bloggerlink': 'blog.naver.com/dbgbks123',
#    'postdate': '20251015'},
#   {'title': 'LS에코에너지 목표 주가 전망: 동남아 데이터센터 버스덕트... ',
#    'link': 'https://blog.naver.com/money_graphy/224041453507',
#    'description': '폭발적으로 성장 중인 동남아 데이터센터 시장 동남아는 지금 클라우드·<b>핀테크</b>·AI 산업 확산으로 전력 인프라 수요가 급증하는 지역입니다. 특히 베트남은 외국계 기업의 데이터센터 100% 소유 허용으로... ',
#    'bloggername': '머니스케치',
#    'bloggerlink': 'blog.naver.com/money_graphy',
#    'postdate': '20251015'},
#   {'title': '케이뱅크 신용대출 비대면 신청방법과 후기',
#    'link': 'https://sibauchi.tistory.com/1143',
#    'description': '주요 시중은행들은 리스크 관리를 강화하며 대출 심사를 더욱 깐깐하게 진행하고 있으며, <b>핀테크</b>... <b>핀테크</b> 기업들은 AI 기반 신용평가 모델을 고도화하여 리스크 관리 능력을 강화하고, 맞춤형 대출 상품을... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '신용카드한도 백화점 상품권현금화 할부 결제 이용 정보',
#    'link': 'https://blog.naver.com/hdhddhddd/224041578951',
#    'description': '<b>핀테크</b> 분야는 그야말로 넓은 바다와 같습니다. 가상화폐부터 부동산까지 다양한 영역을 포함하고... 폭풍우 속에서도 항해를 이어가는 배처럼 기준금리 인상과 불확실한 전망 속에서도 <b>핀테크</b> 분야는 성장세를... ',
#    'bloggername': '딩딩이의 먹방 만년 다이어리',
#    'bloggerlink': 'blog.naver.com/hdhddhddd',
#    'postdate': '20251015'},
#   {'title': '<b>핀테크</b>, 안전, 성희롱! 법이 우리 생활 깊숙이?',
#    'link': 'https://blog.naver.com/bil435dc/224041577161',
#    'description': '<b>핀테크</b>, 안전, 성희롱! 법이 우리 생활 깊숙이? <b>핀테크</b>, 안전, 성희롱! 법이 우리 생활 깊숙이? <b>핀테크</b>와 법, 디지털 금융의 안전지킴이 혹시, <b>핀테크</b>가 세상을 바꿀 거라는 상상해 보셨나요? <b>핀테크</b>는 편리하지만... ',
#    'bloggername': '산책과 함께하는 자연 속 발걸음',
#    'bloggerlink': 'blog.naver.com/bil435dc',
#    'postdate': '20251015'},
#   {'title': '우즈베키스탄 우체국 대전환: 15억 달러 투자 유치전의 숨겨진... ',
#    'link': 'https://blog.naver.com/uzinfo82/224041552113',
#    'description': "3,500개 우체국, 7,000명 직원, 전국을 연결하는 25개 항공 노선. 우즈베키스탄의 국영 우편 사업자 O'zbekiston pochtasi(오즈베키스톤 포흐타시, 이하 우즈포스트)가 서 있는 지금 이 순간은 33년 역사의... ",
#    'bloggername': '우즈베키스탄 정보마당',
#    'bloggerlink': 'blog.naver.com/uzinfo82',
#    'postdate': '20251015'},
#   {'title': '[카카오페이] IT 자체감사 담당자 - IT 진단',
#    'link': 'https://blog.naver.com/infosec-license/224039512915',
#    'description': '원활한 커뮤니케이션과 효과적인 협업 및 문제해결 능력을 갖추신 분이면 더 좋아요. 금융/<b>핀테크</b>/전자금융업 IT환경에 대한 이해가 높으신 분이면 더 좋아요. https://kakaopay.career.greetinghr.com/ko/o/162177',
#    'bloggername': '[씨큐공] 정보보호 공부하기',
#    'bloggerlink': 'blog.naver.com/infosec-license',
#    'postdate': '20251015'},
#   {'title': '정부24 4대보험 가입내역서 발급 방법과 인증서 이용법',
#    'link': 'https://ilovefamily.tistory.com/525',
#    'description': '<b>핀테크</b>, AI, 블록체인 등 다양한 기술이 사회 전반에 걸쳐 빠르게 확산되고 있으며, 정부 서비스 또한 예외는 아닙니다. 특히, 코로나19 팬데믹 이후 비대면 서비스에 대한 수요가 폭발적으로 증가하면서... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '2025년 10월15일 미국증시 핵심 이슈 총정리',
#    'link': 'https://blog.naver.com/donglpc/224041570732',
#    'description': '가능성: <b>핀테크</b> 업계 일부: 경쟁 심화 + 규제 리스크 대응 전략: 기본: 관련 금융주 콜 스프레드 혹은... vs <b>핀테크</b> 상대강도 재편 배경: 전통 금융 실적 회복 + <b>핀테크</b> 신용리스크 우려 영향: 스타일... ',
#    'bloggername': '산골에서 투자하기',
#    'bloggerlink': 'blog.naver.com/donglpc',
#    'postdate': '20251015'},
#   {'title': 'RWA코인 정리 DB',
#    'link': 'https://blog.naver.com/allinbudongsan/224041570283',
#    'description': '간단하고 낮은 수수료로 토큰을 발행하고 거래할 수 있어 소규모 금융 기관 및 <b>핀테크</b>의 RWA... 복잡한 DeFi보다는 간단하고 규제 친화적인 증권형 토큰 발행 및 유통에 최적화되어, <b>핀테크</b> 기업의... ',
#    'bloggername': '집캔디의올인부동산',
#    'bloggerlink': 'blog.naver.com/allinbudongsan',
#    'postdate': '20251015'},
#   {'title': '끝까지 생존할 수밖에 없는 코인에 투자할 것.',
#    'link': 'https://blog.naver.com/hg6918/224041569086',
#    'description': '쪽과 <b>핀테크</b> 쪽에 막대한 자금을 불어넣겠다 이렇게 말하고 있죠 이 벤처 캐피탈 같은 경우는 연평균 내부 수익률 ir라는 한 18% 정도 되는 굉장히 높은 승리를 자랑하는 벤처 캐피탈인데요 그 직원 마른... ',
#    'bloggername': 'Jesus is coming soon',
#    'bloggerlink': 'blog.naver.com/hg6918',
#    'postdate': '20251015'},
#   {'title': '토스뱅크 생활비대출 신청방법과 금리 이용후기 확인',
#    'link': 'https://sibauchi.tistory.com/1108',
#    'description': '<b>핀테크</b> 기업들은 데이터 기반 신용 평가 모델을 고도화하여 리스크 관리를 강화하고, 맞춤형 대출... 주요 은행들은 디지털 전환 가속화와 함께 <b>핀테크</b> 기업과의 협력을 강화하고 있습니다. 카카오뱅크는 생활... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '에이원 대부 대출 신청자격과 한도 조건 꼼꼼히 확인하세요',
#    'link': 'https://sibauchi.tistory.com/1111',
#    'description': '주요 기업들은 리스크 관리 강화와 함께 <b>핀테크</b> 기업과의 협력을 통해 새로운 성장 동력을 확보하려 할 것입니다. 소비자들은 보다 편리하고 안전한 대출 서비스를 선호하며, 개인 정보 보호에 대한 요구가 더욱... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '신한은행 생활비대출 신청자격과 금리조건 총정리',
#    'link': 'https://think-tank.tistory.com/903',
#    'description': '여기에 더해, <b>핀테크</b> 기업들의 약진은 기존 금융권에 경쟁 심화를 가져왔고, 다양한 대출 상품 출시로... 주요 은행들은 디지털 전환 가속화, <b>핀테크</b> 기업과의 협력 강화, ESG 경영 도입 등을 통해 경쟁력 확보에... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': "하루레포트('25.10.14.)",
#    'link': 'https://blog.naver.com/zoogong_/224041566378',
#    'description': '전망) <b>핀테크</b>는 외부결제액 증가로 견조한 흐름**(두나무 합병 시 영업이익 약 44% 증가 추정)** 광고는 추석 전 선집행 효과로 예상보다 양호했으나, GPU·AI 투자비 및 인력 확충에 따른... ',
#    'bloggername': '영리한 주공일기',
#    'bloggerlink': 'blog.naver.com/zoogong_',
#    'postdate': '20251015'},
#   {'title': '자산비율과 혁신의 융합 사례 새로운 금융 패러다임',
#    'link': 'https://blog.naver.com/fis-ru-x/224027884957',
#    'description': '요즘 자산비율과 혁신의 융합 사례가 정말 눈에 띄게 늘어난 것 같지 않아 친구도 공감하며 맞아 특히 금융기술 <b>핀테크</b> 덕분에 자산관리 방식이 완전히 달라졌잖아라고 했어요. 그래서 문득 자산비율과 혁신의... ',
#    'bloggername': '붉은 카펫',
#    'bloggerlink': 'blog.naver.com/fis-ru-x',
#    'postdate': '20251015'},
#   {'title': '우체국보험 환급금 대출 신청조건과 이용시간 안내',
#    'link': 'https://sibauchi.tistory.com/1097',
#    'description': '환급금 대출, 격변의 시대: 시장 변화와 미래 예측 📈 최근 1년간 우체국보험 환급금 대출 시장은 금리 변동, 금융 규제 강화, 그리고 <b>핀테크</b> 기업의 진입이라는 삼중고를 겪었습니다. 특히, 금리 인상은 대출... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '<b>핀테크</b>와 법률의 조화로 지키는 건강한 생활관리 전략',
#    'link': 'https://blog.naver.com/kdtwyfz75g4ro-/224041557192',
#    'description': '<b>핀테크</b>와 법률의 조화로 지키는 건강한 생활관리 전략 <b>핀테크</b>와 법률의 조화로 지키는 건강한 생활관리 전략 현대 사회에서는 금융 기술, 즉 <b>핀테크</b>가 빠르게 발전하면서 관련 과 규제에 대한 이해가 더욱... ',
#    'bloggername': '기분이피곤해',
#    'bloggerlink': 'blog.naver.com/kdtwyfz75g4ro-',
#    'postdate': '20251015'},
#   {'title': '한국 금융시장의 향후 전망과 전략 분석',
#    'link': 'https://blog.naver.com/sharpedges/224041549390',
#    'description': '신생 <b>핀테크</b> 기업들이 전통적인 금융기관을 위협하는 상황 속에서, 기존 회사들은 어떻게 혁신을 이뤄낼 것인지가 관건이죠. 적절한 규제와 경쟁의 공존이 이끄는 건강한 시장 생태계를 조성하는 것이 핵심... ',
#    'bloggername': '뒤샹의 흔들림',
#    'bloggerlink': 'blog.naver.com/sharpedges',
#    'postdate': '20251015'},
#   {'title': '신한 쏠편한 비상금대출 신청 절차와 실제 이용 후기',
#    'link': 'https://sibauchi.tistory.com/1112',
#    'description': '강화, <b>핀테크</b> 기업의 적극적인 참여 등 다양한 요인으로 인해 역동적인 변화를 겪었습니다. 특히 금리 인상은 소비자들의 대출 부담을 가중시켰고, 정부의 대출 규제는 대출 문턱을 높였습니다. 반면, <b>핀테크</b>... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '우리카드론 신청조건과 한도 금리 총정리',
#    'link': 'https://think-tank.tistory.com/873',
#    'description': '또한, <b>핀테크</b> 기업과의 협력을 통해 더욱 편리하고 혁신적인 서비스를 제공할 것으로 기대됩니다. 9. 우리카드론 활용 팁 💡: 현명한 사용자를 위한 지침 우리카드론을 실제로 적용한 사례를 살펴보면, 급하게... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '앤픽몰 사기 사칭 쇼핑몰팀미션 대응방법은',
#    'link': 'https://blog.naver.com/mgreatmaild18/224041142593',
#    'description': '대응방법은 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw',
#    'bloggerlink': 'blog.naver.com/mgreatmaild18',
#    'postdate': '20251015'},
#   {'title': 'MarketBRIDGE 사기 마켓브릿지 사칭 팀미션부업 피해 주의보',
#    'link': 'https://blog.naver.com/ickkoju2/224041354349',
#    'description': '주의보 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이법률사무소',
#    'bloggerlink': 'blog.naver.com/ickkoju2',
#    'postdate': '20251015'},
#   {'title': '하나은행 징검다리론 한도와 금리 신청조건 총정리',
#    'link': 'https://sibauchi.tistory.com/1130',
#    'description': '또한, <b>핀테크</b> 기업과의 협력을 통해 온라인 플랫폼을 강화하고, 사용자 편의성을 높이는 방향으로... 또한, <b>핀테크</b> 기업과의 협력을 통해 온라인 플랫폼을 강화하고, 사용자 편의성을 높이는 방향으로 발전할... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '신한저축은행 참신한500 대출 조건 자격 한도 알아보기',
#    'link': 'https://think-tank.tistory.com/882',
#    'description': '💰🏦 신한저축은행 참신한500 대출, <b>핀테크</b> 시대의 현명한 선택일까? 최근 고금리 시대가 지속되면서... 경쟁 상품으로는 <b>핀테크</b> 기업의 소액 대출 상품들이 있으며, 이들은 참신한500과 유사한 간편한 절차와... ',
#    'bloggername': 'think-tank.tistory.com',
#    'bloggerlink': 'https://think-tank.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '<b>핀테크</b>, 공익, 재판 법의 미묘한 균형과 우리의 책임',
#    'link': 'https://blog.naver.com/lovedme1046/224041528341',
#    'description': '<b>핀테크</b>, 공익, 재판 법의 미묘한 균형과 우리의 책임 <b>핀테크</b>, 공익, 재판 법의 미묘한 균형과 우리의 책임 <b>핀테크</b>와 법, 혁신의 날개를 펴다 새로운 <b>핀테크</b> 기술이 세상을 바꿀 준비를 하고 있지만, 법이라는... ',
#    'bloggername': 'lovedme1046님의 블로그',
#    'bloggerlink': 'blog.naver.com/lovedme1046',
#    'postdate': '20251015'},
#   {'title': '기업은행 대출상품 한도 금리와 신청조건 정리',
#    'link': 'https://sibauchi.tistory.com/1150',
#    'description': '또한, <b>핀테크</b> 기업들의 대출 시장 진출이 활발해지면서 경쟁이 심화되고, 소비자들은 더욱 다양한... 향후 대출 시장은 디지털 전환과 <b>핀테크</b> 기술의 발전으로 인해 더욱 편리하고 다양한 상품과 서비스를... ',
#    'bloggername': "Falconer's Teatime :: 이제는 말하고 말겠다-라멘토 비평",
#    'bloggerlink': 'https://sibauchi.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '우리은행 사잇돌 대출 자격조건 및 한도 계산 방법',
#    'link': 'https://ilovefamily.tistory.com/535',
#    'description': '🧭 지난 1년간 사잇돌 대출 시장은 금리 인상, 대출 규제 변화, 그리고 <b>핀테크</b> 기업들의 공격적인 진출... <b>핀테크</b> 플랫폼을 통한 사잇돌 대출 비교 및 신청 서비스가 더욱 확대될 것이며, 은행들은 자체적인... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '하나은행 무직자대출 가능조건과 재대출 신청 방법',
#    'link': 'https://ilovefamily.tistory.com/529',
#    'description': '하지만, 동시에 <b>핀테크</b> 기업들의 혁신적인 대출 상품 출시와 정부의 서민 금융 지원 확대 정책은 새로운... 온라인 플랫폼 경쟁 심화: <b>핀테크</b> 기업들의 온라인 플랫폼을 통한 대출 서비스 경쟁이 더욱 심화될... ',
#    'bloggername': '과거,현재,미래, 그리고 나.',
#    'bloggerlink': 'https://ilovefamily.tistory.com/',
#    'postdate': '20251015'},
#   {'title': '환전 수수료 절감 카드·앱 조합 요령',
#    'link': 'https://blog.naver.com/rucruc/224041519591',
#    'description': '최소화)는 <b>핀테크</b> 환전 앱이 더 유리한 경우가 많아요. 환전 수수료 절감을 위해선 평소엔 앱에서 미리... 선환전 <b>핀테크</b>에서 외화 보유 실시간 도매/중개 환율 명시 수수료(소액 고정/비율) 충전/출금 한도 확인... ',
#    'bloggername': '행복 운동장',
#    'bloggerlink': 'blog.naver.com/rucruc',
#    'postdate': '20251015'},
#   {'title': 'DIM 사기 사칭 자동매매 시스템의 실체',
#    'link': 'https://blog.naver.com/mgreatmaild18/224041138381',
#    'description': '실체 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw',
#    'bloggerlink': 'blog.naver.com/mgreatmaild18',
#    'postdate': '20251015'},
#   {'title': '아크포인트 블록체인 AI 스테이블코인 투자',
#    'link': 'https://blog.naver.com/whdtnsdl23/224041164931',
#    'description': '기사를 보니 소프트뱅크벤처스, 베인앤컴퍼니 같은 세계적인 투자사 및 컨설팅펌 출신의 <b>핀테크</b> 전문가들을 이미 영입했고요. 개발팀은 서울대, 카이스트 출신의 AI 엔지니어들로 꾸렸다고 합니다. 이건 뭐... ',
#    'bloggername': 'whdtnsdl23님의블로그',
#    'bloggerlink': 'blog.naver.com/whdtnsdl23',
#    'postdate': '20251015'},
#   {'title': '없이 목돈 모으는 법? MTN에 소개된 아임인 소셜<b>핀테크</b>로 해결!',
#    'link': 'https://blog.naver.com/goodfinds/224041515723',
#    'description': '소셜 <b>핀테크</b> 앱으로 주목받고 있습니다.  아임인 설치하기 ※ 앱 사용을 위해서는 AOS 7.0 / iOS 15.6 버전... #아임인 #소셜<b>핀테크</b> #목돈모으기 #재테크앱 #신영일 #머니투데이방송 #스테이지재테크 #대출없이목돈... ',
#    'bloggername': 'goodfinds님의 블로그',
#    'bloggerlink': 'blog.naver.com/goodfinds',
#    'postdate': '20251015'},
#   {'title': '법학 블로그 도전기! <b>핀테크</b>, 학업, 팬심까지 법으로 풀어봐요',
#    'link': 'https://blog.naver.com/2fq2ibfy/224041512718',
#    'description': '<b>핀테크</b>, 학업, 팬심까지 법으로 풀어봐요 두근두근 법학 블로그 도전기! <b>핀테크</b>, 학업, 팬심까지 법으로 풀어봐요 <b>핀테크</b>, 법과 함께라면 똑똑한 금융 생활 어렵지 않아요! 눈 깜짝할 새 지나가는 <b>핀테크</b> 시대, 법... ',
#    'bloggername': '빙빙 돌아가는 회전목마처럼',
#    'bloggerlink': 'blog.naver.com/2fq2ibfy',
#    'postdate': '20251015'},
#   {'title': '11-3. 인공지능(AI)의 자본시장 활용: 사례, 위험, 그리고... ',
#    'link': 'https://blog.naver.com/llivev/224041509364',
#    'description': '요약 이 보고서는 IOSCO(국제증권관리기구) 산하 **<b>핀테크</b> 태스크포스(FTF)**가 수행한 2단계 연구의... 연구 목적과 방법론 IOSCO는 AI 관련 규제 연구를 위해 2022년 **<b>핀테크</b> 태스크포스(FTF)**를 출범시켰고... ',
#    'bloggername': 'Lively and Lovely',
#    'bloggerlink': 'blog.naver.com/llivev',
#    'postdate': '20251015'},
#   {'title': 'LUST클럽 사기 사칭 로맨스스캠 투자 어떻게 해결할까',
#    'link': 'https://blog.naver.com/ickkoju2/224041350303',
#    'description': '해결할까 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이법률사무소',
#    'bloggerlink': 'blog.naver.com/ickkoju2',
#    'postdate': '20251015'},
#   {'title': '오랜만에 보유종목 정리',
#    'link': 'https://blog.naver.com/linear114/224041489013',
#    'description': '근데 쫌 많이 샀음;) 가격대는 예전 로켓랩, 하는일이나 수익구조 / 기반 다지는 방식은 팔란티어와 비슷한 느낌을 받아서 매수해봤음 파가야 테크놀로지 작년부터 관심 가졌던 이스라엘 <b>핀테크</b> 기업 증자를... ',
#    'bloggername': '내일상',
#    'bloggerlink': 'blog.naver.com/linear114',
#    'postdate': '20251015'},
#   {'title': '로드투어 사기 사칭 해외여행 팀미션 대처방안',
#    'link': 'https://blog.naver.com/mgreatmaild18/224041134159',
#    'description': '대처방안 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw',
#    'bloggerlink': 'blog.naver.com/mgreatmaild18',
#    'postdate': '20251015'},
#   {'title': '캐시우드 포트 살펴보기(1010)',
#    'link': 'https://blog.naver.com/10bagger_sisters/224041474231',
#    'description': '축소 <b>핀테크</b>, 자율주행 관련 기업 비중 확대 [신규 편입 종목] LY Corp: 일본의 대형 인터넷·테크 기업 Klarna Group: 스웨덴의 <b>핀테크</b> 회사 Poni.ai: 미국·중국 합작 AI 모빌리티 기업 자율주행차(로보택시... ',
#    'bloggername': '인더로지',
#    'bloggerlink': 'blog.naver.com/10bagger_sisters',
#    'postdate': '20251015'},
#   {'title': '염블리 시장함께읽기 - 기판/호텔/카지노/ESS, 미중갈등에... ',
#    'link': 'https://blog.naver.com/metalblue1/224041473007',
#    'description': '네이버는 <b>핀테크</b> 분야 출신 리더십 체계 구축으로 신사업 추진력 제고 가능 삼성증권, 하나, 고연수 코스피 4000도달시 증권업 PBR도 1배 이상 적용 가능 국내 주식 약정 점유율 7%, 해외 주식 점유율 12... ',
#    'bloggername': '소소한 경제공부',
#    'bloggerlink': 'blog.naver.com/metalblue1',
#    'postdate': '20251015'},
#   {'title': '<b>핀테크</b>/스테이블코인',
#    'link': 'https://blog.naver.com/dufrene_freedom/224041470881',
#    'description': '',
#    'bloggername': 'A small hammer for Escape',
#    'bloggerlink': 'blog.naver.com/dufrene_freedom',
#    'postdate': '20251015'}]}

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="./data/.env_naver") # ./data 폴더에 .env_naver를 불러올 때
# 환경변수 내용 출력
user_id = os.getenv("Id")
secret = os.getenv("Secret")

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path='./.data/.env.naver')
import requests

user_id = os.getenv("user_Id")
user_secret = os.getenv("user_Secret")
url = "https://openapi.naver.com/v1/search/blog"
keyword= "핀테크"
payload = dict(query= keyword,display=100,start=1,sort="date")
headers = {'X-Naver-Client-Id' : user_id,"X-Naver-Client-Secret" : user_secret}
r = requests.get(url,params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
response
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 200
# {'lastBuildDate': 'Tue, 14 Oct 2025 14:24:05 +0900',
#  'total': 476761,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '루민트, 글로벌 협력으로 확장하다',
#    'link': 'https://blog.naver.com/sxnoig/224040826219',
#    'description': '국제 파트너십 강화 루민트는 해외 <b>핀테크</b> 기업들과 협력을 진행 중입니다. 특히 결제 시스템과 데이터 보안 분야에서 협약이 체결되었습니다. 이건 단순한 제휴가 아니라 기술 기반의 실질적 연결입니다.... ',
#    'bloggername': '-',
#    'bloggerlink': 'blog.naver.com/sxnoig',
#    'postdate': '20251014'},
#   {'title': '[케이뱅크 채용] 2026년 케이뱅크 채용연계형 인턴 자소서... ',
#    'link': 'https://blog.naver.com/biographers/224040819512',
#    'description': '따라서 단순히 ‘<b>핀테크</b>가 성장하고 있어서’와 같은 외부적 이유보다는, 케이뱅크만의 서비스·가치·고객 경험 철학에 공감하고, 그것이 본인의 비전과 어떤 방향으로 맞물리는지를 논리적으로 서술해야... ',
#    'bloggername': '자소서 첨삭공방',
#    'bloggerlink': 'blog.naver.com/biographers',
#    'postdate': '20251014'},
#   {'title': '더나은투자 사기 사칭 리딩방 가짜의 온기',
#    'link': 'https://blog.naver.com/slted81266/224039801939',
#    'description': '온기 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/slted81266',
#    'postdate': '20251014'},
#   {'title': '금융 심사의 미래 : 신용점수 vs 소셜 신용 점수',
#    'link': 'https://blog.naver.com/ouoigno361/224040533855',
#    'description': '이런 방식은 아직 국내에서는 본격적으로 도입되지 않았지만, 해외에서는 이미 일부 <b>핀테크</b> 기업들이... <b>핀테크</b> 기술의 발전으로 인해 국내외 다양한 기업들도 유사한 시도를 하고 있으며, 앞으로는 이런 방식이... ',
#    'bloggername': '소비의미학',
#    'bloggerlink': 'blog.naver.com/ouoigno361',
#    'postdate': '20251014'},
#   {'title': '달라진 신용대출 금리 체계와 금융 소비자에게 다가올 주요... ',
#    'link': 'https://blog.naver.com/ggudaofficial/224040799628',
#    'description': '최근에는 FICO 점수 외에도 은행 자체 모델이나 <b>핀테크</b> 기업의 대안 신용평가가 활용되며, 통신료 납부 이력, 공공요금 납부 기록 등 비금융 데이터가 금리 산정에 반영되기도 합니다. 영국은 신용조회기관(CRA)... ',
#    'bloggername': 'GGUDA',
#    'bloggerlink': 'blog.naver.com/ggudaofficial',
#    'postdate': '20251014'},
#   {'title': '넥스볼트 사기 NexVault 로맨스스캠 리딩방 수법 정밀 분석... ',
#    'link': 'https://blog.naver.com/lucifer49329/224040661212',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/lucifer49329',
#    'postdate': '20251014'},
#   {'title': '리사블룸 사기 lsabbact 사칭 팀미션 가면 뒤의 진짜 얼굴',
#    'link': 'https://blog.naver.com/mongoli62869/224039790424',
#    'description': '얼굴 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/mongoli62869',
#    'postdate': '20251014'},
#   {'title': '2025.10.14 한국 경제 신문 &lt;최근에 쇼핑했던 주식들과 최근... ',
#    'link': 'https://blog.naver.com/haileytax/224040789155',
#    'description': '비자 비자는 페이팔과 같은 이유 푸투 홀딩스 상대적으로 규모가 작은 <b>핀테크</b> 및 투자지주회사 유동성이 낮음 데번 에너지 미국의 대표적인 세일 오일, 천연가스 개발 회사. 고배당주 판둬둬 시가 총액 높은... ',
#    'bloggername': 'Hailey Tax Blog',
#    'bloggerlink': 'blog.naver.com/haileytax',
#    'postdate': '20251014'},
#   {'title': '10월 14일 블록체인 소식',
#    'link': 'https://blog.naver.com/phill_ssing/224040783777',
#    'description': '및 <b>핀테크</b> 전문 기업 두나무의 협력이 AI(인공지능)와 웹3(Web3)를 결합한 새로운 벤처 생태계 구축으로 이어질 것이라는 전망이 나온다. 양사의 파트너십은 단순한 페이 서비스나 자산 관리 연동을 넘어, AI... ',
#    'bloggername': "Phill's 삶 속 이야기",
#    'bloggerlink': 'blog.naver.com/phill_ssing',
#    'postdate': '20251014'},
#   {'title': '변화하는 규제 환경, 2025년 사업자 생존 전략',
#    'link': 'https://blog.naver.com/miracle1024_/224040775902',
#    'description': '특히 새로운 기술을 활용하는 <b>핀테크</b>, 빅데이터 분야의 규제와 감독 체계가 강화되고 있습니다. 높은... 금융 및 혁신 분야 규제 대응 <b>핀테크</b>나 디지털 자산 분야의 사업자는 ‘규제 샌드박스’ 제도를... ',
#    'bloggername': '기업운영자금상담',
#    'bloggerlink': 'blog.naver.com/miracle1024_',
#    'postdate': '20251014'},
#   {'title': '더나은투자 사기 및 리딩방 미끼 경계 가이드 (사칭)',
#    'link': 'https://blog.naver.com/dtive84494/224040773011',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/dtive84494',
#    'postdate': '20251014'},
#   {'title': '2025년, ‘비은행의 시대’ — 보이지 않는 금융권력이... ',
#    'link': 'https://blog.naver.com/nandahaha_/224040771863',
#    'description': '금리상승 #유동성리스크 #레버리지위험 #DSR강화 #저축은행 #캐피탈사 #보험사 #증권사 #<b>핀테크</b>금융 #대체금융 #현금흐름투자 #금융리스크 #2025경제 #글로벌자금흐름 #리스크관리 #금융분석 #경제인사이트',
#    'bloggername': '발길이 이끄는 대로',
#    'bloggerlink': 'blog.naver.com/nandahaha_',
#    'postdate': '20251014'},
#   {'title': '씨오비 사기 사칭 코인투자 겉만 번지르르한 말들',
#    'link': 'https://blog.naver.com/mongoli62869/224039786745',
#    'description': '말들 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/mongoli62869',
#    'postdate': '20251014'},
#   {'title': '넥스볼트 사기 NexVault 사칭 로맨스스캠 거짓의 포장지',
#    'link': 'https://blog.naver.com/mongoli62869/224039783984',
#    'description': '포장지 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/mongoli62869',
#    'postdate': '20251014'},
#   {'title': '[칼럼] 비밀과 투명성 사이 — 빌더버그 회의, 그리고 글로벌... ',
#    'link': 'https://blog.naver.com/84jojo/224040749131',
#    'description': '새로운 엘리트 구조 ― 기술기업과 중앙은행의 결합 오늘날 빌더버그의 새로운 축은 테크·<b>핀테크</b>·디지털 화폐다. 2019년 회의 명단에는 Google, Microsoft, Santander, Ripple의 파트너 기관 관계자들이... ',
#    'bloggername': '인문학과 블록체인(화폐) 혁명',
#    'bloggerlink': 'blog.naver.com/84jojo',
#    'postdate': '20251014'},
#   {'title': 'Assessing Bank Performance with Operational Researchand... ',
#    'link': 'https://blog.naver.com/blackzelkova/224040745659',
#    'description': '#은행성과평가 #운영연구 #인공지능금융 #데이터포락분석 #효율성측정 #SFA #신경망 #퍼지로직 #유전알고리즘 #하이브리드모델 #AI은행 #<b>핀테크</b>분석 #금융데이터사이언스 #설명가능AI... ',
#    'bloggername': '왕십리 살쾡이',
#    'bloggerlink': 'blog.naver.com/blackzelkova',
#    'postdate': '20251014'},
#   {'title': '신용카드한도 백화점 상품권현금화 할부 결제 이용 현황',
#    'link': 'https://blog.naver.com/hdhddhddd/224040746142',
#    'description': '<b>핀테크</b>는 가상통화부터 부동산까지 다양한 영역에 적용되고 있다. 어려운 상황에서도 경제적 안정을 찾는 건 위험한 샛길에서 벗어나 안전한 대로로 가는 것과 같다. 그러니 앞으로도 신중하게 차근차근... ',
#    'bloggername': '딩딩이의 먹방 만년 다이어리',
#    'bloggerlink': 'blog.naver.com/hdhddhddd',
#    'postdate': '20251014'},
#   {'title': 'Global Vicke 사기 투자 리딩방 주의해야 할 이유 (사칭)',
#    'link': 'https://blog.naver.com/crnivorous20772/224040742194',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/crnivorous20772',
#    'postdate': '20251014'},
#   {'title': '네이버 주가 전망, 지금 사야 할까? 꼭 알아야 할 3가지',
#    'link': 'https://blog.naver.com/kangho1119/224040540873',
#    'description': '최근에 네이버가 <b>핀테크</b> 회사 두나무와 결합한다는 뉴스 봤죠? 표면적으로는 &quot;웹3 시대를 대비한다&quot;는... #NAVER #네이버 #035420 #주식투자 #포털사이트 #커머스 #목표주가 #투자분석 #<b>핀테크</b> #BUY',
#    'bloggername': '머니플러스',
#    'bloggerlink': 'blog.naver.com/kangho1119',
#    'postdate': '20251014'},
#   {'title': 'AZ financial 사기 사칭 투자플랫폼 완벽은 가장 안전한 가면',
#    'link': 'https://blog.naver.com/mongoli62869/224039777421',
#    'description': '가면 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/mongoli62869',
#    'postdate': '20251014'},
#   {'title': '한국의 인기 직업 트렌드 — MZ세대가 선택한 미래형 커리어',
#    'link': 'https://blog.naver.com/chleogh40/224040743150',
#    'description': '소프트웨어 엔지니어, AI 개발자, 데이터 분석가 등의 수요가 폭발적으로 증가하고 있으며, <b>핀테크</b>(Fintech), 블록체인, 사이버 보안, 스타트업 기술 개발 분야에서도 인재 경쟁이 치열합니다. 삼성, 네이버... ',
#    'bloggername': '도날드트럼프',
#    'bloggerlink': 'blog.naver.com/chleogh40',
#    'postdate': '20251014'},
#   {'title': '“파라과이를 남미의 실리콘밸리로” - 가브리엘라 시빌리스... ',
#    'link': 'https://blog.naver.com/ny-keith/224040434315',
#    'description': '<b>핀테크</b>, 에듀테크, 그린테크 분야에서 신생 기업들이 속속 등장하며, ‘라틴테크 신흥 허브’ 로 주목받고 있다. 가브리엘라는 “파라과이가 작다고 해서 가능성이 작은 건 아니다. 실리콘밸리도 처음엔... ',
#    'bloggername': '행복 메신저',
#    'bloggerlink': 'blog.naver.com/ny-keith',
#    'postdate': '20251014'},
#   {'title': 'Global Vicke 사기 사칭 리딩방 완벽해 보여야만 하는 이유',
#    'link': 'https://blog.naver.com/mongoli62869/224039772596',
#    'description': '이유 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/mongoli62869',
#    'postdate': '20251014'},
#   {'title': '로빈후드 (HOOD) 경제적 해자',
#    'link': 'https://blog.naver.com/hadu_zlz/224040731265',
#    'description': '로빈후드(Robinhood)는 미국 최대 <b>핀테크</b> 기반 투자·거래 플랫폼으로서, 젊은 고객층의 충성도를 바탕으로 금융 슈퍼앱 전략을 통해 혁신적 성장세를 보이고 있음. 2025년 2분기에는 3분기 연속 흑자를... ',
#    'bloggername': '헤이지듀드',
#    'bloggerlink': 'blog.naver.com/hadu_zlz',
#    'postdate': '20251014'},
#   {'title': '[UPPITY 머니레터] 베트남, 글로벌 최저한세(15%) 도입 — 한국... ',
#    'link': 'https://blog.naver.com/myungsu0912/224040731088',
#    'description': '<b>핀테크</b>/결제: 스테이블코인 송금 확대 → 글로벌 간편결제, 거래소와 제휴 가속(예: 일본 페이페이, 바이낸스 재팬 지분 40% 인수).  기업 LG에너지솔루션: 3Q 영업이익 6,013억 원(+34.1% YoY) — ESS 수요 호조.... ',
#    'bloggername': '책 속의 명수씨',
#    'bloggerlink': 'blog.naver.com/myungsu0912',
#    'postdate': '20251014'},
#   {'title': '가전제품 담보대출, 언제까지 가능할까?',
#    'link': 'https://blog.naver.com/miharu8282/224040725372',
#    'description': '최근에는 <b>핀테크</b> 기업에서도 빠르고 손쉽게 대출이 가능합니다. 3.모바일 앱 대출: 다양한 금융 앱을 통해 신용 분석을 거쳐 소액 대출을 받아볼 수 있습니다. 이는 빠른 승인과 간단한 절차가 특징입니다.... ',
#    'bloggername': '엄마의 돈공부 책공부',
#    'bloggerlink': 'blog.naver.com/miharu8282',
#    'postdate': '20251014'},
#   {'title': '신용카드한도 백화점 상품권현금화 할부 결제 이용 원리',
#    'link': 'https://blog.naver.com/hdhddhddd/224040720641',
#    'description': '<b>핀테크</b> 분야는 그야말로 넓은 바다와도 같습니다. 암호화폐에서부터 부동산까지 다양한 영역을... 폭풍우 속에서도 항해를 이어가는 배처럼, 기준금리 인상과 불확실한 전망 속에서도 <b>핀테크</b> 분야는 성장세를... ',
#    'bloggername': '딩딩이의 먹방 만년 다이어리',
#    'bloggerlink': 'blog.naver.com/hdhddhddd',
#    'postdate': '20251014'},
#   {'title': '페이코신용카드상품권현금화 서비스 이용 시 주의사항... ',
#    'link': 'https://blog.naver.com/hdhddhddd/224040718219',
#    'description': '늘었더라구요~ <b>핀테크</b> 산업에 대한 관심도 점점 커지고 있고요! 비트코인, 주식, 부동산 같은 자산에도... <b>핀테크</b> 산업이 그래서 더 주목받는 것 같아요! 0.56포인트로 상품권을 사는 건 흔치 않은 투자법이에요... ',
#    'bloggername': '딩딩이의 먹방 만년 다이어리',
#    'bloggerlink': 'blog.naver.com/hdhddhddd',
#    'postdate': '20251014'},
#   {'title': '10월 14일 국내 글로벌 코인 이슈, 정보!!',
#    'link': 'https://blog.naver.com/lbank-/224040715843',
#    'description': '동시에 한국 <b>핀테크</b> 기업 Toss가 원화 기반 스테이블코인 발행을 검토 중이라는 보도도 있고, 정부 쪽에서도 관련 법제 정비 가능성이 논의되고 있습니다. 만약 성사되면, 원화 스테이블코인이 국내외... ',
#    'bloggername': '코인의 모든것을 도와드립니다. "코모도"',
#    'bloggerlink': 'blog.naver.com/lbank-',
#    'postdate': '20251014'},
#   {'title': '최근 암호화폐 시장의 급락은 기관 투자자들의 의도적인 시장... ',
#    'link': 'https://blog.naver.com/ucrypto/224040712383',
#    'description': '* 시사하는 바: 이번 협력은 암호화폐가 단순 투자 자산을 넘어 실제 기관 금융 인프라에 통합되기 시작했음을 보여주며, 향후 국내 블록체인, <b>핀테크</b>, IT 기업들에게도 새로운 산업 기회가 열릴... ',
#    'bloggername': 'U+Crypto Academy',
#    'bloggerlink': 'blog.naver.com/ucrypto',
#    'postdate': '20251014'},
#   {'title': 'Global Vicke 사기 투자 리딩방의 교묘한 수법과 대응방법... ',
#    'link': 'https://blog.naver.com/dissocition12385/224040713051',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': 'daylaw 강민성 대표 변호사',
#    'bloggerlink': 'blog.naver.com/dissocition12385',
#    'postdate': '20251014'},
#   {'title': '인도네시아 주식 시장, 소액 투자자들의 공감과 분노',
#    'link': 'https://blog.naver.com/begin_of_empathy/224040705276',
#    'description': '특히 금융 서비스의 접근성을 높여주었던 <b>핀테크</b> 기업들이 성장 후 수익성을 위해 정책을 변경할 때, 초기 사용자들의 공감을 얻지 못하면 큰 반발에 직면할 수 있다는 것을 보여주는 사례네요. 2.... ',
#    'bloggername': '공감의 시작',
#    'bloggerlink': 'blog.naver.com/begin_of_empathy',
#    'postdate': '20251014'},
#   {'title': '[10월 부산설명회 초청] 호주 머독대학교 in 싱가포르... ',
#    'link': 'https://blog.naver.com/freewayinternational/224040704311',
#    'description': '분석, <b>핀테크</b>, 호스피탈리티 및 관광경영, 인사관리, 정보기술, 법학, 물류 및 공급망 관리, 마케팅 및 경영, 대중매체 커뮤니케이션, 미디어 커뮤니케이션 및 디지털 마케팅, 심리학, 심리학 및 상담... ',
#    'bloggername': '프리웨이 에듀케이션',
#    'bloggerlink': 'blog.naver.com/freewayinternational',
#    'postdate': '20251014'},
#   {'title': '케이뱅크 역 이름이 생긴 이유 3가지, 서울이 들썩인 진짜 사연',
#    'link': 'https://blog.naver.com/bhivv/224040584698',
#    'description': '경험하는 <b>핀테크</b> 문화”를 완성하고 있는 셈이라고 봐야 한다 ※ 함께 보면 좋은 글 https://blog.naver.com/bhivv/224038476383 이유 3. 지하철 45개 역사에 깔린 생활형 금융 네트워크 생활 속에서도 케이뱅크는 이미... ',
#    'bloggername': '목마른 경제적 자유',
#    'bloggerlink': 'blog.naver.com/bhivv',
#    'postdate': '20251014'},
#   {'title': '미래에셋 박현주회장의 큰딸 박하민이 꿈꾸는 원대한 미래',
#    'link': 'https://blog.naver.com/the-economy/224040700478',
#    'description': '넥서스베이캐피탈의 창업자인 구승하 대표는 과거 중국 <b>핀테크</b> 기업 크레딧이즈(CreditEase)의 글로벌 VC·PE 부문을 총괄해 운용자산 규모를 10억 달러 수준까지 성장시킨 경력이 있다. 또한 맥쿼리, GCM... ',
#    'bloggername': '더 이코노미(The Economy)',
#    'bloggerlink': 'blog.naver.com/the-economy',
#    'postdate': '20251014'},
#   {'title': 'CMA금리비교: 현명한 투자자를 위한 숨겨진 꿀팁 대방출!',
#    'link': 'https://blog.naver.com/gghyui/224040375383',
#    'description': '같은 <b>핀테크</b> 앱을 통해 CMA 금리를 비교하는 사람들도 많습니다. 이러한 앱들은 사용자 친화적인 인터페이스를 제공하여 CMA 상품을 직관적으로 비교할 수 있도록 도와줍니다. 하지만, <b>핀테크</b> 앱에서... ',
#    'bloggername': '⭐경제-킴잡스 이야기⭐',
#    'bloggerlink': 'blog.naver.com/gghyui',
#    'postdate': '20251014'},
#   {'title': '무직자 대출: 신용점수, 담보 활용, 한도 증액까지 현실적인... ',
#    'link': 'https://blog.naver.com/worldcon88/224040692141',
#    'description': '무직자는 토스 등 <b>핀테크</b> 플랫폼으로 대출 신청하면 승인이 더 잘 되나요? • 플랫폼별 자체 스크리닝 기준은 별도로 존재하나, 최종 승인 기준은 각 제휴 금융사의 심사 정책에 따릅니다. 기대출 과다... ',
#    'bloggername': '라이프케어가드',
#    'bloggerlink': 'blog.naver.com/worldcon88',
#    'postdate': '20251014'},
#   {'title': '독일 송금 수수료 부담없이 저렴하게!',
#    'link': 'https://blog.naver.com/wirebarley_official/224040681890',
#    'description': '와이어바알리는 독자적인 <b>핀테크</b> 기술을 통해 중개은행을 거치지 않고 독일 해외송금이 가능한데요.... 빠른 송금 처리 독자적인 <b>핀테크</b> 기술을 통해 중개은행 없이 빠른 송금 처리가 가능하여 간편하게... ',
#    'bloggername': 'WireBarley, 글로벌 해외송금',
#    'bloggerlink': 'blog.naver.com/wirebarley_official',
#    'postdate': '20251014'},
#   {'title': 'NAVER 최신 리포트 정리, 목표주가와 전망 정리',
#    'link': 'https://blog.naver.com/ytl26/224040674392',
#    'description': '서론: NAVER, 지금 주목해야 할 타이밍 네이버는 검색, 광고, 커머스, 콘텐츠, <b>핀테크</b>, 웹툰 등 다방면 서비스를 운영하며 플랫폼 기업으로 자리매김해 왔습니다. 최근에는 AI 투자, 두나무 관련 사업 연계... ',
#    'bloggername': '책배남',
#    'bloggerlink': 'blog.naver.com/ytl26',
#    'postdate': '20251014'},
#   {'title': '테마동향_251013',
#    'link': 'https://blog.naver.com/become_buja84/224040001052',
#    'description': '(Yanolja), <b>핀테크</b>(FinTech), 여행, 줄기세포, 가상화폐(비트코인 등), 블록체인, 무선충전기술, 비만치료제, SNS(소셜네트워크서비스) 등... 로봇(산업용/협동로봇 등)/ 지능형로봇/인공지능(AI) 피규어AI, 3세대... ',
#    'bloggername': '성공, 매일 반복되는 작은 노력의 합',
#    'bloggerlink': 'blog.naver.com/become_buja84',
#    'postdate': '20251014'},
#   {'title': '주말 비대면대출 가능한곳 확고하게 안내',
#    'link': 'https://blog.naver.com/zooer/224040079926',
#    'description': '스마트폰 기술의 빠른 발전과 함께 <b>핀테크</b> 산업도 급성장하면서 토스 뱅크나 카카오뱅크 같은 디지털 은행들이 생겨났고 다양한 금융사에 서도 온라인 전용 상품을 꾸준히 출시하고 있습늬다. 그렇다면... ',
#    'bloggername': '주노CAKE',
#    'bloggerlink': 'blog.naver.com/zooer',
#    'postdate': '20251014'},
#   {'title': '한국 유니콘 기업 현황',
#    'link': 'https://blog.naver.com/s-cover/224040671190',
#    'description': '업종 분포는 전자상거래 4개, 소매업 2개, 기타 7개로 다양하나 <b>핀테크</b>·AI 등 기술 분야가... 전체적으로 <b>핀테크</b>(Toss, $7.4B), 모빌리티(Kakao Mobility, $6.5B), 게임(Bluehole Studio, $4.6B), e-commerce... ',
#    'bloggername': '에스커버 모바일 액세서리 전문 쇼핑몰',
#    'bloggerlink': 'blog.naver.com/s-cover',
#    'postdate': '20251014'},
#   {'title': '와이즈 Wise USD, AUD달러 계좌 개설 모인 MOIN 송금서비스... ',
#    'link': 'https://blog.naver.com/juho524/224040666691',
#    'description': '해외 송금이나 외화 결제가 필요할 때, 비싼 은행수수료 대신 빠르고 저렴한 <b>핀테크</b> 앱 하나로... Wise(와이즈) 앱으로 USD, AUD 계좌 개설하는 방법 와이즈는 영국 <b>핀테크</b> 기반의 글로벌 금융 서비스로... ',
#    'bloggername': '퇴직금으로 여행하는 심플수트',
#    'bloggerlink': 'blog.naver.com/juho524',
#    'postdate': '20251014'},
#   {'title': 'AZ Financial 사기 투자 플랫폼 수법 완전 분석 (사칭)',
#    'link': 'https://blog.naver.com/lucifer49329/224040522753',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/lucifer49329',
#    'postdate': '20251014'},
#   {'title': '프랙탈에프엔 리틀버핏 오전 뉴스 [10/14 (화)]',
#    'link': 'https://blog.naver.com/mmd1292/224040659480',
#    'description': '안녕하세요, 오늘의 주요 <b>핀테크</b> 뉴스를 공유 드립니다. 한국<b>핀테크</b>지원센터 Daily News Monitoring [10/14 (화)] [한국<b>핀테크</b>지원센터] 1. 2025 <b>핀테크</b> 전문가 과정 ‘FinBoost... ',
#    'bloggername': '리틀버핏',
#    'bloggerlink': 'blog.naver.com/mmd1292',
#    'postdate': '20251014'},
#   {'title': '네이버 업비트 두나무 관련주, 뱅크웨어글로벌 종목 분석',
#    'link': 'https://blog.naver.com/luckyinnae/224040653772',
#    'description': '네이버 두나무 인수 관련주 총정리 | 뱅크웨어글로벌 주가 전망과 투자전략 최근 <b>핀테크</b> 시장이... 결제·<b>핀테크</b> 인프라 공급사 NHN KCP, 쿠콘, 헥토파이낸셜, 다날 스테이블코인·결제 API 핵심 수혜주 금융 IT... ',
#    'bloggername': '심소장의 아파트분양 리뷰',
#    'bloggerlink': 'blog.naver.com/luckyinnae',
#    'postdate': '20251014'},
#   {'title': '쇼피파이 2분기 어닝콜 프리젠테이션 자료 분석',
#    'link': 'https://blog.naver.com/hhr4376/224040649401',
#    'description': 'https://s27.q4cdn.com/572064924/files/doc_presentations/2025/May/08/Investor-Overview-Deck-Q1-2025-2.pdf AI 활용 설정 사진 설명을 입력하세요. AI 활용 설정 사진 설명을 입력하세요. 해당 이미지는 쇼피파이(Shopify)의 주요... ',
#    'bloggername': '생각이 돈이다',
#    'bloggerlink': 'blog.naver.com/hhr4376',
#    'postdate': '20251014'},
#   {'title': '변화와 미래 전망:금융권 동향부터 디지털 혁신,<b>핀테크</b>까지',
#    'link': 'https://blog.naver.com/dth73819/224040643226',
#    'description': '금융산업 변화와 미래전망 : 금융권 동향부터 디지털 혁신, <b>핀테크</b> 까지 안녕하세요,금융에 관심있는 여러분! 최근 금융 산업은 빠르게 변화하고 있습니다. 전통 금융권은 물론, 디지털 금융과 <b>핀테크</b>까지... ',
#    'bloggername': '삽살개',
#    'bloggerlink': 'blog.naver.com/dth73819',
#    'postdate': '20251014'},
#   {'title': '[도약 프로그램] 2025 중소기업 지원, 도약(Jump-Up)... ',
#    'link': 'https://blog.naver.com/fki_lsc/224040446624',
#    'description': '서비스 <b>핀테크</b>, 인슈어테크, 로보어드바이저, 디지털 뱅킹 등 전문 및 교육 서비스 에듀테크, 온라인 교육 플랫폼, 디자인 컨설팅 등 친환경 및 스마트인프라 신재생에너지 태양광, 풍력, 수소에너지, 지열... ',
#    'bloggername': '한경협중소기업협력센터',
#    'bloggerlink': 'blog.naver.com/fki_lsc',
#    'postdate': '20251014'},
#   {'title': '2025년 10월 14일 - 15일 미국주식정보(25.10.14... ',
#    'link': 'https://blog.naver.com/wnguddhkd/224040630301',
#    'description': '기대 • <b>핀테크</b>: GS, PYPL(PayPal), MQ(Marqeta) ‘매도’ 하향 – 마진 압박 및 집중 리스크 지적 5️⃣ 자산시장 동향 • 채권시장 휴장(Columbus Day)으로 변동 제한. WTI $59.95, Gold $4,114로 상승... ',
#    'bloggername': '호기심',
#    'bloggerlink': 'blog.naver.com/wnguddhkd',
#    'postdate': '20251014'},
#   {'title': '실리콘밸리 <b>핀테크</b> 하프모어, 딥코어 리드 투자로 누적 35억 원... ',
#    'link': 'https://blog.naver.com/ksvalley/224040630287',
#    'description': '딥코어 관계자는 &quot;하프모어는 강력한 초기 성과와 넓은 금융 웰니스로의 확장 잠재력을 갖췄다&quot;며 투자 배경을 밝혔다.',
#    'bloggername': 'k스타트업 밸리',
#    'bloggerlink': 'blog.naver.com/ksvalley',
#    'postdate': '20251014'},
#   {'title': '[CTN정보]꼭 읽어야 할 서울시소식',
#    'link': 'https://blog.naver.com/ggh7000/224040630580',
#    'description': '(금) ‘(재)서울투자진흥재단 창립총회’ 개최…설립 전 주요사항 심의 및 의결 - 창립총회 이후, 법인설립 허가 및 등기 등 제반 절차 거쳐 10월말 출범 목표 - GFCI 3년 연속 Top10, <b>핀테크</b> 8위 최초... ',
#    'bloggername': 'CTN신문사',
#    'bloggerlink': 'blog.naver.com/ggh7000',
#    'postdate': '20251014'},
#   {'title': '가족간 차용증 이자율 부모자식 형제 작성법(양식 무료다운)',
#    'link': 'https://blog.naver.com/kapbue/224040628117',
#    'description': '<b>핀테크</b> 기반의 앱을 통해 변호사 검토가 포함된 계약서를 작성할 수 있으며, 본인 인증까지 완료되어 법적 효력을 갖출 수 있습니다. 전자 차용증은 종이보다 보관이 쉽고 분실 위험도 적어 요즘 많은 분들이... ',
#    'bloggername': '호치스의 50억 만드는 부동산',
#    'bloggerlink': 'blog.naver.com/kapbue',
#    'postdate': '20251014'},
#   {'title': '무직자도 OK! 지금 바로 대출 가능?',
#    'link': 'https://blog.naver.com/himse/224040621180',
#    'description': '<b>핀테크</b> 기술의 발전과 더불어 청년, 취업준비생, 사회초년생 등 다양한 계층을 위한 맞춤형 대출 상품이 쏟아져 나오고 있어요.은행 문턱이 높다고 좌절하지 마세요. 2금융권, <b>핀테크</b> 기업 등 다양한 곳에서... ',
#    'bloggername': '아파트 담보대출 전문! OK자산관리대부',
#    'bloggerlink': 'blog.naver.com/himse',
#    'postdate': '20251014'},
#   {'title': '2025년 노벨 경제학상 - “창조적 파괴”',
#    'link': 'https://blog.naver.com/jeenu123/224040620030',
#    'description': '✅ <b>핀테크</b>·디지털 금융: Toss 등 — 은행·결제 시스템의 경쟁 재구성 무엇이 바뀌었나: Toss 등 <b>핀테크</b>는 간편송금·금융서비스를 통해 전통 은행의 소매금융 일부를 잠식하고, 사용자 경험을 재정의.... ',
#    'bloggername': 'Humus',
#    'bloggerlink': 'blog.naver.com/jeenu123',
#    'postdate': '20251014'},
#   {'title': '전자금융공동망은 어떻게 진화했을까, 미래 금융의 뿌리',
#    'link': 'https://blog.naver.com/rlocate/224040618979',
#    'description': "넘어 '금융기관과 <b>핀테크</b> 기업의 연결 허브'로 확장되었습니다 <b>핀테크</b> 기업들은 중앙은행이 관리하는 공동망을 통해 은행의 핵심 결제 기능에 접근할 수 있게 되었고 이는 간편 송금, 간편 결제 등 다양한... ",
#    'bloggername': '미소 지는 순간',
#    'bloggerlink': 'blog.naver.com/rlocate',
#    'postdate': '20251014'},
#   {'title': '패스트파이브, 올 상반기 재계약률 94%...‘믿고 찾는 사무실... ',
#    'link': 'https://blog.naver.com/phenomdark/224040619773',
#    'description': '실제 장기 입주 기업 중 한 곳인 글로벌 <b>핀테크</b> 기업 와이어바알리는 2019년 첫 입주 이후 6년 이상 패스트파이브를 거점 오피스로 사용해 왔다. 와이어바알리는 성장 단계마다 필요한 규모와 입지를 유연하게... ',
#    'bloggername': 'SHOW MUST GO ON..',
#    'bloggerlink': 'blog.naver.com/phenomdark',
#    'postdate': '20251014'},
#   {'title': '7편 – PG(Payment Gateway)란 무엇인가',
#    'link': 'https://blog.naver.com/dydwo7151-/224040619374',
#    'description': 'PG의 진화 – <b>핀테크</b>와 함께 가는 길 최근 PG 산업은 단순한 결제 중개를 넘어 데이터 기반 정산, 마케팅, 소비 분석을 제공하는 방향으로 발전하고 있습니다. 또한 블록체인 기술과 결합해, 국경 없는... ',
#    'bloggername': 'dydwo7151-님의 블로그',
#    'bloggerlink': 'blog.naver.com/dydwo7151-',
#    'postdate': '20251014'},
#   {'title': '급여통장 신규 개설 및 인터넷뱅킹 신청 방법',
#    'link': 'https://blog.naver.com/elow1957/224040614815',
#    'description': '다른 <b>핀테크</b> 서비스의 대안 서론 요즘 대부분의 금융거래가 온라인으로 이루어지고 있습니다. 이에... 다른 <b>핀테크</b> 서비스의 대안 최근에는 카카오뱅크, 케이뱅크 등 인터넷 전문은행을 통한 다양한 통장... ',
#    'bloggername': '내가 좋아하는것들',
#    'bloggerlink': 'blog.naver.com/elow1957',
#    'postdate': '20251014'},
#   {'title': '전망좋은주식 미국 주식 종목 중심 분석',
#    'link': 'https://blog.naver.com/wwlcc28/224040612860',
#    'description': '에너지 저장, 5G 통신, <b>핀테크</b> 분야 또한 안정적인 성장세를 보이고 있습니다. 이런 흐름 속에서 주목받는 기업들은 기술력, 수익 구조, 시장 점유율 세 가지 기준에서 공통된 특징을 가집니다. “지속... ',
#    'bloggername': 'wwlcc28님의 블로그',
#    'bloggerlink': 'blog.naver.com/wwlcc28',
#    'postdate': '20251014'},
#   {'title': '인도 ETF｜RISE 인도디지털성장·KODEX 인도Nifty50·TIGER... ',
#    'link': 'https://blog.naver.com/notinghel/224040610822',
#    'description': 'MarketVector 지수를 추종하며, 인도의 인터넷·<b>핀테크</b>·통신·클라우드 기업들이 중심입니다.... IT, <b>핀테크</b>, 통신 대형주, 금융, 에너지 소비재, 서비스, 자동차 최근 NAV 수준 약 10,300원 약 13... ',
#    'bloggername': 'notinghel님의 블로그',
#    'bloggerlink': 'blog.naver.com/notinghel',
#    'postdate': '20251014'},
#   {'title': '감성지능: <b>핀테크</b> 고객 경험의 미래',
#    'link': 'https://blog.naver.com/pxjlpss565/224040607064',
#    'description': '감성지능: <b>핀테크</b> 고객 경험의 미래 <b>핀테크</b> 산업은 빠르게 발전하고 있으며, 이에 따라 고객 경험에 대한 요구도 더욱 증가하고 있다. 최근 감성지능 기술의 발전으로 <b>핀테크</b> 기업들은 더욱 개인화된 서비스를... ',
#    'bloggername': '운동과 공부가 취미',
#    'bloggerlink': 'blog.naver.com/pxjlpss565',
#    'postdate': '20251014'},
#   {'title': '[신한투자증권 미국주식 주요이슈] 챗GPT 내 즉시 결제... ',
#    'link': 'https://blog.naver.com/shinhansec_official/224040598934',
#    'description': '구글과 쇼핑 전쟁 : 이번 기능은 오픈AI의 자체 기술인 ‘에이전틱 커머스 프로토콜’과 <b>핀테크</b> 기업 스트라이프(Stripe)와의 협력을 통해 구현됐고, 앞으로 장바구니 기능 및 글로벌 확장도 계획 중이에요.... ',
#    'bloggername': '신한투자증권 공식 블로그',
#    'bloggerlink': 'blog.naver.com/shinhansec_official',
#    'postdate': '20251014'},
#   {'title': '영문계약서, 어디서부터 봐야 할까? 기본 구조와 핵심 조항... ',
#    'link': 'https://blog.naver.com/legal_lemonade/224040593334',
#    'description': 'About the Authour 국내 대형은행 법무팀에서 10년 이상 국제금융, 신용장, 영문계약서 및 외국환규제 자문 등을 담당하고, <b>핀테크</b> 기업에서 해외 지급결제와 해외 진출 등 다양한 프로젝트를 수행한... ',
#    'bloggername': '리걸 레몬에이드',
#    'bloggerlink': 'blog.naver.com/legal_lemonade',
#    'postdate': '20251014'},
#   {'title': '비트코인관련주 코인베이스 다날 우리기술투자 주가 분석',
#    'link': 'https://blog.naver.com/fashiongreen/224040588409',
#    'description': "기반 <b>핀테크</b> / 결제 플랫폼 기업으로 암호화폐 결제 플랫폼인 다날<b>핀테크</b>를 개발해 '페이코인'을 실생활 결제에 적용하는 등의 경험을 가지고 있는데요 이러한 기술력을 기반으로 스테이블코인 사업 진출... ",
#    'bloggername': '돈 되는 경제만 쉽고 빠르게',
#    'bloggerlink': 'blog.naver.com/fashiongreen',
#    'postdate': '20251014'},
#   {'title': '신용점수 올리는 방법 2025 최신 기준 정리',
#    'link': 'https://blog.naver.com/sssolution1858/224039350975',
#    'description': '정확한 진단 정직한 처방 고객과 상생을 도모하는 에스에스솔루션 2025년 들어 신용점수 제도가 한층 더 정교해졌다. 단순히 연체 없이 대출을 갚는 것만으로는 점수를 높이기 어렵고, 금융사마다 평가 기준이... ',
#    'bloggername': 'Sssolution',
#    'bloggerlink': 'blog.naver.com/sssolution1858',
#    'postdate': '20251014'},
#   {'title': 'RISE 인도디지털성장 ETF 완전정리｜인도 디지털 인프라... ',
#    'link': 'https://blog.naver.com/notinghel/224040584997',
#    'description': '이 ETF는 인도의 IT·통신·<b>핀테크</b>·디지털 인프라 산업을 대표하는 상장기업들로 구성되어... 디지털 인프라, 온라인 서비스, 통신, <b>핀테크</b>, 클라우드 등 인도의 정보기술 기반 산업 성장을... ',
#    'bloggername': 'notinghel님의 블로그',
#    'bloggerlink': 'blog.naver.com/notinghel',
#    'postdate': '20251014'},
#   {'title': '시니어 마케팅, 60대·70대·80대, 같은 ‘시니어’로 묶어선... ',
#    'link': 'https://blog.naver.com/trotnewsofficial/224040583199',
#    'description': '평생교육, 디지털 고급 교육(<b>핀테크</b>, AI 활용)을 제공하세요. 여가·문화·관광 바우처를 적극 활용하세요. 70대 정책: 안전 관리 만성질환 예방 바우처, 보안·사기 예방 교육을 확대하세요. 디지털 서비스에 1:1... ',
#    'bloggername': '시니어마케팅 연구소',
#    'bloggerlink': 'blog.naver.com/trotnewsofficial',
#    'postdate': '20251014'},
#   {'title': '신한은행 2026년 동계 청년인턴 채용 완벽 가이드 - 금융권... ',
#    'link': 'https://blog.naver.com/cymmcymm/224040566983',
#    'description': '결합된 <b>핀테크</b> 시대에 꼭 필요한 경험을 쌓을 수 있는 기회랍니다. 신한은행 청년인턴 지원 자격 조건... 금융권 취업을 준비하고 계신 분들, IT와 금융을 결합한 <b>핀테크</b> 분야에 관심 있는 분들 모두에게 정말... ',
#    'bloggername': 'Creater Y',
#    'bloggerlink': 'blog.naver.com/cymmcymm',
#    'postdate': '20251014'},
#   {'title': '“솔라나 × 한국 스테이블코인 — 주식시장에서 주목할... ',
#    'link': 'https://blog.naver.com/hmn1204/224040565408',
#    'description': '증가 <b>핀테크</b> / 결제 플랫폼 스테이블코인 → 결제/송금/정산 활용 가능성, 자체 플랫폼 내 사용... <b>핀테크</b> / 결제 플랫폼 회사 (예: 토스 등) 실제 보도가 있듯 토스(Toss)가 “원화 기반 스테이블코인 발행”을... ',
#    'bloggername': '억만덕후의 이시대 살아남는법',
#    'bloggerlink': 'blog.naver.com/hmn1204',
#    'postdate': '20251014'},
#   {'title': '미국의 파이어족이 불러올 경제의 나비효과',
#    'link': 'https://blog.naver.com/garts44/224040562087',
#    'description': '오늘날의 <b>핀테크</b>, 국채, 디지털 자산이 같은 역할을 하고 있습니다. 5️⃣ 소비재·유통 도시화와 중산층의 등장으로 전국 유통망이 생겼고, 시어스의 카탈로그와 코카콜라는 그 시대의 아이콘이었습니다.... ',
#    'bloggername': '오늘 질문은...',
#    'bloggerlink': 'blog.naver.com/garts44',
#    'postdate': '20251014'},
#   {'title': '[<b>핀테크</b> 기자단] 2025 K-DATA·신용보즘기금·한국<b>핀테크</b>지... ',
#    'link': 'https://blog.naver.com/koreafintech/224040557226',
#    'description': '지난 9월 18일 디캠프 프론트원에서 진행된 2025 K-DATA·신용보즘기금· 한국<b>핀테크</b>지원센터 IR DAY 데모데이에 <b>핀테크</b> 대학생 기자단이 현장취재를 다녀왔습니다! 각 기관이 지원하는 유망 스타트업들을... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20251014'},
#   {'title': '8월 서울 오피스 시장 분석 — 거래 급감에도 공실률은 하락',
#    'link': 'https://blog.naver.com/jsh5015/224040557309',
#    'description': 'AI, <b>핀테크</b>, 콘텐츠 업종 중심으로 오피스 입주 문의는 오히려 증가세.”  임대비용 — NOC 상승세... AI·<b>핀테크</b>·콘텐츠 산업 중심의 신규 오피스 수요 지속 하반기에는 강남·성수·여의도권 중심 재계약... ',
#    'bloggername': '부동산과 경제 뉴스 정리, 분양 소식과 다양한 정보',
#    'bloggerlink': 'blog.naver.com/jsh5015',
#    'postdate': '20251014'},
#   {'title': '증권사리포트 요약본 2025.10.14',
#    'link': 'https://blog.naver.com/kwangpoong/224040556592',
#    'description': '[035420] ˝AI, <b>핀테크</b>, 커머스˝ 모두 바쁨 ▶ 3Q25 Preview: 영업이익 5,579억원(+13.9% YoY)으로 컨센서스 하회 추정 ▶ 중장기 <b>핀테크</b> 사업 가치 부각 하나증권 이준호 카카오 [035720] 3분기 영업이익 1... ',
#    'bloggername': '學習忍',
#    'bloggerlink': 'blog.naver.com/kwangpoong',
#    'postdate': '20251014'},
#   {'title': '스테이블코인 결제시스템 3가지 핵심 변화 총정리',
#    'link': 'https://blog.naver.com/law_sugarsquare/224035670742',
#    'description': "* [상담문의]  02-563-5877  010-****-**** 카톡 '법무법인슈가스퀘어' 검색! 또는 카카오톡 상담링크  ****@sugar.legal #스테이블코인 #결제시스템 #<b>핀테크</b> #블록체인 #금융혁신",
#    'bloggername': '법무법인 슈가스퀘어 블로그',
#    'bloggerlink': 'blog.naver.com/law_sugarsquare',
#    'postdate': '20251014'},
#   {'title': '2025년 10월 14일 관심종목(주식)',
#    'link': 'https://blog.naver.com/kk9550ch/224040546776',
#    'description': 'idxno=3162806 아이티센피엔에스 - 통합 보안시스템+양자암호 솔루션 - <b>핀테크</b>, 스테이블코인 관련주 [특징주] 아이티센피엔에스, &quot;美 스테이블코인 규제법 통과&quot; 가상화폐 ... ',
#    'bloggername': '재테크 in my life (feat.맛난음식)',
#    'bloggerlink': 'blog.naver.com/kk9550ch',
#    'postdate': '20251014'},
#   {'title': '오늘자 이커머스 전망에 대해 알아보자',
#    'link': 'https://blog.naver.com/pdion/224040542746',
#    'description': '결제·<b>핀테크</b> 통합 BNPL(Buy Now Pay Later), 간편 결제, 디지털 월렛 등이 사용자 경험을 매끄럽게 할 것 마켓플레이스 재편 / 플랫폼 경쟁 플랫폼 간 제휴, 인수합병, 수수료 및 데이터 경쟁이 심화될 것 3. 기회... ',
#    'bloggername': '피디온',
#    'bloggerlink': 'blog.naver.com/pdion',
#    'postdate': '20251014'},
#   {'title': '코스피 시가총액 순위, 대한민국 TOP10 기업 성적표',
#    'link': 'https://blog.naver.com/hanvit_lol/224040543213',
#    'description': 'TOP10에 턱걸이로 안착했으며 <b>핀테크</b>, 콘텐츠, AI 삼박자를 앞세워서 제2의 도약을 노리고 있는 중이다. 이상으로 대한민국 경제의 심장인 코스피 TOP10 기업들의 역동적인 성적표 보았다. 25년의 성적표는 AI... ',
#    'bloggername': '잘먹고 잘사는 오리좌',
#    'bloggerlink': 'blog.naver.com/hanvit_lol',
#    'postdate': '20251014'},
#   {'title': '[비트코인 스탠다드]가 말하지 못한 것: GENIUS Act와 STABLE... ',
#    'link': 'https://blog.naver.com/10000reading/224040540164',
#    'description': '이 경우 카드 네트워크·은행 코어·<b>핀테크</b> 월렛이 스테이블코인 결제 레일을 품으며 **‘매끄러운... 은행-<b>핀테크</b>-카드사가 맺는 삼각 파트너십이 관건이다. 4) 체인 간 상호운용성과 계정 추상화 모바일... ',
#    'bloggername': '일만리딩',
#    'bloggerlink': 'blog.naver.com/10000reading',
#    'postdate': '20251014'},
#   {'title': '네이버·카카오, AI 전환으로 실적 폭발!',
#    'link': 'https://blog.naver.com/smart-moneylog/224039305600',
#    'description': '디지털 자산, <b>핀테크</b>, 블록체인 등 새로운 성장축이 확실히 잡히는 셈이죠. AI에다 가상자산까지... 앞으로의 관전 포인트 네이버는 AI로 쇼핑과 <b>핀테크</b>를, 카카오는 AI로 커뮤니케이션과 광고를 진화시키는... ',
#    'bloggername': '스마트머니로그',
#    'bloggerlink': 'blog.naver.com/smart-moneylog',
#    'postdate': '20251014'},
#   {'title': '비바리퍼블리카 주가 급등하는 이유, 2025년 상장 앞둔 토스의... ',
#    'link': 'https://blog.naver.com/kwonmj1216/224022265678',
#    'description': '최근 <b>핀테크</b> 업계에서 가장 뜨거운 관심을 받는 비바리퍼블리카에 대한 궁금증이었습니다. 실제로... 나 역시 <b>핀테크</b> 업계를 10년 넘게 지켜보면서 이만큼 탄탄한 실적 기반을 갖춘 회사를 본 적이 드물다고... ',
#    'bloggername': '올인포',
#    'bloggerlink': 'blog.naver.com/kwonmj1216',
#    'postdate': '20251014'},
#   {'title': 'AI가 리드하는 <b>핀테크</b> 혁신의 미래! : 서울 <b>핀테크</b> 위크 2025... ',
#    'link': 'https://blog.naver.com/elmanproduction/224040539614',
#    'description': '오늘은 서울 <b>핀테크</b> 위크 2025 홍보 영상 제작 후기를 들고 왔습니다. 로딩중,,, 글로번 <b>핀테크</b> 축제인 서울 <b>핀테크</b> 위크 2025가 곧 개최됩니다. 금융과 AI, <b>핀테크</b> 산업의 주요 이슈를 다루고 혁신적인... ',
#    'bloggername': 'ELMAN 영상제작사',
#    'bloggerlink': 'blog.naver.com/elmanproduction',
#    'postdate': '20251014'},
#   {'title': '벤처기업도 이제 ‘가상자산 거래업’을 할 수 있다!',
#    'link': 'https://blog.naver.com/veteran01/224040538500',
#    'description': '◆ 기대 효과 혁신 스타트업의 진입 확대: 블록체인 기술 기반의 <b>핀테크</b>, 거래 플랫폼, 토큰증권(STO) 등 다양한 영역에서 벤처기업들이 자유롭게 사업을 추진할 수 있습니다. 투자 활성화: 벤처기업 인증이... ',
#    'bloggername': 'Not success but Service',
#    'bloggerlink': 'blog.naver.com/veteran01',
#    'postdate': '20251014'},
#   {'title': '<b>핀테크</b>와 혁신의 만남 : 제4회 피노베이션 챌린지 행사 오프닝... ',
#    'link': 'https://blog.naver.com/elmanproduction/224040533011',
#    'description': '<b>핀테크</b>(Fintech)와 이노베이션(Innovation)을 합친 용어로, 서울시가 추진해온 프로그램입니다. <b>핀테크</b>, 인슈어테크, AI, 빅데이터 등 다양한 기술 역량을 가진 스타트업을 발굴하고, 금융사와의 공동 사업화를... ',
#    'bloggername': 'ELMAN 영상제작사',
#    'bloggerlink': 'blog.naver.com/elmanproduction',
#    'postdate': '20251014'},
#   {'title': '10월 14일. 투자자를 위한 뉴스 속 실마리 [자본시장 이슈... ',
#    'link': 'https://blog.naver.com/numbersmembers/224040531979',
#    'description': "https://www.insightkorea.co.kr/news/articleView.html?idxno=233417 Published on: 2025-10-13 15:34:00 가상자산 M&amp;A 3배 급증…금융·<b>핀테크</b> '합종연횡' 본격화 /전자신문 가상자산 업계 인수합병(M&amp;A) 발표가... ",
#    'bloggername': 'M&A·지배구조·Deal·기업분석 뉴스 서비스 <넘버스>',
#    'bloggerlink': 'blog.naver.com/numbersmembers',
#    'postdate': '20251014'},
#   {'title': '디지털 브레튼우즈의 서막: 달러·금의 시대를 넘어 블록체인... ',
#    'link': 'https://blog.naver.com/10000reading/224040531447',
#    'description': 'IMF·BIS와 함께 민간 PSP, <b>핀테크</b>, 은행 컨소시엄이 공동으로 의결권을 행사하여 권력 집중을 방지한다. 5~7년의 로드맵: 테스트넷에서 글로벌 표준으로 1단계에서는 CBDC 상호운용 최소규격과 디지털 SDR... ',
#    'bloggername': '일만리딩',
#    'bloggerlink': 'blog.naver.com/10000reading',
#    'postdate': '20251014'},
#   {'title': '[GPU Live] GPUaaS 서비스 GPU Live!',
#    'link': 'https://blog.naver.com/nhn_injeinc/224039765197',
#    'description': '✅ 금융·<b>핀테크</b> 산업 GPU Live는 금융기관에서 중요한 딥러닝 기반 이상거래 탐지(FDS), 신용평가 모델링, 고객 행동 분석 등대규모 연산이 필요한 금융 서비스 환경에 최적화되어 있습니다! GPU 자원을... ',
#    'bloggername': 'NHN 인재아이엔씨',
#    'bloggerlink': 'blog.naver.com/nhn_injeinc',
#    'postdate': '20251014'},
#   {'title': '채무통합대환대출조건 채무통합으로 시작하는 현명한 재무 관리',
#    'link': 'https://blog.naver.com/my-loan-clinic/223949594538',
#    'description': '금융사의 상품을 비교할 때 대출 비교 앱이나 <b>핀테크</b> 플랫폼을 적극 활용해 봐야 합니다. 통합 대출 시 발생할 수 있는 수수료나 추가 비용도 반드시 확인하셔야 합니다. 직접 금융 기관 상담이 어렵다면 전문가... ',
#    'bloggername': '마이금융클리닉 공식블로그',
#    'bloggerlink': 'blog.naver.com/my-loan-clinic',
#    'postdate': '20251014'},
#   {'title': '카드매출로 보증받는 법, 실전 가이드',
#    'link': 'https://blog.naver.com/yj920621/224040121932',
#    'description': '은행·<b>핀테크</b> 특례형) Tip: 현금 매출 비중이 높아도 카드·PG 매출 증빙 비율을 최대화하면 한도에 유리합니다. 준비물 체크리스트 - 필수 - 사업자등록증 사본 - 대표자 신분증 - 최근 6~12개월 카드매출 내역... ',
#    'bloggername': '한국중소기업 지원센터',
#    'bloggerlink': 'blog.naver.com/yj920621',
#    'postdate': '20251014'},
#   {'title': '가상자산: ‘벤처인증 허용’+‘대출 규제’ 병행… 산업은... ',
#    'link': 'https://blog.naver.com/k3228452/224040522149',
#    'description': '#가상자산 #크립토 #디지털자산 #벤처인증 #디지털자산기본법 #스테이블코인 #렌딩규제 #금리상한 #레버리지금지 #소비자보호 #공시의무 #내부통제 #준법감시 #리스크관리 #거래소 #커스터디 #<b>핀테크</b> #웹3',
#    'bloggername': '한눈정책 – 핵심만 콕, 하루 한 장',
#    'bloggerlink': 'blog.naver.com/k3228452',
#    'postdate': '20251014'},
#   {'title': 'Eat-Lancet이 제시한 이상적인 식단',
#    'link': 'https://blog.naver.com/yelms/224040517993',
#    'description': '이는 저렴한 식물성 단백질 기반의 간편식(HMR), 개인 맞춤형 구독 서비스, 혹은 건강한 식습관을 유도하는 챌린지 앱과 같은 <b>핀테크</b> 결합 서비스 등 무궁무진한 사업 기회를 의미한다. 2. 전통 식단의 보호와... ',
#    'bloggername': '국경없는금융포럼',
#    'bloggerlink': 'blog.naver.com/yelms',
#    'postdate': '20251014'},
#   {'title': '2025.10.14(화) 기업 리포트 요약 정리',
#    'link': 'https://blog.naver.com/timulys/224040516473',
#    'description': 'A035420 -˝AI, <b>핀테크</b>, 커머스˝ 모두 바쁨 3Q25 Preview: 영업이익 5,579억원(+13.9% YoY)으로 컨센서스 하회 추정 중장기 <b>핀테크</b> 사업 가치 부각 매수 320,000 262,500 SK증권 남효지 2025/10/14... ',
#    'bloggername': '투자하는 행복',
#    'bloggerlink': 'blog.naver.com/timulys',
#    'postdate': '20251014'},
#   {'title': '[TUO]10월14일 세계뉴스: 가자 휴전, 우크라 토마호크, EU... ',
#    'link': 'https://blog.naver.com/world-response/224040514540',
#    'description': '넷째, 유엔 사이버협약의 서명·비준 과정을 거치며 데이터 이전, 전자증거 교환, 플랫폼 책임 범위가 분명해지면 클라우드·보안·<b>핀테크</b> 기업의 규제 대응 비용과 수익 모델에도 변화가 생길 가능성이 큽니다.... ',
#    'bloggername': '장대표의 인사이드 베트남',
#    'bloggerlink': 'blog.naver.com/world-response',
#    'postdate': '20251014'},
#   {'title': 'Global Vicke 사기 투자 리딩방 미끼 완전 해부 (사칭)',
#    'link': 'https://blog.naver.com/lucifer49329/224040508093',
#    'description': '(사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기 #투자사기대응법 #투자사기법적대응 #사기피해회복 #사기피해대응 #사기피해전문변호사 #<b>핀테크</b>전문 #사기피해전문... ',
#    'bloggername': '데이 강민성 변호사',
#    'bloggerlink': 'blog.naver.com/lucifer49329',
#    'postdate': '20251014'},
#   {'title': 'Angel❤️월세·전세금 부담 줄이는 혁신 서비스  보증금... ',
#    'link': 'https://blog.naver.com/nyk34644/224040504261',
#    'description': '이런 고민을 해결해주는 다양한 <b>핀테크</b> 서비스들이 등장하고 있어 관심이 집중되고 있습니다.... <b>핀테크</b> 스타트업 데브디에서 출시한 집업페이는 또 다른 혁신을 가져왔습니다. 바로 집주인의 동의 없이도... ',
#    'bloggername': '작으면서 큰 부동산이야기',
#    'bloggerlink': 'blog.naver.com/nyk34644',
#    'postdate': '20251014'},
#   {'title': '이직사유 예시 BEST 3, 면접 답변 꿀팁 총정리 &amp; 합격 전략!',
#    'link': 'https://blog.naver.com/staffs00/224040498054',
#    'description': '최근 <b>핀테크</b> 분야에 큰 관심을 갖게 되면서 귀사의 AI 기반 개인화 금융 서비스를 주목하게... 제가 보유한 대용량 데이터 처리 경험과 금융 도메인 지식을 바탕으로 귀사 AI <b>핀테크</b> 서비스의 안정성과 확장성... ',
#    'bloggername': 'STAFFS STORY',
#    'bloggerlink': 'blog.naver.com/staffs00',
#    'postdate': '20251014'},
#   {'title': '2030대가 선호하는 대기업 TOP10과 선택 이유',
#    'link': 'https://blog.naver.com/rct190/224040494783',
#    'description': '카카오 플랫폼, 콘텐츠, <b>핀테크</b> 등 영역을 넘나들며 혁신을 시도하는 모습이 2030대의 관심을 끌고 있습니다. “미래 가치가 기대된다”라는 평가와 함께 브랜드 이미지도 세련되고 젊은 감각이 강하다는... ',
#    'bloggername': '파이어족의 경제, 금융 이야기',
#    'bloggerlink': 'blog.naver.com/rct190',
#    'postdate': '20251014'},
#   {'title': '카카오페이 10월 14일 퀴즈 맞히고 복권 받기',
#    'link': 'https://blog.naver.com/tkadla1422/224040494383',
#    'description': '이처럼 통합 <b>핀테크</b> 플랫폼으로 진화하며 투자, 환전, 보험, 청구서 관리 등 다양한 금융 서비스를 통합 제공하는 점도 큰 강점입니다. 요약하면, 카카오페이는 카카오톡과의 완벽한 연동으로 쉽고 빠른 결제와... ',
#    'bloggername': '김맹구의 탐구생활',
#    'bloggerlink': 'blog.naver.com/tkadla1422',
#    'postdate': '20251014'},
#   {'title': '카카오뱅크 목표가 하향 대출 규제 속 성장 전망 분석 투자 전략!',
#    'link': 'https://blog.naver.com/lottotem_economy/224040487251',
#    'description': '가계대출 규제가 성장 전망치에 미친 구체적 영향 <b>핀테크</b> 리더로서 카카오뱅크는 저렴한 수신 확대를... 시장 컨센서스 비교 및 <b>핀테크</b> 주의 향후 주가 전망 KB증권이 제시한 28,000원의 목표주가는 최근 6개월... ',
#    'bloggername': '경제톡',
#    'bloggerlink': 'blog.naver.com/lottotem_economy',
#    'postdate': '20251014'},
#   {'title': '10/14 섹터별 현황',
#    'link': 'https://blog.naver.com/mark-s/224040487497',
#    'description': '93 <b>핀테크</b>(FinTech) 0.92 mRNA(메신저 리보핵산) 0.92 PCB(FPCB 등) 0.90 코로나19(치료제/백신 개발 등) 0.90 2025 상반기 신규상장 0.89 딥페이크(deepfake) 0.88 제습기 0.87 두나무(Dunamu) 0.86... ',
#    'bloggername': 'Observer',
#    'bloggerlink': 'blog.naver.com/mark-s',
#    'postdate': '20251014'}]}

# %% [markdown]
# # 네이버 API에서 수집가능한 최대 자료 모두 수집하기

# %%
start_num = 1
for i in range(100, 1001, 100):
    if i <= 900:
        print(start_num + i)
    elif i > 900:
        print(i)
# Out:
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1000

# %%
start_num = 1
for i in range(1,11):
    if i < 900:
        start_num += 100
        print(start_num)
    elif i >= 900:
        start_num += 99
        print(start_num)
# Out:
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1001

# %%
# while 문을 이용해야 함
page = 1
if response['total'] // 100 > 10:
    page = 10
else:
    page = response['total'] // 100 +1

# %% [markdown]
# # for문을 이용해 최대한 수집하기
# * naver api는 start 파라미터 최대값 100
# * 1페이지당 100개씩 수집시 최대 11페이지까지 가능

# %%
import pandas as pd

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path="./.data/.env_naver")
import requests

num = 1
all_data = []
for page in range(11):
    user_id = os.getenv("user_Id")
    user_secret = os.getenv("user_Secret")
    url = "https://openapi.naver.com/v1/search/blog"
    keyword = "핀테크"
    payload = dict(query=keyword, display=100, start=num, sort="date")
    headers = {"X-Naver-Client-Id" : user_id, "X-Naver-Client-Secret" : user_secret}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    response = r.json()
    all_data.append(pd.DataFrame(response['items']))    
    
    if num < 901:
        num += 100
    elif num >= 901:
        num += 99
    print(num)
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 401
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 19
#      17 print(r.status_code)
#      18 response = r.json()
# ---> 19 all_data.append(pd.DataFrame(response['items']))
#      21 if num < 901:
#      22     num += 100
#
# KeyError: 'items'

# %%
final_result = pd.concat(all_data)
final_result
# Out:
#                                     title  \
# 0              로드투어 사기 사칭 팀미션 말은 화려했지만 가짜
# 1     AI 인재 확보 전쟁, 금융권이 움직인다! 인재 영입 경쟁 치열
# 2                  루민트 상장, 생태계의 확장기로 접어들다
# 3                      루민트, 글로벌 협력으로 확장하다
# 4   [케이뱅크 채용] 2026년 케이뱅크 채용연계형 인턴 자소서...
# ..                                    ...
# 95        신용플래너: 카카오페이로 신용점수와 금융안전을 한 번에!
# 96    네이버 두나무 인수 합병 빅딜 나스닥 상장 전제 주가 분석(2)
# 97    이튼밴스매니지먼트 사기 사칭 글로벌투자 운용사 피해사례와...
# 98     글린키 사기 리뷰팀 미션 조심하지 않으면 당할수 있다 (사칭)
# 99       네이버와 두나무 (업비트)합병 의미 디지털금융 시장의 전망
#
#                                                 link  \
# 0     https://blog.naver.com/slted81266/224039812321
# 1   https://blog.naver.com/eduwill_gov2/224040534474
# 2     https://blog.naver.com/alscjf0545/224040835833
# 3         https://blog.naver.com/sxnoig/224040826219
# 4    https://blog.naver.com/biographers/224040819512
# ..                                               ...
# 95     https://blog.naver.com/naldaland/224037095538
# 96      https://blog.naver.com/z_zzzzzz/224037095610
# 97     https://blog.naver.com/dgzuxzgby/224036625284
# 98  https://blog.naver.com/lucifer49329/224036660761
# 99    https://blog.naver.com/banyahappy/224037089385
#
#                                           description        bloggername  \
# 0   가짜 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자사기...  daylaw 강민성 대표 변호사
# 1   KB금융그룹은 ‘KB GenAI 포털’을 구축해 그룹 공동 AI 플랫폼을 운영하며,...            에듀윌 블로그
# 2   <b>핀테크</b>, 물류, 엔터테인먼트, 공공 서비스까지. 모든 산업이 블록체인과...    alscjf0545님의블로그
# 3   국제 파트너십 강화 루민트는 해외 <b>핀테크</b> 기업들과 협력을 진행 중입니다...                  -
# 4   따라서 단순히 ‘<b>핀테크</b>가 성장하고 있어서’와 같은 외부적 이유보다는, ...           자소서 첨삭공방
# ..                                                ...                ...
# 95  *본 포스팅은 저작권 보호를 위해 이미지를 AI로 재구성하여 작성되었습니다. #신용...            연결되는 세상
# 96  AI시대에 대해서 블록체인, 금, 비트코인까지 이렇게 크게 떠오르고 있는 상황인데 ...      리치뉴스 RichNews
# 97  대처방안 #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자...            데이법률사무소
# 98  (사칭) #팀미션사기 #주식사기 #코인사기 #스캠사기 #사칭사기 #공모주사기 #투자...         데이 강민성 변호사
# 99  및 <b>핀테크</b> 생태계는 새로운 국면을 맞게 될 가능성이 높다. 다음은 제 ...          늘해피 열정이야기
#
#                     bloggerlink  postdate
# 0     blog.naver.com/slted81266  20251014
# 1   blog.naver.com/eduwill_gov2  20251014
# 2     blog.naver.com/alscjf0545  20251014
# 3         blog.naver.com/sxnoig  20251014
# 4    blog.naver.com/biographers  20251014
# ..                          ...       ...
# 95     blog.naver.com/naldaland  20251010
# 96      blog.naver.com/z_zzzzzz  20251010
# 97     blog.naver.com/dgzuxzgby  20251010
# 98  blog.naver.com/lucifer49329  20251010
# 99    blog.naver.com/banyahappy  20251010
#
# [1100 rows x 6 columns]

# %% [markdown]
# # while문을 이용해서 수집페이지까지 자동화하기

# %%
#while문 이용
from dotenv import load_dotenv
import os
load_dotenv()

total_page = 1
page = 1
num = 1

all_data = []
while page <= total_page:
    user_id = os.getenv("Id")
    user_secret = os.getenv("Secret")
    url = "https://openapi.naver.com/v1/search/blog"
    keword= '핀테크'
    payload = dict(query= keyword,display=100,start=1,sort="date")
    headers = {'X-Naver-Client-Id' : user_id,"X-Naver-Client-Secret" : user_secret}
    r = requests.get(url,params=payload, headers=headers)
    print(r.url)
  #  print(r.status_code)
    response = r.json()
    all_data.append(response['items'])
# 전체 페이지 계산
    if response['total'] // 100 > 11:
        total_page = 11
    else:
        total_page = response['total'] // 100 +1
    #page 증가
    page += 1
    
    # numdl 1000이 되도록
    if num <= 901:
        num += 100
    elif num >= 901:
        num += 99
    print(num)
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 101
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 201
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 301
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 401
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 501
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 601
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 701
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 801
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 901
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 1001
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=date
# 1100

# %%
len(all_data)
# Out:
# 11

# %%
result = {}
for page in all_data:
    for item in page:
        for key,value in item.items():
            if key in['title','description']:
                result.setdefault(key,[]).append(text_clean(value))
            else:
                result.setdefault(key,[]).append(value)
                
final_df = pd.DataFrame(result)               
final_df
# Out:
#                                        title  \
# 0                          루민트 글로벌 협력으로 확장하다
# 1           케이뱅크 채용 2026년 케이뱅크 채용연계형 인턴 자소서
# 2                     더나은투자 사기 사칭 리딩방 가짜의 온기
# 3                 금융 심사의 미래 신용점수 vs 소셜 신용 점수
# 4           달라진 신용대출 금리 체계와 금융 소비자에게 다가올 주요
# ...                                      ...
# 1095  이직사유 예시 BEST 3 면접 답변 꿀팁 총정리 amp 합격 전략
# 1096            2030대가 선호하는 대기업 TOP10과 선택 이유
# 1097              카카오페이 10월 14일 퀴즈 맞히고 복권 받기
# 1098    카카오뱅크 목표가 하향 대출 규제 속 성장 전망 분석 투자 전략
# 1099                            10 14 섹터별 현황
#
#                                                    link  \
# 0            https://blog.naver.com/sxnoig/224040826219
# 1       https://blog.naver.com/biographers/224040819512
# 2        https://blog.naver.com/slted81266/224039801939
# 3        https://blog.naver.com/ouoigno361/224040533855
# 4     https://blog.naver.com/ggudaofficial/224040799628
# ...                                                 ...
# 1095       https://blog.naver.com/staffs00/224040498054
# 1096         https://blog.naver.com/rct190/224040494783
# 1097     https://blog.naver.com/tkadla1422/224040494383
# 1098  https://blog.naver.com/lottotem_economy/224040...
# 1099         https://blog.naver.com/mark-s/224040487497
#
#                                             description        bloggername  \
# 0     국제 파트너십 강화 루민트는 해외 핀테크 기업들과 협력을 진행 중입니다 특히 결제 ...                  -
# 1     따라서 단순히 핀테크가 성장하고 있어서 와 같은 외부적 이유보다는 케이뱅크만의 서비...           자소서 첨삭공방
# 2     온기 팀미션사기 주식사기 코인사기 스캠사기 사칭사기 공모주사기 투자사기 투자사기대응...  daylaw 강민성 대표 변호사
# 3     이런 방식은 아직 국내에서는 본격적으로 도입되지 않았지만 해외에서는 이미 일부 핀테...              소비의미학
# 4     최근에는 FICO 점수 외에도 은행 자체 모델이나 핀테크 기업의 대안 신용평가가 활...              GGUDA
# ...                                                 ...                ...
# 1095  최근 핀테크 분야에 큰 관심을 갖게 되면서 귀사의 AI 기반 개인화 금융 서비스를 ...       STAFFS STORY
# 1096  카카오 플랫폼 콘텐츠 핀테크 등 영역을 넘나들며 혁신을 시도하는 모습이 2030대의...   파이어족의 경제, 금융 이야기
# 1097  이처럼 통합 핀테크 플랫폼으로 진화하며 투자 환전 보험 청구서 관리 등 다양한 금융...          김맹구의 탐구생활
# 1098  가계대출 규제가 성장 전망치에 미친 구체적 영향 핀테크 리더로서 카카오뱅크는 저렴한...                경제톡
# 1099  93 핀테크 FinTech 0 92 mRNA 메신저 리보핵산 0 92 PCB FPC...           Observer
#
#                           bloggerlink  postdate
# 0               blog.naver.com/sxnoig  20251014
# 1          blog.naver.com/biographers  20251014
# 2           blog.naver.com/slted81266  20251014
# 3           blog.naver.com/ouoigno361  20251014
# 4        blog.naver.com/ggudaofficial  20251014
# ...                               ...       ...
# 1095          blog.naver.com/staffs00  20251014
# 1096            blog.naver.com/rct190  20251014
# 1097        blog.naver.com/tkadla1422  20251014
# 1098  blog.naver.com/lottotem_economy  20251014
# 1099            blog.naver.com/mark-s  20251014
#
# [1100 rows x 6 columns]

# %%
final_df.to_csv("./data/네이버api수집1100개.csv", index=False , encoding = 'utf-8-sig')
